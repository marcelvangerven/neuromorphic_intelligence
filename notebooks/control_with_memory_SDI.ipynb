# %% [markdown]
# # Control of a stochastic double integrator

# %%
# Specify the cores to use for XLA
import os
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=10'

import jax
import jax.numpy as jnp
import diffrax
import jax.random as jr
import matplotlib.pyplot as plt
from matplotlib.transforms import ScaledTranslation
from jax import Array
from typing import Tuple, Callable
import copy

from kozax.genetic_programming import GeneticProgramming
from neuromorphic_intelligence.kozax_sdi import StochasticDoubleIntegrator

# %% [markdown]
# First we generate data, consisting of initial conditions, keys for noise, targets and parameters of the environment.

# %%
def get_data(key, env, batch_size, dt, T, param_setting):
    init_key, noise_key, param_key = jr.split(key, 3)
    x0, targets = env.sample_init_states(batch_size, init_key)
    noise_keys = jr.split(noise_key, batch_size)
    ts = jnp.arange(0, T, dt)

    params = env.sample_params(batch_size, param_setting, ts, param_key)
    return jnp.zeros_like(x0), ts, jnp.zeros_like(targets), noise_keys, params # initial state of coupled system set to zero; target location always 0.0

key = jr.PRNGKey(0)
gp_key, data_key = jr.split(key)
batch_size = 16
T = 100
dt = 0.1
param_setting = "Constant"

env = StochasticDoubleIntegrator(process_noise = 0.1, obs_noise = 0.0)

data = get_data(data_key, env, batch_size, dt, T, param_setting)

# %% [markdown]
# The evaluator class parallelizes the simulation of the control loop over the batched data. In each trajectory, a coupled dynamical system is simulated using diffrax, integrating both the dynamic memory and the dynamic environment, defined by the drift and diffusion functions. At every time step, the state of the environment is mapped to observations and the latent memory is mapped to a control signal. Afterwards, the state equation of the memory and environment state is computed. When the simulation is done, the fitness is computed given the control and environment state.

# %%
class Evaluator:
    def __init__(self, env, state_size: int, dt0: float, solver=diffrax.Euler(), max_steps: int = 16**4, stepsize_controller: diffrax.AbstractStepSizeController = diffrax.ConstantStepSize()) -> None:
        """Evaluates dynamic symbolic policies in control tasks.

        Args:
            env: Environment on which the candidate is evaluated.
            state_size: Dimensionality of the hidden state.
            dt0: Initial step size for integration.
            solver: Solver used for integration (default: diffrax.Euler()).
            max_steps: The maximum number of steps that can be used in integration (default: 16**4).
            stepsize_controller: Controller for the stepsize during integration (default: diffrax.ConstantStepSize()).

        Attributes:
            env: Environment on which the candidate is evaluated.
            max_fitness: Max fitness which is assigned when a trajectory returns an invalid value.
            state_size: Dimensionality of the hidden state.
            obs_size: Dimensionality of the observations.
            control_size: Dimensionality of the control.
            latent_size: Dimensionality of the state of the environment.
            dt0: Initial step size for integration.
            solver: Solver used for integration.
            max_steps: The maximum number of steps that can be used in integration.
            stepsize_controller: Controller for the stepsize during integration.
        """
        self.env = env
        self.max_fitness = 1e4
        self.state_size = state_size
        self.obs_size = env.n_obs
        self.control_size = env.n_control_inputs
        self.latent_size = env.n_var*env.n_dim
        self.dt0 = dt0
        self.solver = solver
        self.max_steps = max_steps
        self.stepsize_controller = stepsize_controller

    def __call__(self, candidate: Array, data: Tuple, tree_evaluator: Callable) -> float:
        """Evaluates the candidate on a task.

        Args:
            candidate: The coefficients of the candidate.
            data: The data required to evaluate the candidate.
            tree_evaluator: Function for evaluating trees.

        Returns:
            Fitness of the candidate.
        """
        _, _, _, _, fitness = jax.vmap(self.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(candidate, *data, tree_evaluator)

        fitness = jnp.mean(fitness)
        return fitness
      
    def evaluate_trajectory(self, candidate: Array, x0: Array, ts: Array, target: float, noise_key: jr.PRNGKey, params: Tuple, tree_evaluator: Callable) -> Tuple[Array, Array, Array, Array, float]:
        """Solves the coupled differential equation of the system and controller. 
        The differential equation of the system is defined in the environment and the differential equation 
        of the control is defined by the set of trees.

        Args:
            candidate: Candidate with trees for the hidden state and readout.
            x0: Initial state of the system.
            ts: Time points on which the controller is evaluated.
            target: Target position that the system should reach.
            noise_key: Key to generate noisy observations.
            params: Parameters that define the environment.
            tree_evaluator: Function for evaluating trees.

        Returns:
            States, observations, control, activities of the hidden state of the candidate and the fitness of the candidate.
        """
        env = copy.copy(self.env)
        env.initialize_parameters(params, ts)

        state_equation = candidate[:self.state_size]
        readout = candidate[self.state_size:]
        
        solver = self.solver
        dt0 = self.dt0
        saveat = diffrax.SaveAt(ts=ts)

        process_noise_key, obs_noise_key = jr.split(noise_key, 2)

        # Concatenate the initial state of the system with the initial state of the latent memory
        _x0 = jnp.concatenate([x0, jnp.zeros(self.state_size)])

        brownian_motion = diffrax.UnsafeBrownianPath(shape=(env.n_var,), key=process_noise_key, levy_area=diffrax.SpaceTimeLevyArea) #define process noise
        system = diffrax.MultiTerm(diffrax.ODETerm(self._drift), diffrax.ControlTerm(self._diffusion, brownian_motion))
        
        # Solve the coupled system of the environment and the controller
        # We ignore the learnt initial state and. set to zero
        sol = diffrax.diffeqsolve(
            system, solver, ts[0], ts[-1], dt0, jnp.zeros_like(_x0), saveat=saveat, adjoint=diffrax.DirectAdjoint(), max_steps=self.max_steps, event=diffrax.Event(self.env.cond_fn_nan), 
            args=(env, state_equation, readout, obs_noise_key, target, tree_evaluator), stepsize_controller=self.stepsize_controller, throw=False
        )

        xs = sol.ys[:,:self.latent_size]
        # Get observations of the state at every time step
        _, ys = jax.lax.scan(env.f_obs, obs_noise_key, (ts, xs))

        activities = sol.ys[:,self.latent_size:]
        # Get control actions at every time step
        us = jax.vmap(lambda y, a, tar: tree_evaluator(readout, jnp.concatenate([y, a, jnp.zeros(self.control_size), target])), in_axes=[0,0,None])(ys, activities, target)

        # Compute the fitness of the candidate in this trajectory
        fitness = env.fitness_function(xs, us[:,None], target, ts)

        return xs, ys, us, activities, fitness
    
    def _drift(self, t, x_a, args):
        env, state_equation, readout, obs_noise_key, target, tree_evaluator = args
        x = x_a[:self.latent_size]
        a = x_a[self.latent_size:]

        _, y = env.f_obs(obs_noise_key, (t, x)) #Get observations from system
        u = tree_evaluator(readout, jnp.concatenate([jnp.zeros(self.obs_size), a, jnp.zeros(self.control_size), target])) #Compute control action from latent memory

        u = jnp.atleast_1d(u)

        dx = env.drift(t, x, u) #Apply control to system and get system change
        da = tree_evaluator(state_equation, jnp.concatenate([y, a, u, target])) #Compute change in latent memory

        return jnp.concatenate([dx, da])
    
    def _diffusion(self, t, x_a, args):
        env, state_equation, readout, obs_noise_key, target, tree_evaluator = args
        x = x_a[:self.latent_size]
        a = x_a[self.latent_size:]

        return jnp.concatenate([env.diffusion(t, x, jnp.array([0])), jnp.zeros((self.state_size, self.latent_size))]) #Only the system is stochastic

# %% [markdown]
# Here we define the hyperparameters, operators, variables and initialize the strategy. The control policy will consist of two latent variables and a readout layer. `layer_sizes` allows us to define different types of tree, where `variable_list` contains different sets of input variables for each type of tree. The readout layer will only receive the latent states, while the inputs to the state equations consists of the observations, control signal and latent states.

# %%
#Define hyperparameters
population_size = 100
num_populations = 10
num_generations = 50
state_size = 2

#Define expressions # UNIVERSAL?
operator_list = [("+", lambda x, y: x + y, 2, 0.5), 
                ("-", lambda x, y: x - y, 2, 0.1),
                ("*", lambda x, y: x * y, 2, 0.5)]

variable_list = [["x" + str(i) for i in range(env.n_obs)] + ["a1", "a2"], ["a1", "a2"]]

layer_sizes = jnp.array([state_size, env.n_control_inputs])

#Define evaluator # SHARK FOR SDE WITH ADDITIVE NOISE!
fitness_function = Evaluator(env, state_size, dt, solver=diffrax.GeneralShARK(), max_steps=1000)

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, layer_sizes, num_populations = num_populations, size_parsimony=0.003)

strategy.fit(gp_key, data, verbose=True)
# Out:
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2'].
# In generation 1, best fitness = 11.0282, best solution = [-0.247*x0 + x1, 2.91*x1, -0.302*a2]
# In generation 2, best fitness = 8.9730, best solution = [1.13*a1*x0*(-a1 + a2**2), a1 - 1.12*x1, a2]
# In generation 3, best fitness = 8.2354, best solution = [(x0 - 1.26)*(a2*x0 + a2 + x1), 1.71*a2**2*(-a2 - 0.129), a1]
# In generation 4, best fitness = 7.7956, best solution = [-0.683*a1 + x1, 0.527*x1, 1.23*a2*(a1 - 2.11)]
# In generation 5, best fitness = 5.8152, best solution = [-0.341*a1 + 0.0845*x0 + 0.659*x1, -5.42*x1, 1.23*a1*(a1 - 2.11)]
# In generation 6, best fitness = 5.0349, best solution = [-0.341*a1 + 0.0845*x0 + 0.659*x1, 1.15*a2*x1, 1.23*a1*(-0.0309*a2 - 2.65)]
# In generation 7, best fitness = 4.4887, best solution = [-0.341*a1 + 0.0845*x0 + 0.659*x1, 0.458*x1 - 1.56, 1.23*a1*(2*a1 - 3.67)]
# In generation 8, best fitness = 4.4647, best solution = [-0.341*a1 + 0.0845*x0 + 0.659*x1, 0.132, 1.23*a1*(2*a1 - 3.67)]
# In generation 9, best fitness = 4.4647, best solution = [-0.341*a1 + 0.0845*x0 + 0.659*x1, 0.132, 1.23*a1*(2*a1 - 3.67)]
# In generation 10, best fitness = 4.2702, best solution = [-3.87*a1 + 2.34*x0, -1.12*x1, 2*a1 + 3*a2]
# In generation 11, best fitness = 3.5516, best solution = [-1.53*a1 + 1.53*x0, -1.12*x1, 2*a1 + 3*a2]
# In generation 12, best fitness = 3.1495, best solution = [-2.34*a1 + 2.34*x0, -1.12*x1, 3*a1 + 4*a2]
# In generation 13, best fitness = 3.1495, best solution = [-2.34*a1 + 2.34*x0, -1.12*x1, 3*a1 + 4*a2]
# In generation 14, best fitness = 3.1256, best solution = [-1.53*a1 + 1.53*x0, -1.12*x1, 3*a1 + 4*a2]
# In generation 15, best fitness = 3.1256, best solution = [-1.53*a1 + 1.53*x0, -1.12*x1, 3*a1 + 4*a2]
# In generation 16, best fitness = 3.1256, best solution = [-1.53*a1 + 1.53*x0, -1.12*x1, 3*a1 + 4*a2]
# In generation 17, best fitness = 2.9770, best solution = [0.344*a2, -1.71*a2 - 1.81*x1, 3*a1 + 4*a2]
# In generation 18, best fitness = 2.9517, best solution = [0.344*a2, -1.71*a2 - 1.81*x1, 4*a1 + 3*a2]
# In generation 19, best fitness = 2.9517, best solution = [0.344*a2, -1.71*a2 - 1.81*x1, 4*a1 + 3*a2]
# In generation 20, best fitness = 2.8393, best solution = [0.91*x1*(0.225*a2*x0 + 2.07), -3.42*a2 - 4.46*x1, -1.54*a1 + a2]
# In generation 21, best fitness = 2.8393, best solution = [0.91*x1*(0.225*a2*x0 + 2.07), -3.42*a2 - 4.46*x1, -1.54*a1 + a2]
# In generation 22, best fitness = 2.8049, best solution = [3.28*x1, -2.83*a2 - 1.71*x1, -0.526*a1 + 2.47*a2]
# In generation 23, best fitness = 2.6236, best solution = [-2.09*x1*(-0.471*x0*x1 + 2.07), -3.42*a2 - 4.46*x1, 0.593*a1 + 2*a2]
# In generation 24, best fitness = 2.5595, best solution = [-2.09*x1*(-0.471*x0*x1 + 0.91), -3.42*a2 - 4.46*x1, -0.171*a1*a2 + a1 + 2*a2]
# In generation 25, best fitness = 2.5155, best solution = [-2.09*x1, -3.75*a2 - 2.75*x1, a1 + 2.51*a2]
# In generation 26, best fitness = 2.5114, best solution = [a2, -5.13*a2 - 2.42*x1, 4*a1 + 4*a2]
# In generation 27, best fitness = 2.5114, best solution = [a2, -5.13*a2 - 2.42*x1, 4*a1 + 4*a2]
# In generation 28, best fitness = 2.4928, best solution = [2.34*a2, -5.13*a2 - 1.81*x1, 2*a1 + 6*a2]
# In generation 29, best fitness = 2.4928, best solution = [2.34*a2, -5.13*a2 - 1.81*x1, 2*a1 + 6*a2]
# In generation 30, best fitness = 2.3946, best solution = [2.07*a2, -5.13*a2 - 2.42*x1, 2*a1 + 5*a2]
# In generation 31, best fitness = 2.3932, best solution = [2.07*a2, -5.13*a2 - 2.42*x1, 2*a1 + 6*a2]
# In generation 32, best fitness = 2.3330, best solution = [1.53*a2, -8.55*a2 - 3.42*x1, 3*a1 + 5*a2]
# In generation 33, best fitness = 2.2938, best solution = [1.53*a2, -6.84*a2 - 3.42*x1, 3*a1 + 5*a2]
# In generation 34, best fitness = 2.2908, best solution = [2.34*a2, -8.55*a2 - 3.42*x1, 3*a1 + 5*a2]
# In generation 35, best fitness = 2.2908, best solution = [2.34*a2, -8.55*a2 - 3.42*x1, 3*a1 + 5*a2]
# In generation 36, best fitness = 2.2878, best solution = [1.53*a2, -6.84*a2 - 3.42*x1, 3*a1 + 5*a2]
# In generation 37, best fitness = 2.2657, best solution = [3.58*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# In generation 38, best fitness = 2.2657, best solution = [3.58*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# In generation 39, best fitness = 2.2657, best solution = [3.58*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# In generation 40, best fitness = 2.2657, best solution = [3.58*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# In generation 41, best fitness = 2.2657, best solution = [3.58*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# In generation 42, best fitness = 2.2657, best solution = [3.58*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# In generation 43, best fitness = 2.2657, best solution = [3.58*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# In generation 44, best fitness = 2.2444, best solution = [3.17*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# In generation 45, best fitness = 2.2444, best solution = [3.17*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# In generation 46, best fitness = 2.2444, best solution = [3.17*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# In generation 47, best fitness = 2.2444, best solution = [3.17*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# In generation 48, best fitness = 2.2444, best solution = [3.17*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# In generation 49, best fitness = 2.2444, best solution = [3.17*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# In generation 50, best fitness = 2.2444, best solution = [3.17*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# Complexity: 3, fitness: 903.9429931640625, equations: [a1, 0.810, a1]
# Complexity: 5, fitness: 5.796449184417725, equations: [x1, a2, -2.8*a1]
# Complexity: 9, fitness: 5.006582736968994, equations: [-0.341*a1 + x1, 2.58, -5.09*a1]
# Complexity: 11, fitness: 4.149129390716553, equations: [-1.53*a1 + 1.53*x0, -2.78*x1, a1 + a2]
# Complexity: 15, fitness: 2.9356908798217773, equations: [a2, -1.71*a2 - 1.71*x1, a1 + 4*a2]
# Complexity: 17, fitness: 2.5169410705566406, equations: [-3.64*a1 + 0.62*x0 + x1, -0.0482, -13.7*a1]
# Complexity: 19, fitness: 2.3467905521392822, equations: [-5.45*a1 + 0.62*x0 + x1, x0, -13.7*a1]
# Complexity: 21, fitness: 2.303041696548462, equations: [-5.45*a1 + 0.62*x0 + x1, -1.35, -15.5*a1]
# Complexity: 25, fitness: 2.3018972873687744, equations: [2.07*a2, -5.13*a2 - 5.13*x1, a1 + 3*a2]
# Complexity: 27, fitness: 2.2811920642852783, equations: [-2.09*x1, -5.13*a2 - 2.75*x1, a1 + 4*a2]
# Complexity: 29, fitness: 2.218632459640503, equations: [-2.09*x1, -6.84*a2 - 3.42*x1, a1 + 5*a2]
# Complexity: 31, fitness: 2.1947810649871826, equations: [1.53*a2, -6.84*a2 - 3.42*x1, 3*a1 + 5*a2]
# Complexity: 33, fitness: 2.171060800552368, equations: [2.07*a2, -8.55*a2 - 3.42*x1, 3*a1 + 5*a2]
# Complexity: 35, fitness: 2.1393821239471436, equations: [3.17*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]

# %%
F = []
for g in range(num_generations):
    best_fitness, best_solution = strategy.get_statistics(g+1)
    F.append(-best_fitness)

print(best_fitness)
print(strategy.expression_to_string(best_solution))

# evaluate on new test data
# test_data = get_data(jr.PRNGKey(1), env, 1, dt, 300, param_setting) # dt seemed very different here
# xs, ts, targets, noise_key, params = data

# initial state of latent memory assumed zero!

xs, ys, us, activities, fitness = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(best_solution, *data, strategy.tree_evaluator)
print(jnp.mean(fitness))

best_fitness0, best_solution0 = strategy.get_statistics(1)
xs0, ys0, us0, activities0, fitness0 = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(best_solution0, *data, strategy.tree_evaluator)
print(jnp.mean(fitness0))
# Out:
# 2.2443821
# [3.17*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# 2.1393824
# 8.921961

# %% [markdown]
# # best solution in tikz
#
# \begin{forest}
# for tree={
#     %   edge={->}, % arrows if you want
#   edge path={
#     \noexpand\path [\forestoption{edge}]
#       (!u.parent anchor) -- +(0,-5pt) -| (.child anchor)\forestoption{edge label};
#   },
#   edge={line width=1pt},
#   parent anchor=south,
#   child anchor=north
# }
# [$-$
#   [$-$
#       [$\times$
#           [$-5.32$]
#           [$z_1$]
#       ]
#       [$\times$
#           [$-1.61$]
#           [$s_0$]
#       ]
#   ]
#   [$\times$
#       [$-1.71$]
#       [$s_1$]
#   ]
# ]
# \end{forest}

# %%
# xs0, ys0, us0, activities0, fitness0 = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(init_population, *data, strategy.tree_evaluator)
# jnp.mean(fitness)

# init_strategy = copy.copy(strategy)
# init_strategy.reset()
# key, init_key = jr.split(gp_key)
# init_population = init_strategy.initialize_population(init_key)

# init_population = init_population.reshape(-1, init_population.shape[-1])
# init_population.shape
# best_solution.shape

# %% [markdown]
# ## Visualize best solution

# %%
# best_candidate = strategy.pareto_front[1][17] # how does pareto front work?
# print(strategy.expression_to_string(best_candidate))
# # the representation is a1, a2 and output u

# best_initial_candidate = strategy.pareto_front[1][17] # how does pareto front work?
# print(strategy.expression_to_string(best_candidate))

# compute performance of this candidate on data
# xs, ys, us, activities, fitness = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(best_solution, *data, strategy.tree_evaluator)
# jnp.mean(fitness)

# %%
# res = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(best_candidate, *data, strategy.tree_evaluator)
# States, observations, control, activities of the hidden state of the candidate and the fitness of the candidate.

# %%
#Generate test_data
# test_data = get_data(jr.PRNGKey(1), env, 1, dt, 300, param_setting) # dt seemed very different here
# xs, ts, targets, noise_key, params = data

# ts = jnp.arange(0, T, dt)
# xs, ys, us, activities, fitness = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(best_candidate, *data, strategy.tree_evaluator)

# key, init_key = jr.split(key)
# strategy.reset()
# population = strategy.initialize_population(init_key)
# key, eval_key, sample_key = jr.split(key, 3)
# fitness, population = strategy.evaluate_population(population, data, eval_key)

# %%
ts = jnp.arange(0, T, dt)

fig, ax = plt.subplots(1,3, figsize=(12,3))
# fig.align_xlabels(ax)
# fig.align_ylabels(ax)

ax[0].plot([0, T], [0.0, 0.0], 'k-', lw=0.5,label='_nolegend_')
ax[0].plot(ts, xs0[0,:,0],label='first generation')
ax[0].plot(ts, xs[0,:,0],label='final generation')
ax[0].legend()
ax[0].set_title('Particle position');
ax[0].set_xlabel('time (s)')
# ax[0].text(0.0, 1.0, '(a)', transform=(
#     ax[0].transAxes + ScaledTranslation(-32/72, +7/72, fig.dpi_scale_trans)),
#     fontsize='large', va='bottom', fontfamily='serif')

ax[1].plot([0, T], [0.0, 0.0], 'k-', lw=0.5,label='_nolegend_')
ax[1].plot(ts, xs0[0,:,1],label='first generation')
ax[1].plot(ts, xs[0,:,1],label='final generation')
ax[1].set_title('Particle velocity');
ax[1].set_xlabel('time (s)')
# ax[1].text(0.0, 1.0, '(b)', transform=(
#     ax[1].transAxes + ScaledTranslation(-32/72, +7/72, fig.dpi_scale_trans)),
#     fontsize='large', va='bottom', fontfamily='serif')

# ax[2].plot([0, 40], [0.0, 0.0], 'k-', lw=0.5,label='_nolegend_')
ax[2].plot(jnp.arange(num_generations)+1, F, label='no learning')
ax[2].set_title('Fitness');
ax[2].set_xlabel('generation')
# ax[2].text(0.0, 1.0, '(c)', transform=(
#     ax[2].transAxes + ScaledTranslation(-32/72, +7/72, fig.dpi_scale_trans)),
#     fontsize='large', va='bottom', fontfamily='serif')

for i in range(3):
    ax[i].margins(x=0)
plt.tight_layout()

# plt.savefig('../figures/dgp_results.pdf', format='pdf')

# %%
ts = jnp.arange(0, T, dt)

fig, ax = plt.subplots(1,2, figsize=(8,3))
# fig.align_xlabels(ax)
# fig.align_ylabels(ax)

idx=0
ax[0].plot([0, T], [0.0, 0.0], 'k-', lw=0.5,label='_nolegend_')
ax[0].plot(ts, xs0[idx,:,0],label='first generation')
ax[0].plot(ts, xs[idx,:,0],label='last generation')
ax[0].legend(loc='lower right')
ax[0].set_title('Particle position');
ax[0].set_xlabel('time (s)')

ax[1].plot(jnp.arange(num_generations)+1, F, label='no learning')
ax[1].set_title('Fitness');
ax[1].set_xlabel('generation')

# ax[2].axis('off')

for i in range(2):
    ax[i].margins(x=0)
plt.tight_layout()

plt.savefig('../figures/dgp_results_2states.pdf', format='pdf')

# %%
# key, eval_key, sample_key = jr.split(key, 3)
# fitness, population = strategy.evaluate_population(init_population, data, eval_key)
# f0 = jnp.min(fitness)

# %%
# show phase plane evolution; show phase plane vector field!
# show distribution over fitnesses; show fitness landscape
# show readout 'tree'

import numpy as np

env.initialize_parameters(env.sample_params(1, 'Constant', None, jax.random.PRNGKey(0))[0], None)

vector_field = env.drift

dd = 0.15
xrange=(-dd,dd); 
yrange=(-dd,dd); 
args = jnp.zeros((1,))
ax=None; 
color='lightgrey'

fig, ax = plt.subplots(figsize=(9, 3))

# we are using arange since linspace can lead to uneven spacing!
x_points = np.arange(xrange[0], xrange[1], (xrange[1]-xrange[0])/200)
y_points = np.arange(yrange[0], yrange[1], (yrange[1]-yrange[0])/200)

X, Y = np.meshgrid(x_points, y_points, sparse=False, indexing='xy')

Z = jax.vmap(vector_field, in_axes=(None, 1, None))(0, jnp.vstack([X.flatten(), Y.flatten()]), args)

U = jnp.reshape(Z[:,0], X.shape)
V = jnp.reshape(Z[:,1], Y.shape)
ax.streamplot(np.array(X), np.array(Y), np.array(U), np.array(V), density=0.5, color=color)

# system = System(damping_factor=damping)
# sol = dfx.diffeqsolve(system.terms(), dfx.Tsit5(), t0=0, t1=20, dt0=0.05, y0=system.initial(),\
#             saveat=dfx.SaveAt(steps=True), adjoint=dfx.DirectAdjoint(), max_steps=10000, stepsize_controller=dfx.PIDController(rtol=1e-7, atol=1e-7)) 

# ax = phase_portrait(drift, ax=ax[i], xrange=(-1.5, 1.5), yrange=(-1.5, 1.5))
ax.plot(0, 0, 'k.')
ax.axis('square')
ax.set_xlabel('position')
ax.set_ylabel('velocity')
ax.set_xticks([])
ax.set_yticks([])

# trajectories2d(sol.ys, ax=ax[i], marker=False)

plt.tight_layout()

i=5
n=50
ax.plot(xs0[i,:n,0], xs0[i,:n,1], alpha=1.0, lw=0.5, color='blue', label='first generation')
ax.plot(xs[i,:n,0], xs[i,:n,1], alpha=1.0, lw=0.5, color='red', label='final generation')



# plt.savefig(media+'harmonic_oscillator_phase_diagram.pdf', format='pdf', transparent=True)

# %%
initial_fitness, initial_solution = strategy.get_statistics(1)
final_fitness, final_solution = strategy.get_statistics(num_generations)

# print(strategy.expression_to_string(best_solution))

xs, ys, us, activities, fitness = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(initial_solution, *data, strategy.tree_evaluator)
print(jnp.mean(fitness))

xs, ys, us, activities, fitness = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(final_solution, *data, strategy.tree_evaluator)
print(jnp.mean(fitness))
# Out:
# 8.921961
# 2.1393824

# %%
env.initialize_parameters(env.sample_params(1, 'Constant', None, jax.random.PRNGKey(0))[0], None)

# %%
strategy.print_pareto_front()
# Out:
# Complexity: 3, fitness: 903.9429931640625, equations: [a1, 0.810, a1]
# Complexity: 5, fitness: 5.796449184417725, equations: [x1, a2, -2.8*a1]
# Complexity: 9, fitness: 5.006582736968994, equations: [-0.341*a1 + x1, 2.58, -5.09*a1]
# Complexity: 11, fitness: 4.149129390716553, equations: [-1.53*a1 + 1.53*x0, -2.78*x1, a1 + a2]
# Complexity: 15, fitness: 2.9356908798217773, equations: [a2, -1.71*a2 - 1.71*x1, a1 + 4*a2]
# Complexity: 17, fitness: 2.5169410705566406, equations: [-3.64*a1 + 0.62*x0 + x1, -0.0482, -13.7*a1]
# Complexity: 19, fitness: 2.3467905521392822, equations: [-5.45*a1 + 0.62*x0 + x1, x0, -13.7*a1]
# Complexity: 21, fitness: 2.303041696548462, equations: [-5.45*a1 + 0.62*x0 + x1, -1.35, -15.5*a1]
# Complexity: 25, fitness: 2.3018972873687744, equations: [2.07*a2, -5.13*a2 - 5.13*x1, a1 + 3*a2]
# Complexity: 27, fitness: 2.2811920642852783, equations: [-2.09*x1, -5.13*a2 - 2.75*x1, a1 + 4*a2]
# Complexity: 29, fitness: 2.218632459640503, equations: [-2.09*x1, -6.84*a2 - 3.42*x1, a1 + 5*a2]
# Complexity: 31, fitness: 2.1947810649871826, equations: [1.53*a2, -6.84*a2 - 3.42*x1, 3*a1 + 5*a2]
# Complexity: 33, fitness: 2.171060800552368, equations: [2.07*a2, -8.55*a2 - 3.42*x1, 3*a1 + 5*a2]
# Complexity: 35, fitness: 2.1393821239471436, equations: [3.17*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]

# %%
# Sample the initial population
key, gp_key = jr.split(jr.PRNGKey(0))
population = strategy.initialize_population(gp_key)

for g in range(num_generations):
    key, eval_key, sample_key = jr.split(key, 3)
    # Evaluate the population on the data, and return the fitness
    fitness, population = strategy.evaluate_population(population, (data), eval_key)

    if (g%5)==0:
        print("Generation:", g)
        strategy.print_pareto_front()

    # Evolve the population until the last generation. The fitness should be given to the evolve function.
    if g < (num_generations-1):
        population = strategy.evolve_population(population, fitness, sample_key)
# Out:
# Generation: 0
# Complexity: 3, fitness: 903.9429931640625, equations: [a1, 0.810, a1]
# Complexity: 5, fitness: 5.796449184417725, equations: [x1, a2, -2.8*a1]
# Complexity: 9, fitness: 5.006582736968994, equations: [-0.341*a1 + x1, 2.58, -5.09*a1]
# Complexity: 11, fitness: 4.149129390716553, equations: [-1.53*a1 + 1.53*x0, -2.78*x1, a1 + a2]
# Complexity: 15, fitness: 2.9356908798217773, equations: [a2, -1.71*a2 - 1.71*x1, a1 + 4*a2]
# Complexity: 17, fitness: 2.5169410705566406, equations: [-3.64*a1 + 0.62*x0 + x1, -0.0482, -13.7*a1]
# Complexity: 19, fitness: 2.3467905521392822, equations: [-5.45*a1 + 0.62*x0 + x1, x0, -13.7*a1]
# Complexity: 21, fitness: 2.303041696548462, equations: [-5.45*a1 + 0.62*x0 + x1, -1.35, -15.5*a1]
# Complexity: 25, fitness: 2.3018972873687744, equations: [2.07*a2, -5.13*a2 - 5.13*x1, a1 + 3*a2]
# Complexity: 27, fitness: 2.2811920642852783, equations: [-2.09*x1, -5.13*a2 - 2.75*x1, a1 + 4*a2]
# Complexity: 29, fitness: 2.218632459640503, equations: [-2.09*x1, -6.84*a2 - 3.42*x1, a1 + 5*a2]
# Complexity: 31, fitness: 2.1947810649871826, equations: [1.53*a2, -6.84*a2 - 3.42*x1, 3*a1 + 5*a2]
# Complexity: 33, fitness: 2.171060800552368, equations: [2.07*a2, -8.55*a2 - 3.42*x1, 3*a1 + 5*a2]
# Complexity: 35, fitness: 2.1393821239471436, equations: [3.17*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# Generation: 5
# Complexity: 3, fitness: 903.9429931640625, equations: [a1, a1, a1]
# Complexity: 5, fitness: 5.796449184417725, equations: [x1, a2, -2.8*a1]
# Complexity: 9, fitness: 5.006582736968994, equations: [-0.341*a1 + x1, 2.58, -5.09*a1]
# Complexity: 11, fitness: 4.149129390716553, equations: [-1.53*a1 + 1.53*x0, -2.78*x1, a1 + a2]
# Complexity: 15, fitness: 2.9356908798217773, equations: [a2, -1.71*a2 - 1.71*x1, a1 + 4*a2]
# Complexity: 17, fitness: 2.5169410705566406, equations: [-3.64*a1 + 0.62*x0 + x1, -0.0482, -13.7*a1]
# Complexity: 19, fitness: 2.3467905521392822, equations: [-5.45*a1 + 0.62*x0 + x1, x0, -13.7*a1]
# Complexity: 21, fitness: 2.303041696548462, equations: [-5.45*a1 + 0.62*x0 + x1, -1.35, -15.5*a1]
# Complexity: 25, fitness: 2.3018972873687744, equations: [2.07*a2, -5.13*a2 - 5.13*x1, a1 + 3*a2]
# Complexity: 27, fitness: 2.2811920642852783, equations: [-2.09*x1, -5.13*a2 - 2.75*x1, a1 + 4*a2]
# Complexity: 29, fitness: 2.218632459640503, equations: [-2.09*x1, -6.84*a2 - 3.42*x1, a1 + 5*a2]
# Complexity: 31, fitness: 2.1947810649871826, equations: [1.53*a2, -6.84*a2 - 3.42*x1, 3*a1 + 5*a2]
# Complexity: 33, fitness: 2.171060800552368, equations: [2.07*a2, -8.55*a2 - 3.42*x1, 3*a1 + 5*a2]
# Complexity: 35, fitness: 2.1393821239471436, equations: [3.17*a2, -8.55*a2 - 3.42*x1, 2*a1 + 6*a2]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[107], line 8
#       6 key, eval_key, sample_key = jr.split(key, 3)
#       7 # Evaluate the population on the data, and return the fitness
# ----> 8 fitness, population = strategy.evaluate_population(population, (data), eval_key)
#      10 if (g%5)==0:
#      11     print("Generation:", g)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/kozax/genetic_programming.py:771, in GeneticProgramming.evaluate_population(self, populations, data, key)
#     768     flat_populations = flat_populations.at[best_candidates_idx].set(optimized_population)
#     769     fitness = fitness.at[best_candidates_idx].set(optimized_fitness)
# --> 771 self.update_pareto_front(fitness, flat_populations)
#     773 # Increase fitness based on the size of the candidate
#     774 fitness = fitness + jax.vmap(lambda array: self.size_parsimony * jnp.sum(array[:, :, 0] != 0))(flat_populations)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/kozax/genetic_programming.py:962, in GeneticProgramming.update_pareto_front(self, current_fitness, current_population)
#     951 """
#     952 Updates the Pareto front with the current population.
#     953
#    (...)    959     Current population.
#     960 """
#     961 # Compute complexity of the current population
# --> 962 current_population_complexity = jax.vmap(lambda array: jnp.sum(array[:, :, 0] != 0))(current_population)
#     963 pareto_fitness, pareto_solutions = self.pareto_front
#     965 # Replace the best solutions in the Pareto front with the best solutions at each complexity level
#
#     [... skipping hidden 1 frame]
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/api.py:1053, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1050 try:
#    1051   axis_data = batching.AxisData(axis_name, axis_size_, spmd_axis_name,
#    1052                                 explicit_mesh_axis)
# -> 1053   out_flat = batching.batch(
#    1054       flat_fun, axis_data, in_axes_flat,
#    1055       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes)
#    1056   ).call_wrapped(*args_flat)
#    1057 except batching.SpecMatchError as e:
#    1058   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:607, in _batch_outer(f, axis_data, in_dims, *in_vals)
#     605 tag = TraceTag()
#     606 with source_info_util.transform_name_stack('vmap'):
# --> 607   outs, trace = f(tag, in_dims, *in_vals)
#     608 with core.ensure_no_leaks(trace): del trace
#     609 return outs
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:623, in _batch_inner(f, axis_data, out_dim_dests, tag, in_dims, *in_vals)
#     619   in_tracers = map(partial(to_elt, trace, idx), in_vals, in_dims)
#     620 with (core.set_current_trace(trace),
#     621       core.extend_axis_env_nd([(axis_data.name, axis_data.size)]),
#     622       core.add_spmd_axis_names(axis_data.spmd_name)):
# --> 623   outs = f(*in_tracers)
#     624   out_dim_dests = out_dim_dests() if callable(out_dim_dests) else out_dim_dests
#     625   out_vals = map(partial(from_elt, trace, axis_data.size, axis_data.explicit_mesh_axis),
#     626                  range(len(outs)), outs, out_dim_dests)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:340, in flatten_fun_for_vmap(f, store, in_tree, *args_flat)
#     336 @lu.transformation_with_aux2
#     337 def flatten_fun_for_vmap(f: Callable,
#     338                          store: lu.Store, in_tree: PyTreeDef, *args_flat):
#     339   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# --> 340   ans = f(*py_args, **py_kwargs)
#     341   ans, out_tree = tree_flatten(ans, is_leaf=is_vmappable)
#     342   store.store(out_tree)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:402, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     400 @transformation_with_aux2
#     401 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 402   ans = _fun(*args, **kwargs)
#     403   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     404   if _store:
#     405     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     406     # the bwd function in a custom_vjp
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/kozax/genetic_programming.py:962, in GeneticProgramming.update_pareto_front.<locals>.<lambda>(array)
#     951 """
#     952 Updates the Pareto front with the current population.
#     953
#    (...)    959     Current population.
#     960 """
#     961 # Compute complexity of the current population
# --> 962 current_population_complexity = jax.vmap(lambda array: jnp.sum(array[:, :, 0] != 0))(current_population)
#     963 pareto_fitness, pareto_solutions = self.pareto_front
#     965 # Replace the best solutions in the Pareto front with the best solutions at each complexity level
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:1060, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1059 def op(self, *args):
# -> 1060   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:652, in _getitem(self, item)
#     651 def _getitem(self, item):
# --> 652   return indexing.rewriting_take(self, item)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/numpy/indexing.py:625, in rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value, out_sharding)
#     616 def rewriting_take(arr, idx, indices_are_sorted=False, unique_indices=False,
#     617                    mode=None, fill_value=None, out_sharding=None):
#     618   # Computes arr[idx].
#    (...)    622   # For simplicity of generated primitives, we call lax.dynamic_slice in the
#     623   # simplest cases: i.e. non-dynamic arrays indexed with integers and slices.
# --> 625   if (result := _attempt_rewriting_take_via_slice(arr, idx, mode)) is not None:
#     626     return result
#     628   # TODO(mattjj,dougalm): expand dynamic shape indexing support
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/numpy/indexing.py:598, in _attempt_rewriting_take_via_slice(arr, idx, mode)
#     596   int_start_indices = [int(i) for i in start_indices]  # type: ignore
#     597   int_limit_indices = [i + s for i, s in zip(int_start_indices, slice_sizes)]
# --> 598   arr = lax.slice(
#     599       arr, start_indices=int_start_indices, limit_indices=int_limit_indices)
#     600 else:
#     601   # We must be careful with dtypes because dynamic_slice requires all
#     602   # start indices to have matching types.
#     603   if len(start_indices) > 1:
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/lax/slicing.py:108, in slice(operand, start_indices, limit_indices, strides)
#      57 def slice(operand: ArrayLike, start_indices: Sequence[int],
#      58           limit_indices: Sequence[int],
#      59           strides: Sequence[int] | None = None) -> Array:
#      60   """Wraps XLA's `Slice
#      61   <https://www.tensorflow.org/xla/operation_semantics#slice>`_
#      62   operator.
#    (...)    106     - :func:`jax.lax.dynamic_slice`
#     107   """
# --> 108   return slice_p.bind(operand, start_indices=tuple(start_indices),
#     109                       limit_indices=tuple(limit_indices),
#     110                       strides=None if strides is None else tuple(strides))
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:496, in Primitive.bind(self, *args, **params)
#     494 def bind(self, *args, **params):
#     495   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 496   return self._true_bind(*args, **params)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:512, in Primitive._true_bind(self, *args, **params)
#     510 trace_ctx.set_trace(eval_trace)
#     511 try:
# --> 512   return self.bind_with_trace(prev_trace, args, params)
#     513 finally:
#     514   trace_ctx.set_trace(prev_trace)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:517, in Primitive.bind_with_trace(self, trace, args, params)
#     516 def bind_with_trace(self, trace, args, params):
# --> 517   return trace.process_primitive(self, args, params)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:501, in BatchTrace.process_primitive(self, p, tracers, params)
#     499 elif p in primitive_batchers:
#     500   with core.set_current_trace(self.parent_trace):
# --> 501     val_out, dim_out = primitive_batchers[p](vals_in, dims_in, **params)
#     502 else:
#     503   raise NotImplementedError("Batching rule for '{}' not implemented".format(p))
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/lax/slicing.py:1411, in _slice_batching_rule(batched_args, batch_dims, start_indices, limit_indices, strides)
#    1408   new_strides = list(strides)
#    1409   new_strides.insert(bdim, 1)
# -> 1411 out = slice(operand, new_start_indices, new_limit_indices, new_strides)
#    1412 return out, bdim
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/lax/slicing.py:108, in slice(operand, start_indices, limit_indices, strides)
#      57 def slice(operand: ArrayLike, start_indices: Sequence[int],
#      58           limit_indices: Sequence[int],
#      59           strides: Sequence[int] | None = None) -> Array:
#      60   """Wraps XLA's `Slice
#      61   <https://www.tensorflow.org/xla/operation_semantics#slice>`_
#      62   operator.
#    (...)    106     - :func:`jax.lax.dynamic_slice`
#     107   """
# --> 108   return slice_p.bind(operand, start_indices=tuple(start_indices),
#     109                       limit_indices=tuple(limit_indices),
#     110                       strides=None if strides is None else tuple(strides))
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:496, in Primitive.bind(self, *args, **params)
#     494 def bind(self, *args, **params):
#     495   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 496   return self._true_bind(*args, **params)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:512, in Primitive._true_bind(self, *args, **params)
#     510 trace_ctx.set_trace(eval_trace)
#     511 try:
# --> 512   return self.bind_with_trace(prev_trace, args, params)
#     513 finally:
#     514   trace_ctx.set_trace(prev_trace)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:517, in Primitive.bind_with_trace(self, trace, args, params)
#     516 def bind_with_trace(self, trace, args, params):
# --> 517   return trace.process_primitive(self, args, params)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:1017, in EvalTrace.process_primitive(self, primitive, args, params)
#    1015 args = map(full_lower, args)
#    1016 check_eval_args(args)
# -> 1017 return primitive.impl(*args, **params)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/lax/slicing.py:1434, in _slice_impl(x, start_indices, limit_indices, strides)
#    1430   return dispatch.apply_primitive(
#    1431     slice_p, x, start_indices=start_indices,
#    1432     limit_indices=limit_indices, strides=strides)
#    1433 slice_sizes = tuple(np.array(limit_indices) - np.array(start_indices))
# -> 1434 return dispatch.apply_primitive(dynamic_slice_p, x, *start_indices,
#    1435                                 slice_sizes=slice_sizes)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/dispatch.py:89, in apply_primitive(prim, *args, **params)
#      87 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      88 try:
# ---> 89   outs = fun(*args)
#      90 finally:
#      91   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 1 frame]
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:340, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     335 if config.no_tracing.value:
#     336   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     337                      "`jit`, but 'no_tracing' is set")
#     339 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, executable,
# --> 340  pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     342 maybe_fastpath_data = _get_fastpath_data(
#     343     executable, out_tree, args_flat, out_flat, attrs_tracked, jaxpr.effects,
#     344     jaxpr.consts, jit_info.abstracted_axes,
#     345     pgle_profiler)
#     347 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:193, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     191   out_flat, compiled, profiler = _pjit_call_impl_python(*args_flat, **p.params)
#     192 else:
# --> 193   out_flat = pjit_p.bind(*args_flat, **p.params)
#     194   compiled = None
#     195   profiler = None
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:496, in Primitive.bind(self, *args, **params)
#     494 def bind(self, *args, **params):
#     495   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 496   return self._true_bind(*args, **params)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:512, in Primitive._true_bind(self, *args, **params)
#     510 trace_ctx.set_trace(eval_trace)
#     511 try:
# --> 512   return self.bind_with_trace(prev_trace, args, params)
#     513 finally:
#     514   trace_ctx.set_trace(prev_trace)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:517, in Primitive.bind_with_trace(self, trace, args, params)
#     516 def bind_with_trace(self, trace, args, params):
# --> 517   return trace.process_primitive(self, args, params)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:1017, in EvalTrace.process_primitive(self, primitive, args, params)
#    1015 args = map(full_lower, args)
#    1016 check_eval_args(args)
# -> 1017 return primitive.impl(*args, **params)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:1875, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1867 donated_argnums = tuple(i for i, d in enumerate(donated_invars) if d)
#    1868 cache_key = pxla.JitGlobalCppCacheKeys(
#    1869     donate_argnums=donated_argnums, donate_argnames=None,
#    1870     device=None, backend=None,
#    (...)   1873     in_layouts_treedef=None, in_layouts_leaves=in_layouts,
#    1874     out_layouts_treedef=None, out_layouts_leaves=out_layouts)
# -> 1875 return xc._xla.pjit(
#    1876     name, f, call_impl_cache_miss, [], [], cache_key,
#    1877     tree_util.dispatch_registry, pxla.cc_shard_arg,
#    1878     _get_cpp_global_cache(cache_key.contains_explicit_attributes))(*args)
#
# KeyboardInterrupt:
