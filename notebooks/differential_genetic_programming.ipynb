# %% [markdown]
# # Control of a stochastic double integrator

# %%
# Specify the cores to use for XLA
import os
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=10'

import jax
import jax.numpy as jnp
import diffrax
import jax.random as jr
import matplotlib.pyplot as plt
from matplotlib.transforms import ScaledTranslation
from jax import Array
from typing import Tuple, Callable
import copy

from kozax.genetic_programming import GeneticProgramming
from neuromorphic_intelligence.kozax_sdi import StochasticDoubleIntegrator
# Out:
# These device(s) are detected:  [CpuDevice(id=0), CpuDevice(id=1), CpuDevice(id=2), CpuDevice(id=3), CpuDevice(id=4), CpuDevice(id=5), CpuDevice(id=6), CpuDevice(id=7), CpuDevice(id=8), CpuDevice(id=9)]

# %%
# set colormap
cmap = plt.get_cmap("tab10")
plt.rcParams["axes.prop_cycle"] = plt.cycler(color=cmap.colors)
plt.rcParams["figure.dpi"] = 200
plt.rcParams["font.size"] = 10
plt.rcParams["text.usetex"] = True
plt.rcParams["axes.labelsize"] = 12
plt.rcParams["axes.titlesize"] = 12
plt.rcParams["legend.fontsize"] = 8
plt.rcParams["xtick.labelsize"] = 10
plt.rcParams["ytick.labelsize"] = 10

# %% [markdown]
# First we generate data, consisting of initial conditions, keys for noise, targets and parameters of the environment.

# %%
def get_data(key, env, batch_size, dt, T, param_setting):
    init_key, noise_key, param_key = jr.split(key, 3)
    x0, targets = env.sample_init_states(batch_size, init_key)
    noise_keys = jr.split(noise_key, batch_size)
    ts = jnp.arange(0, T, dt)

    params = env.sample_params(batch_size, param_setting, ts, param_key)
    
    # initial state of coupled system set to zero; target location always 0.0
    return jnp.zeros_like(x0), ts, jnp.zeros_like(targets), noise_keys, params 

key = jr.PRNGKey(0)
gp_key, data_key = jr.split(key)
batch_size = 16
T = 100
dt = 0.1
param_setting = "Constant"

env = StochasticDoubleIntegrator(process_noise = 0.1, obs_noise = 0.0)

data = get_data(data_key, env, batch_size, dt, T, param_setting)

# %% [markdown]
# The evaluator class parallelizes the simulation of the control loop over the batched data. In each trajectory, a coupled dynamical system is simulated using diffrax, integrating both the dynamic memory and the dynamic environment, defined by the drift and diffusion functions. At every time step, the state of the environment is mapped to observations and the latent memory is mapped to a control signal. Afterwards, the state equation of the memory and environment state is computed. When the simulation is done, the fitness is computed given the control and environment state.

# %%
class Evaluator:
    def __init__(self, env, state_size: int, dt0: float, solver=diffrax.Euler(), max_steps: int = 16**4, stepsize_controller: diffrax.AbstractStepSizeController = diffrax.ConstantStepSize()) -> None:
        """Evaluates dynamic symbolic policies in control tasks.

        Args:
            env: Environment on which the candidate is evaluated.
            state_size: Dimensionality of the hidden state.
            dt0: Initial step size for integration.
            solver: Solver used for integration (default: diffrax.Euler()).
            max_steps: The maximum number of steps that can be used in integration (default: 16**4).
            stepsize_controller: Controller for the stepsize during integration (default: diffrax.ConstantStepSize()).

        Attributes:
            env: Environment on which the candidate is evaluated.
            max_fitness: Max fitness which is assigned when a trajectory returns an invalid value.
            state_size: Dimensionality of the hidden state.
            obs_size: Dimensionality of the observations.
            control_size: Dimensionality of the control.
            latent_size: Dimensionality of the state of the environment.
            dt0: Initial step size for integration.
            solver: Solver used for integration.
            max_steps: The maximum number of steps that can be used in integration.
            stepsize_controller: Controller for the stepsize during integration.
        """
        self.env = env
        self.max_fitness = 1e4
        self.state_size = state_size
        self.obs_size = env.n_obs
        self.control_size = env.n_control_inputs
        self.latent_size = env.n_var*env.n_dim
        self.dt0 = dt0
        self.solver = solver
        self.max_steps = max_steps
        self.stepsize_controller = stepsize_controller

    def __call__(self, candidate: Array, data: Tuple, tree_evaluator: Callable) -> float:
        """Evaluates the candidate on a task.

        Args:
            candidate: The coefficients of the candidate.
            data: The data required to evaluate the candidate.
            tree_evaluator: Function for evaluating trees.

        Returns:
            Fitness of the candidate.
        """
        _, _, _, _, fitness = jax.vmap(self.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(candidate, *data, tree_evaluator)

        fitness = jnp.mean(fitness)
        return fitness
      
    def evaluate_trajectory(self, candidate: Array, x0: Array, ts: Array, target: float, noise_key: jr.PRNGKey, params: Tuple, tree_evaluator: Callable) -> Tuple[Array, Array, Array, Array, float]:
        """Solves the coupled differential equation of the system and controller. 
        The differential equation of the system is defined in the environment and the differential equation 
        of the control is defined by the set of trees.

        Args:
            candidate: Candidate with trees for the hidden state and readout.
            x0: Initial state of the system.
            ts: Time points on which the controller is evaluated.
            target: Target position that the system should reach.
            noise_key: Key to generate noisy observations.
            params: Parameters that define the environment.
            tree_evaluator: Function for evaluating trees.

        Returns:
            States, observations, control, activities of the hidden state of the candidate and the fitness of the candidate.
        """
        env = copy.copy(self.env)
        env.initialize_parameters(params, ts)

        state_equation = candidate[:self.state_size]
        readout = candidate[self.state_size:]
        
        solver = self.solver
        dt0 = self.dt0
        saveat = diffrax.SaveAt(ts=ts)

        process_noise_key, obs_noise_key = jr.split(noise_key, 2)

        # Concatenate the initial state of the system with the initial state of the latent memory
        _x0 = jnp.concatenate([x0, jnp.zeros(self.state_size)])

        brownian_motion = diffrax.UnsafeBrownianPath(shape=(env.n_var,), key=process_noise_key, levy_area=diffrax.SpaceTimeLevyArea) #define process noise
        system = diffrax.MultiTerm(diffrax.ODETerm(self._drift), diffrax.ControlTerm(self._diffusion, brownian_motion))
        
        # Solve the coupled system of the environment and the controller
        # We ignore the learnt initial state and set to zero
        sol = diffrax.diffeqsolve(
            system, solver, ts[0], ts[-1], dt0, jnp.zeros_like(_x0), saveat=saveat, adjoint=diffrax.DirectAdjoint(), max_steps=self.max_steps, event=diffrax.Event(self.env.cond_fn_nan), 
            args=(env, state_equation, readout, obs_noise_key, target, tree_evaluator), stepsize_controller=self.stepsize_controller, throw=False
        )

        xs = sol.ys[:,:self.latent_size]
        # Get observations of the state at every time step
        _, ys = jax.lax.scan(env.f_obs, obs_noise_key, (ts, xs))

        activities = sol.ys[:,self.latent_size:]
        # Get control actions at every time step
        us = jax.vmap(lambda y, a, tar: tree_evaluator(readout, jnp.concatenate([y, a, jnp.zeros(self.control_size), target])), in_axes=[0,0,None])(ys, activities, target)

        # Compute the fitness of the candidate in this trajectory
        fitness = env.fitness_function(xs, us[:,None], target, ts)

        return xs, ys, us, activities, fitness
    
    def _drift(self, t, x_a, args):
        env, state_equation, readout, obs_noise_key, target, tree_evaluator = args
        x = x_a[:self.latent_size]
        a = x_a[self.latent_size:]

        _, y = env.f_obs(obs_noise_key, (t, x)) #Get observations from system
        u = tree_evaluator(readout, jnp.concatenate([jnp.zeros(self.obs_size), a, jnp.zeros(self.control_size), target])) #Compute control action from latent memory

        u = jnp.atleast_1d(u)

        dx = env.drift(t, x, u) #Apply control to system and get system change
        da = tree_evaluator(state_equation, jnp.concatenate([y, a, u, target])) #Compute change in latent memory

        return jnp.concatenate([dx, da])
    
    def _diffusion(self, t, x_a, args):
        env, state_equation, readout, obs_noise_key, target, tree_evaluator = args
        x = x_a[:self.latent_size]
        a = x_a[self.latent_size:]

        return jnp.concatenate([env.diffusion(t, x, jnp.array([0])), jnp.zeros((self.state_size, self.latent_size))]) #Only the system is stochastic

# %% [markdown]
# Here we define the hyperparameters, operators, variables and initialize the strategy. The control policy will consist of two latent variables and a readout layer. `layer_sizes` allows us to define different types of tree, where `variable_list` contains different sets of input variables for each type of tree. The readout layer will only receive the latent states, while the inputs to the state equations consists of the observations, control signal and latent states.

# %%
#Define hyperparameters
population_size = 100 # 100
num_populations = 10 # 10
num_generations = 50
state_size = 2

#Define expressions # UNIVERSAL?
operator_list = [("+", lambda x, y: x + y, 2, 0.5), 
                ("-", lambda x, y: x - y, 2, 0.1),
                ("*", lambda x, y: x * y, 2, 0.5)]

variable_list = [["x" + str(i) for i in range(env.n_obs)] + ["a1", "a2"], ["a1", "a2"]]

layer_sizes = jnp.array([state_size, env.n_control_inputs])

# %%
XS0 =[]
XS = []
FS = []
FBEST = []
STRATS = []

NUM_EXP = 20

for idx in range(NUM_EXP):

    #Define evaluator # SHARK FOR SDE WITH ADDITIVE NOISE!
    fitness_function = Evaluator(env, state_size, dt, solver=diffrax.GeneralShARK(), max_steps=1000)

    #Initialize strategy
    strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, layer_sizes, num_populations = num_populations, size_parsimony=0.003)

    # strategy.fit(gp_key, data, verbose=True)
    
    # Sample the initial population
    key, gp_key = jr.split(jr.PRNGKey(idx))
    population = strategy.initialize_population(gp_key)

    F = []
    F_best = []

    for g in range(num_generations):
        key, eval_key, sample_key = jr.split(key, 3)

        # Evaluate the population on the data, and return the fitness
        fitness, population = strategy.evaluate_population(population, (data), eval_key)

        F.append(-fitness)

        # if (g%5)==0:
        #     print("Generation:", g)
        #     strategy.print_pareto_front()

        # Evolve the population until the last generation. The fitness should be given to the evolve function.
        if g < (num_generations-1):
            population = strategy.evolve_population(population, fitness, sample_key)

    F = jnp.stack(F) # generation, subpopulation_nr, population_size

    F_best = []
    for g in range(num_generations):
        best_fitness, best_solution = strategy.get_statistics(g+1)
        F_best.append(-best_fitness)
        print(f'experiment {idx+1} generation {g+1} best solution: {strategy.expression_to_string(best_solution)}')

    # compute performance on test data

    test_data = get_data(jax.random.PRNGKey(1), env, batch_size, dt, T, param_setting)

    for i in range(num_generations):
        best_fitness, best_solution = strategy.get_statistics(i+1)
        xs, ys, us, activities, fitness = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(best_solution, *test_data, strategy.tree_evaluator)
        F_best[i] = -jnp.mean(fitness)

    # initial solution; store trajectory
    initial_fitness, initial_solution = strategy.get_statistics(1)
    xs0, ys0, us0, activities0, fitness0 = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(initial_solution, *data, strategy.tree_evaluator)
    # print(-jnp.mean(fitness0))

    # final best solution; store trajectory
    final_fitness, final_solution = strategy.get_statistics(num_generations)
    xs, ys, us, activities, fitness = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(best_solution, *data, strategy.tree_evaluator)
    print(f'experiment {idx+1} final best solution: {strategy.expression_to_string(final_solution)}')
    print(f'experiment {idx+1} fitness: {-jnp.mean(fitness)}')

    # store results
    XS0.append(copy.copy(xs0))
    XS.append(copy.copy(xs))
    FS.append(copy.copy(F))
    FBEST.append(copy.copy(F_best))
    STRATS.append(copy.copy(strategy))
# Out:
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2'].
# experiment 1 generation 1 best solution: [x1, (0.66*a1 - a2)*(x0 - 0.373), -1.18*a1]
# experiment 1 generation 2 best solution: [-0.597*x1, a2*(-a1 - 1.29), a1*(a2 + 1.63)]
# experiment 1 generation 3 best solution: [x1, a1**3*(x1 + 0.999), -1.07*a1]
# experiment 1 generation 4 best solution: [x1, a1**3*(x1 + 0.999), -1.07*a1]
# experiment 1 generation 5 best solution: [x1, a1**3*(x1 + 0.999), a1*(2*a2 - 1.07)]
# experiment 1 generation 6 best solution: [x1, a1**3*(x1 + 0.999), a1*(2*a2 - 1.07)]
# experiment 1 generation 7 best solution: [a2 + 0.33*x1, -1.54*a2 - 0.988*x1, a1 + 5.56*a2]
# experiment 1 generation 8 best solution: [a2 + 0.33*x1, -1.54*a2 - 0.988*x1, a1 + 5.56*a2]
# experiment 1 generation 9 best solution: [a2 + 0.33*x1, -1.54*a2 - 0.988*x1, a1 + 5.56*a2]
# experiment 1 generation 10 best solution: [a2 + 0.33*x1, -1.54*a2 - 0.988*x1, a1 + 5.56*a2]
# experiment 1 generation 11 best solution: [a2, -1.54*a2 - 0.988*x1, 0.989*a1 + 1.98*a2]
# experiment 1 generation 12 best solution: [a2 - 0.0498*x1, -1.54*a2 - 0.988*x1, a1 + 3*a2]
# experiment 1 generation 13 best solution: [a2, -1.54*a2 - 0.988*x1, 0.989*a1 + 2.97*a2]
# experiment 1 generation 14 best solution: [a2, -1.54*a2 - 0.988*x1, 0.989*a1 + 2.97*a2]
# experiment 1 generation 15 best solution: [a2, -1.54*a2 - 0.988*x1, 0.989*a1 + 2.97*a2]
# experiment 1 generation 16 best solution: [a2, -1.54*a2 - 0.988*x1, 0.989*a1 + 2.97*a2]
# experiment 1 generation 17 best solution: [a2, -1.54*a2 - 0.988*x1, 0.989*a1 + 2.97*a2]
# experiment 1 generation 18 best solution: [a2, -1.54*a2 - 0.988*x1, 0.989*a1 + 2.97*a2]
# experiment 1 generation 19 best solution: [a2, -1.54*a2 - 0.988*x1, 0.989*a1 + 2.97*a2]
# experiment 1 generation 20 best solution: [a2, -1.54*a2 - 0.988*x1, 0.989*a1 + 2.97*a2]
# experiment 1 generation 21 best solution: [a2, -3.09*a2 - 0.988*x1, 1.98*a1 + 4.94*a2]
# experiment 1 generation 22 best solution: [a2, -3.09*a2 - 0.988*x1, 1.98*a1 + 4.94*a2]
# experiment 1 generation 23 best solution: [a2, -3.09*a2 - 0.988*x1, 1.98*a1 + 4.94*a2]
# experiment 1 generation 24 best solution: [a2, -3.09*a2 - 0.988*x1, 1.98*a1 + 4.94*a2]
# experiment 1 generation 25 best solution: [0.33*a1*a2*x1 + a2, -3.09*a2 - 1.98*x1, a1 + 2*a2]
# experiment 1 generation 26 best solution: [a2, -3.09*a2 - 1.09*x1, 1.98*a1 + 3.95*a2]
# experiment 1 generation 27 best solution: [a2, -3.09*a2 - 1.09*x1, 1.98*a1 + 3.95*a2]
# experiment 1 generation 28 best solution: [a2, -3.09*a2 - 1.09*x1, 1.98*a1 + 3.95*a2]
# experiment 1 generation 29 best solution: [a2, -3.09*a2 - 1.09*x1, 1.98*a1 + 3.95*a2]
# experiment 1 generation 30 best solution: [a2, -3.09*a2 - 1.09*x1, 1.98*a1 + 3.95*a2]
# experiment 1 generation 31 best solution: [a2, -3.09*a2 - 1.09*x1, 1.98*a1 + 3.95*a2]
# experiment 1 generation 32 best solution: [a2, -3.09*a2 - 1.09*x1, 1.98*a1 + 3.95*a2]
# experiment 1 generation 33 best solution: [a2, -3.09*a2 - 1.09*x1, 1.98*a1 + 3.95*a2]
# experiment 1 generation 34 best solution: [a2, -3.09*a2 - 1.09*x1, 1.98*a1 + 3.95*a2]
# experiment 1 generation 35 best solution: [a2, -3.09*a2 - 1.09*x1, 1.98*a1 + 3.95*a2]
# experiment 1 generation 36 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 5*a2]
# experiment 1 generation 37 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 5*a2]
# experiment 1 generation 38 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 5*a2]
# experiment 1 generation 39 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 6*a2]
# experiment 1 generation 40 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 6*a2]
# experiment 1 generation 41 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 6*a2]
# experiment 1 generation 42 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 6*a2]
# experiment 1 generation 43 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 6*a2]
# experiment 1 generation 44 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 6*a2]
# experiment 1 generation 45 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 6*a2]
# experiment 1 generation 46 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 6*a2]
# experiment 1 generation 47 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 6*a2]
# experiment 1 generation 48 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 6*a2]
# experiment 1 generation 49 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 6*a2]
# experiment 1 generation 50 best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 6*a2]
# experiment 1 final best solution: [2*a2, -4.63*a2 - 0.988*x1, 2*a1 + 6*a2]
# experiment 1 fitness: -10.645225524902344
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2'].
# experiment 2 generation 1 best solution: [-0.467*a1 + x1, (-0.328*a1 + x1)*(a2 - 0.26), -0.631*a1 + 3*a2 - 0.0132]
# experiment 2 generation 2 best solution: [a2*(a2 + x0)*(-a1 + x0 + 0.531) + 0.0568, -0.949*a1*(1.02*a2 + x0 + 1.02*x1), 0.951*a2]
# experiment 2 generation 3 best solution: [0.0568, -0.949*a1*(2*a2 + x0 + x1), 2*a2]
# experiment 2 generation 4 best solution: [0.0568, -0.949*a1*(2*a2 + x0 + x1), 2*a2]
# experiment 2 generation 5 best solution: [0.0568, -0.949*a1*(2*a2 + x0 + x1), 2*a2]
# experiment 2 generation 6 best solution: [0.0568, -0.949*a1*(2*a2 + x0 + x1), 2*a2]
# experiment 2 generation 7 best solution: [x1**2 + 0.0568, -0.949*a1*(2*a2 + x0 + x1), 2*a2]
# experiment 2 generation 8 best solution: [x1**2 + 0.0568, -0.949*a1*(2*a2 + x0 + x1), 2*a2]
# experiment 2 generation 9 best solution: [0.114, -0.949*a1*(2*a2 + x0 + x1), 2*a2]
# experiment 2 generation 10 best solution: [a2*x1*(x1 + 0.455) + 0.0568, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, a2*(a2 + 0.124) + 2*a2]
# experiment 2 generation 11 best solution: [a2*x1*(x1 + 0.455) + 0.0568, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, a2*(a2 + 0.124) + 2*a2]
# experiment 2 generation 12 best solution: [a2*x1*(x1 + 0.455) + 0.0568, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, a2*(a2 + 0.124) + 2*a2]
# experiment 2 generation 13 best solution: [a2*x1*(x1 + 0.455) + 0.0568, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, a2*(a2 + 0.124) + 2*a2]
# experiment 2 generation 14 best solution: [a2*x1*(x1 + 0.455) + 0.0568, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 15 best solution: [a2*x1*(x1 + 0.455) + 0.0568, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 16 best solution: [x1*(x1 + 0.455) + 0.0568, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 17 best solution: [x1*(x1 + 0.455) + 0.0568, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 18 best solution: [x1*(x1 + 0.455) + 0.0568, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 19 best solution: [x1*(x1 + 0.455) + 0.0568, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 20 best solution: [x1*(x1 + 0.455) + 0.0568, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 21 best solution: [x1*(x1 + 0.455) + 0.0568, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 22 best solution: [x1*(x1 + 0.455) + 0.0568, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 23 best solution: [a2*x1 + 0.114, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2.01*a2]
# experiment 2 generation 24 best solution: [a2*x1 + 0.114, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2.01*a2]
# experiment 2 generation 25 best solution: [0.0708, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 26 best solution: [0.0708, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 27 best solution: [-a1*x1 + 0.0987, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 28 best solution: [-a1*x1 + 0.0987, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 29 best solution: [-a1*x1 + 0.0987, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 30 best solution: [-a1*x1 + 0.0987, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 31 best solution: [-a1*x1 + 0.0987, -0.949*a1*(2*a2 + x0 + x1) - 0.949*a2 - 0.949*x1, 2*a2]
# experiment 2 generation 32 best solution: [x1*(x1 + 0.0568) + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2.12*a2]
# experiment 2 generation 33 best solution: [x1*(x1 + 0.0568) + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2.12*a2]
# experiment 2 generation 34 best solution: [a1*x1 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 35 best solution: [a1*x1 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 36 best solution: [a1*x1 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 37 best solution: [a1*x1 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 38 best solution: [a1*x1 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 39 best solution: [a1*x1 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 40 best solution: [a1*x1 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 41 best solution: [a1*x1 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 42 best solution: [x1**2 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 43 best solution: [x1**2 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 44 best solution: [x1**2 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 45 best solution: [x1**2 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 46 best solution: [x1**2 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 47 best solution: [x1**2 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 48 best solution: [x1**2 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 49 best solution: [x1**2 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 generation 50 best solution: [x1**2 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 final best solution: [x1**2 + 0.0568, -1.53*a1*(2*a2 + x0 + x1) - 1.53*a2 - 1.53*x1, 2*a2]
# experiment 2 fitness: -10.2365140914917
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2'].
# experiment 3 generation 1 best solution: [a2 + x0 + x1, -1.24*x1, a2]
# experiment 3 generation 2 best solution: [-1.1*x1, 0.500, a1]
# experiment 3 generation 3 best solution: [-1.1*x1, 0.500, a1]
# experiment 3 generation 4 best solution: [(a1 - 1.68)*(2*x1 - 0.00104), -1.45*a1 - 1.45*a2 - 1.45*x0, 0.368*a1**2 + a1 + a2*(a1 + 1.04)]
# experiment 3 generation 5 best solution: [(a1 - 1.68)*(2*x1 - 0.00104), -1.45*a1 - 1.45*a2 - 1.45*x0, 0.368*a1**2 + a1 + a2*(a1 + 1.04)]
# experiment 3 generation 6 best solution: [(a1 - 1.68)*(2*x1 - 0.00104), -1.45*a1 - 1.45*a2 - 1.45*x0, 0.368*a1**2 + a1 + a2*(a1 + 1.04)]
# experiment 3 generation 7 best solution: [(a1 - 1.68)*(2*x1 - 0.00104), -1.45*a1 - 1.45*a2 - 1.45*x0, 0.368*a1**2 + a1 + a2*(a1 + 1.04)]
# experiment 3 generation 8 best solution: [(a1 - 1.68)*(2*x1 - 0.00104), -1.45*a1 - 1.45*a2 - 1.45*x0, 0.368*a1**2 + a1 + a2*(a1 + 1.04)]
# experiment 3 generation 9 best solution: [(a1 - 1.68)*(2*x1 - 0.00104), -1.45*a1 - 1.45*a2 - 1.45*x0, 0.368*a1**2 + a1 + a2*(a1 + 1.04)]
# experiment 3 generation 10 best solution: [(a1 - 1.68)*(2*x1 - 0.00104), -1.45*a1 - 1.45*a2 - 1.45*x0, 0.368*a1**2 + a1 + a2*(a1 + 1.04)]
# experiment 3 generation 11 best solution: [(a1 - 1.68)*(2*x1 - 0.00104), -1.45*a1 - 1.45*a2 - 1.45*x0, 0.368*a1**2 + a1 + a2*(a1 + 1.04)]
# experiment 3 generation 12 best solution: [(a1 - 1.68)*(2*x1 - 0.00104), -1.45*a1 - 1.45*a2 - 1.45*x0, 0.368*a1**2 + a1 + a2*(a1 + 1.04)]
# experiment 3 generation 13 best solution: [(a1 - 1.68)*(2*x1 - 0.00104), -1.45*a1 - 1.45*a2 - 1.45*x0, 0.368*a1**2 + a1 + a2*(a1 + 1.04)]
# experiment 3 generation 14 best solution: [(a1 - 1.68)*(2*x1 - 0.00104), -1.45*a1 - 1.45*a2 - 1.45*x0, 0.368*a1**2 + a1 + a2*(a1 + 1.04)]
# experiment 3 generation 15 best solution: [a1*(-0.375*a1*x0*x1 + a2), -3.18*a2 - 3.18*x0 - 3.18*x1, a2]
# experiment 3 generation 16 best solution: [a1*(-0.375*a1*x0*x1 + a2), -3.18*a2 - 3.18*x0 - 3.18*x1, a2]
# experiment 3 generation 17 best solution: [a1*(-0.375*a1*x0*x1 + a2), -3.18*a2 - 3.18*x0 - 3.18*x1, a2]
# experiment 3 generation 18 best solution: [a1*(-0.375*a1*x0*x1 + a2), -3.18*a2 - 3.18*x0 - 3.18*x1, a2]
# experiment 3 generation 19 best solution: [a1*(a2 - 0.375*x1**2), -3.18*a2 - 3.18*x0 - 3.18*x1, a2]
# experiment 3 generation 20 best solution: [a1*(a2 - 0.141*x1), -6.96*a2 - 6.96*x0 - 6.96*x1, a2]
# experiment 3 generation 21 best solution: [1.10, -6.96*a2 - 6.96*x0 - 6.96*x1, a2]
# experiment 3 generation 22 best solution: [1.10, -6.96*a2 - 6.96*x0 - 6.96*x1, a2]
# experiment 3 generation 23 best solution: [0.375, -6.96*a2 - 6.96*x0 - 6.96*x1, a2]
# experiment 3 generation 24 best solution: [1.10, -15.2*a2 - 15.2*x0 - 15.2*x1, a2]
# experiment 3 generation 25 best solution: [1.10, -15.2*a2 - 15.2*x0 - 15.2*x1, a2]
# experiment 3 generation 26 best solution: [-0.842, -15.2*a2 - 15.2*x0 - 15.2*x1, a2]
# experiment 3 generation 27 best solution: [-0.842, -15.2*a2 - 15.2*x0 - 15.2*x1, a2]
# experiment 3 generation 28 best solution: [-0.842, -15.2*a2 - 15.2*x0 - 15.2*x1, a2]
# experiment 3 generation 29 best solution: [-0.842, -15.2*a2 - 15.2*x0 - 15.2*x1, a2]
# experiment 3 generation 30 best solution: [-1.04, -15.2*a2 - 15.2*x0 - 15.2*x1, a2]
# experiment 3 generation 31 best solution: [-1.04, -15.2*a2 - 15.2*x0 - 15.2*x1, a2]
# experiment 3 generation 32 best solution: [-1.15, -15.2*a2 - 15.2*x0 - 15.2*x1, a2]
# experiment 3 generation 33 best solution: [-1.15, -15.2*a2 - 15.2*x0 - 15.2*x1, a2]
# experiment 3 generation 34 best solution: [-1.15, -15.2*a2 - 15.2*x0 - 15.2*x1, a2]
# experiment 3 generation 35 best solution: [-1.28, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 36 best solution: [-1.28, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 37 best solution: [-1.28, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 38 best solution: [-1.28, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 39 best solution: [-1.28, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 40 best solution: [-1.28, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 41 best solution: [-1.28, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 42 best solution: [-2.22, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 43 best solution: [-2.22, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 44 best solution: [-2.22, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 45 best solution: [-2.22, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 46 best solution: [-2.22, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 47 best solution: [-2.22, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 48 best solution: [-2.22, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 49 best solution: [-2.22, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 generation 50 best solution: [-2.22, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 final best solution: [-2.22, -15.2*a2 - 15.2*x0 - 17.7*x1, a2]
# experiment 3 fitness: -9.967403411865234
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2'].
# experiment 4 generation 1 best solution: [x1*(0.395*a1 - 0.443), a1*(0.833*x1 - 1.6), 2*a1]
# experiment 4 generation 2 best solution: [x1*(a1 - 1.12), a1*(0.833*x1 - 1.6), a1]
# experiment 4 generation 3 best solution: [x1*(a1 + a2 + 2.02), a1**2*(a2*x0 + 0.988*x1), -0.544*a1]
# experiment 4 generation 4 best solution: [x1*(a1 - 1.12), a1*a2, a1]
# experiment 4 generation 5 best solution: [2*x1, -0.486*x0*(a1 + x1), -0.544*a1]
# experiment 4 generation 6 best solution: [2*x1, a1, -0.544*a1]
# experiment 4 generation 7 best solution: [-0.109*a1 - x1, 2*a2, a1*a2 + 1.15*a1 + a2]
# experiment 4 generation 8 best solution: [-0.109*a1 - x1, 2*a2, a1*a2 + 1.15*a1 + a2]
# experiment 4 generation 9 best solution: [-0.109*a1 - x1, 2*a2, a1*a2 + 1.15*a1 + a2]
# experiment 4 generation 10 best solution: [-0.109*a1 - x1, 2*a2, a1*a2 + 1.15*a1 + a2]
# experiment 4 generation 11 best solution: [-0.109*a1 - x1, 2*a2, a1*a2 + 1.15*a1 + a2]
# experiment 4 generation 12 best solution: [-0.109*a1 - x1, a1*(a1 + 0.341), 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 13 best solution: [-0.109*a1 - x1, a1*(a1 + 0.341), 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 14 best solution: [-0.109*a1 - x1, a1*(a1 + 0.341), 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 15 best solution: [-0.109*a1 - x1, a1*(a1 + 0.341), 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 16 best solution: [-0.109*a1 - x1, 0.536*x1, 1.15*a1 - 0.131*a2]
# experiment 4 generation 17 best solution: [-0.109*a1 - x1, 0.536*x1, 1.15*a1 - 0.131*a2]
# experiment 4 generation 18 best solution: [-0.109*a1 - x1, 0.536*x1, 1.15*a1 - 0.131*a2]
# experiment 4 generation 19 best solution: [-0.109*a1 - x1, 0.536*x1, 1.15*a1 - 0.131*a2]
# experiment 4 generation 20 best solution: [-0.109*a1 - x1, 2*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 21 best solution: [-0.109*a1 - x1, 2*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 22 best solution: [-0.109*a1 - x1, 2*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 23 best solution: [-0.109*a1 - x1, 3*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 24 best solution: [-0.109*a1 - x1, 3*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 25 best solution: [-0.109*a1 - x1, 3*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 26 best solution: [-0.109*a1 - x1, 3*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 27 best solution: [-0.109*a1 - x1, 3*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 28 best solution: [-0.109*a1 - x1, 3*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 29 best solution: [-0.109*a1 - x1, 3*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 30 best solution: [-0.109*a1 - x1, 3*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 31 best solution: [-0.109*a1 - x1, 3*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 32 best solution: [-0.109*a1 - x1, 3*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 33 best solution: [-0.109*a1 - x1, 3*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 34 best solution: [-0.109*a1 - x1, 3*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 35 best solution: [-0.109*a1 - x1, 3*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 36 best solution: [-0.109*a1 - x1, 3*a1, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 37 best solution: [-0.109*a1 - x1, x0, 1.15*a1*(-0.647*a1*a2 + 1.06)]
# experiment 4 generation 38 best solution: [-0.109*a1 - x1, x0, 1.15*a1*(-0.647*a1*a2 + 1.06)]
# experiment 4 generation 39 best solution: [-0.109*a1 - x1, a1 - x0, 1.15*a1*(a1*a2 + 1.06)]
# experiment 4 generation 40 best solution: [-0.109*a1 - x1, x1, a1 - 0.131*a2]
# experiment 4 generation 41 best solution: [-0.109*a1 - x1, x1, a1 - 0.131*a2]
# experiment 4 generation 42 best solution: [-0.109*a1 - x1, x1, a1 - 0.131*a2]
# experiment 4 generation 43 best solution: [-0.109*a1 - x1, x1, a1 - 0.131*a2]
# experiment 4 generation 44 best solution: [-0.109*a1 - x1, x1, 1.06*a1 - 0.131*a2]
# experiment 4 generation 45 best solution: [-0.109*a1 - x1, x1, 1.06*a1 - 0.131*a2]
# experiment 4 generation 46 best solution: [-0.109*a1 - x1, x1, 1.06*a1 - 0.131*a2]
# experiment 4 generation 47 best solution: [-0.109*a1 - x1, x1, 1.06*a1 - 0.131*a2]
# experiment 4 generation 48 best solution: [-0.109*a1 - x1, x1, 1.06*a1 - 0.131*a2]
# experiment 4 generation 49 best solution: [-0.109*a1 - x1, -2.25*a2 - 2.25*x1, 1.15*a1*a2 + 1.31*a1 + a2]
# experiment 4 generation 50 best solution: [-0.109*a1 - x1, -2.25*a2 - 2.25*x1, 1.15*a1*a2 + 1.31*a1 + a2]
# experiment 4 final best solution: [-0.109*a1 - x1, -2.25*a2 - 2.25*x1, 1.15*a1*a2 + 1.31*a1 + a2]
# experiment 4 fitness: -13.775388717651367
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2'].
# experiment 5 generation 1 best solution: [-0.689*x1, x0 - 0.606, 1.35*a1]
# experiment 5 generation 2 best solution: [1.56*x1, a1*a2**2 - 0.835*x1, a1**2*(a2 + 0.0761) + 1.15*a2]
# experiment 5 generation 3 best solution: [1.56*x1, a1*a2**2 - 0.835*x1, a1**2*(a2 + 0.0761) + 1.15*a2]
# experiment 5 generation 4 best solution: [2*x1, -0.723*a2*x0**2 - x1, a2]
# experiment 5 generation 5 best solution: [2*x1, -0.723*a2*x0**2 - x1, a2]
# experiment 5 generation 6 best solution: [a1*a2*(-a2 - 1.74) + a1, -1.4*a2*(a1 + 0.019) - 1.4*x1, 0.854*a1*a2 + 0.854*a2]
# experiment 5 generation 7 best solution: [0.0353*a1*x0*x1**2, -1.4*a2*(a1 + 0.019) - 1.4*x1, 0.854*a2]
# experiment 5 generation 8 best solution: [0.0353*a1*x0*x1**2, -1.4*a2*(a1 + 0.019) - 1.4*x1, 0.854*a2]
# experiment 5 generation 9 best solution: [a1**2*a2 + a1, -1.4*a2*(a1 + 0.019) - 1.4*x1, 0.729*a2]
# experiment 5 generation 10 best solution: [-0.307*a1*x0*x1**2, -1.4*a2*(a1 + 0.038) - 1.4*x1, 0.729*a2]
# experiment 5 generation 11 best solution: [-0.307*a1*x0*x1**2, -1.4*a2*(a1 + 0.038) - 1.4*x1, 0.729*a2]
# experiment 5 generation 12 best solution: [-0.307*a1*x0*x1**2, -1.4*a2*(a1 + 0.038) - 1.4*x1, 0.729*a2]
# experiment 5 generation 13 best solution: [x1, -1.4*a1 - 1.4*a2 - 1.4*x1 - 0.0266, 0.729*a2]
# experiment 5 generation 14 best solution: [x1, -1.4*a1 - 1.4*a2 - 1.4*x1 - 0.0266, 0.729*a2]
# experiment 5 generation 15 best solution: [a1*a2 + 0.106*a1*x1, -0.708*a2 + 0.708*x0 + 1.71*x1, -0.0185*a1 - 1.04*a2]
# experiment 5 generation 16 best solution: [a1*(x1 - 0.921), -1.56*a2 + 1.56*x0 + 4.12*x1, -0.776*a2]
# experiment 5 generation 17 best solution: [a1*(x1 - 0.921), -1.56*a2 + 1.56*x0 + 4.12*x1, -0.776*a2]
# experiment 5 generation 18 best solution: [a1*(x1 - 0.921), -1.56*a2 + 1.56*x0 + 4.12*x1, -0.776*a2]
# experiment 5 generation 19 best solution: [a1*(x1 - 0.921), -1.56*a2 + 1.56*x0 + 4.12*x1, -0.776*a2]
# experiment 5 generation 20 best solution: [0.106*a1*x1, -1.42*a2 + 0.708*x0 + 2.42*x1, -0.102*a1*a2**2 - 1.04*a2]
# experiment 5 generation 21 best solution: [0.106*a1*x1, -1.42*a2 + 0.708*x0 + 2.42*x1, -0.102*a1*a2**2 - 1.04*a2]
# experiment 5 generation 22 best solution: [-0.921*a1*x1, -3*a2 + x0 + 4*x1, -1.55*a2]
# experiment 5 generation 23 best solution: [x1, -1.4*a1 - 2.8*a2 - 4.2*x1 - 0.0266, a2]
# experiment 5 generation 24 best solution: [x1, -1.4*a1 - 2.8*a2 - 4.2*x1 - 0.0266, a2]
# experiment 5 generation 25 best solution: [x1, -1.4*a1 - 2.8*a2 - 1.4*x0 - 4.2*x1, a2]
# experiment 5 generation 26 best solution: [-2.64, -2.8*a2 - 1.4*x0 - 2.8*x1, 0.729*a2*(a2 + 0.854) + 0.854*a2]
# experiment 5 generation 27 best solution: [-2.64, -2.8*a2 - 1.4*x0 - 2.8*x1, 0.729*a2*(a2 + 0.854) + 0.854*a2]
# experiment 5 generation 28 best solution: [-2.64, -2.8*a2 - 1.4*x0 - 2.8*x1, 0.729*a2*(a2 + 0.854) + 0.854*a2]
# experiment 5 generation 29 best solution: [-2.64, -2.8*a2 - 1.4*x0 - 2.8*x1, 0.729*a2*(a2 + 0.854) + 0.854*a2]
# experiment 5 generation 30 best solution: [-2.64, -2.8*a2 - 1.4*x0 - 2.8*x1, 0.729*a2*(a2 + 0.854) + 0.854*a2]
# experiment 5 generation 31 best solution: [-2.64, -2.8*a2 - 1.4*x0 - 2.8*x1, 0.729*a2*(a2 + 0.854) + 0.854*a2]
# experiment 5 generation 32 best solution: [-0.115*x1, -4.2*a2 - 2.8*x0 - 2.8*x1, 0.729*a2**3 + 1.58*a2]
# experiment 5 generation 33 best solution: [-0.242*a1**2*a2*x1, -4.2*a2 - 1.4*x0 - 2.8*x1, 1.73*a2]
# experiment 5 generation 34 best solution: [x1, -1.4*a1 - 4.2*a2 - 2.8*x1, 2.31*a2]
# experiment 5 generation 35 best solution: [2.1*a1*a2*(a1 + 0.0133), -4.2*a2 - 1.4*x0 - 2.8*x1, 2*a2]
# experiment 5 generation 36 best solution: [-0.308, -5.6*a2 - 1.4*x0 - 2.8*x1, 0.854*a2*(a2 + 0.854) + 1.71*a2]
# experiment 5 generation 37 best solution: [-0.115*a1, -5.6*a2 - 1.4*x0 - 2.8*x1, 3.04*a2]
# experiment 5 generation 38 best solution: [-0.115*a1, -5.6*a2 - 1.4*x0 - 2.8*x1, 2.71*a2]
# experiment 5 generation 39 best solution: [x1, -5.6*a2 - 1.4*x0 - 2.8*x1, 2.71*a2]
# experiment 5 generation 40 best solution: [x1, -5.6*a2 - 1.4*x0 - 2.8*x1, 2.71*a2]
# experiment 5 generation 41 best solution: [-0.115, -5.6*a2 - 1.4*x0 - 2.8*x1, 2.71*a2]
# experiment 5 generation 42 best solution: [-1.06, -5.6*a2 - 1.4*x0 - 2.8*x1, 2.71*a2]
# experiment 5 generation 43 best solution: [-1.06, -5.6*a2 - 1.4*x0 - 2.8*x1, 2.71*a2]
# experiment 5 generation 44 best solution: [-1.06, -5.6*a2 - 1.4*x0 - 2.8*x1, 2.71*a2]
# experiment 5 generation 45 best solution: [-1.06, -5.6*a2 - 1.4*x0 - 2.8*x1, 2.71*a2]
# experiment 5 generation 46 best solution: [-1.06, -5.6*a2 - 1.4*x0 - 2.8*x1, 2.71*a2]
# experiment 5 generation 47 best solution: [-1.06*a2, -7.0*a2 - 1.4*x0 - 1.4*x1, 4.62*a2]
# experiment 5 generation 48 best solution: [-1.06*a2, -7.0*a2 - 1.4*x0 - 1.4*x1, 4.62*a2]
# experiment 5 generation 49 best solution: [-1.06*a2, -7.0*a2 - 1.4*x0 - 1.4*x1, 4.62*a2]
# experiment 5 generation 50 best solution: [-1.06*a2, -7.0*a2 - 1.4*x0 - 1.4*x1, 4.62*a2]
# experiment 5 final best solution: [-1.06*a2, -7.0*a2 - 1.4*x0 - 1.4*x1, 4.62*a2]
# experiment 5 fitness: -10.53377914428711
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2'].
# experiment 6 generation 1 best solution: [1.51*x0*(2*a2 + x0), 1.25*x1, -1.19*a2]
# experiment 6 generation 2 best solution: [-0.693*x1, 0.39*x1, 1.66*a1 - 0.337*a2]
# experiment 6 generation 3 best solution: [0.131*x1*(0.604*a1 + 0.299), x1*(1.31 - a2), a1**2*a2 + a1 - a2]
# experiment 6 generation 4 best solution: [0.315*x1, -0.318*a2 - 0.0566, -2.89*a1]
# experiment 6 generation 5 best solution: [-0.693*x1, 0, 1.38*a1 - 0.337*a2]
# experiment 6 generation 6 best solution: [0.131*x1*(0.365*a1 + 0.181), x1*(-a2 + x0 + 1.14), 2*a1 - a2]
# experiment 6 generation 7 best solution: [1.48*x1, -0.303, -0.729*a1]
# experiment 6 generation 8 best solution: [1.48*x1, -0.303, -0.729*a1]
# experiment 6 generation 9 best solution: [0.237*x0, -1.07*x1, -0.162*a1**2 + a2]
# experiment 6 generation 10 best solution: [-0.898*x1*(a1 + x0 + 1.12), -0.681*a1 - 0.681*x0 - 1.36*x1, -0.336*a1 + a2]
# experiment 6 generation 11 best solution: [-0.898*x1*(a1 + x0 + 1.12), -0.681*a1 - 0.681*x0 - 1.36*x1, -0.336*a1 + a2]
# experiment 6 generation 12 best solution: [-0.898*x1*(a1 + x0 + 1.12), -0.681*a1 - 0.681*x0 - 1.36*x1, -0.336*a1 + a2]
# experiment 6 generation 13 best solution: [-0.898*x1*(a1 + x0 + 1.12), -0.681*a1 - 0.681*x0 - 1.36*x1, -0.336*a1 + a2]
# experiment 6 generation 14 best solution: [-0.898*x1*(a1 + x0 + 1.12), -0.681*a1 - 0.681*x0 - 1.36*x1, -0.336*a1 + a2]
# experiment 6 generation 15 best solution: [-0.898*x1*(a1 + 0.178), -0.681*a1 - 0.681*a2 - 0.681*x1, 2.34*a1 + a2]
# experiment 6 generation 16 best solution: [-0.898*x1*(a1 + x0 + 1.61), -0.681*a2 - 0.681*x0 - 1.36*x1, -0.336*a1 + a2]
# experiment 6 generation 17 best solution: [-0.898*x1*(a1 + x0 + 1.61), -0.681*a2 - 0.681*x0 - 1.36*x1, -0.336*a1 + a2]
# experiment 6 generation 18 best solution: [-0.898*x1*(a1 + x0 + 1.61), -0.681*a2 - 0.681*x0 - 1.36*x1, -0.336*a1 + a2]
# experiment 6 generation 19 best solution: [-0.898*x1*(a1 + x0 + 1.61), -0.681*a2 - 0.681*x0 - 1.36*x1, -0.336*a1 + a2]
# experiment 6 generation 20 best solution: [-0.898*x1*(a1 + x0 + 1.61), -0.681*a2 - 0.681*x0 - 1.36*x1, -0.336*a1 + a2]
# experiment 6 generation 21 best solution: [0.978*x1, -0.681*a2 - 0.681*x1 + 0.0018, -0.336*a1 + a2]
# experiment 6 generation 22 best solution: [0.978*x1, -0.681*a2 - 0.681*x1 + 0.0018, -0.336*a1 + a2]
# experiment 6 generation 23 best solution: [0.978*x1, -0.681*a2 - 0.681*x1 + 0.0018, -0.336*a1 + a2]
# experiment 6 generation 24 best solution: [x1*(x0 + 0.639), -0.681*a2 - 0.681*x0 - 1.36*x1, 0.271*a1 + a2]
# experiment 6 generation 25 best solution: [-0.898*x1*(0.662 - 0.485*a1), -0.681*a1 - 0.681*a2 - 0.681*x1, 2.34*a1 + a2]
# experiment 6 generation 26 best solution: [0.807*x0, -1.36*a2 - 0.681*x0 - 2.04*x1, a2]
# experiment 6 generation 27 best solution: [-0.898*x0, -1.36*a2 - 0.681*x0 - 2.04*x1, a2]
# experiment 6 generation 28 best solution: [-0.898*x0, -1.36*a2 - 0.681*x0 - 2.04*x1, a2]
# experiment 6 generation 29 best solution: [x1*(x1*(a1 + a2 - x0 + x1) + 0.639), -1.36*a2 - 0.681*x0 - 2.04*x1, -0.336*a1 + a2]
# experiment 6 generation 30 best solution: [x1*(x1*(a1 + a2 - x0 + x1) + 0.639), -2.04*a2 - 0.681*x0 - 1.36*x1, -0.336*a1 + 2*a2]
# experiment 6 generation 31 best solution: [x0, -2.04*a2 - 0.681*x0 - 1.36*x1, 2*a2]
# experiment 6 generation 32 best solution: [x0, -2.04*a2 - 0.681*x0 - 1.36*x1, 2*a2]
# experiment 6 generation 33 best solution: [-0.898*x0*x1*(0.996*x1 + 0.178), (a2 - 1.06)*(3*a2 + x0 + 2*x1), 2*a2]
# experiment 6 generation 34 best solution: [-0.139*x1, (a2 - 1.06)*(3*a2 + x0 + 2*x1), 2*a2]
# experiment 6 generation 35 best solution: [1.44, (a2 - 1.06)*(3*a2 + x0 + 2*x1), 2*a2]
# experiment 6 generation 36 best solution: [0.534, (a2 - 1.06)*(3*a2 + x0 + 2*x1), 2*a2]
# experiment 6 generation 37 best solution: [x0*x1**2*(x0 - 0.155*x1), -9.52*a2 - 3.17*x0 - 6.35*x1, 2*a2]
# experiment 6 generation 38 best solution: [x0*x1**2*(x0 - 0.155*x1), -9.52*a2 - 3.17*x0 - 6.35*x1, 2*a2]
# experiment 6 generation 39 best solution: [0.276*x0**3, -9.52*a2 - 3.17*x0 - 6.35*x1, 2*a2]
# experiment 6 generation 40 best solution: [0.0943, -9.52*a2 - 3.17*x0 - 6.35*x1, 2*a2]
# experiment 6 generation 41 best solution: [0.0943, -9.52*a2 - 3.17*x0 - 6.35*x1, 2*a2]
# experiment 6 generation 42 best solution: [0.0943, -9.52*a2 - 3.17*x0 - 6.35*x1, 2*a2]
# experiment 6 generation 43 best solution: [-0.379, -12.7*a2 - 3.17*x0 - 6.35*x1, 3*a2]
# experiment 6 generation 44 best solution: [x0*x1**2, -9.52*a2 - 3.17*x0 - 3.17*x1, 3*a2]
# experiment 6 generation 45 best solution: [0.0943, -12.7*a2 - 3.17*x0 - 3.17*x1, 4*a2]
# experiment 6 generation 46 best solution: [0.0943, -12.7*a2 - 3.17*x0 - 3.17*x1, 4*a2]
# experiment 6 generation 47 best solution: [0.0943, -12.7*a2 - 3.17*x0 - 3.17*x1, 4*a2]
# experiment 6 generation 48 best solution: [0.0943, -12.7*a2 - 3.17*x0 - 3.17*x1, 4*a2]
# experiment 6 generation 49 best solution: [x0, -15.9*a2 - 3.17*x0 - 3.17*x1, 5*a2]
# experiment 6 generation 50 best solution: [x0, -15.9*a2 - 3.17*x0 - 3.17*x1, 5*a2]
# experiment 6 final best solution: [x0, -15.9*a2 - 3.17*x0 - 3.17*x1, 5*a2]
# experiment 6 fitness: -9.965580940246582
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2'].
# experiment 7 generation 1 best solution: [0.434*a2 - 0.963*x1, a2*(a2 + 2*x0 + x1), a1 + 2.25*a2]
# experiment 7 generation 2 best solution: [0.434*a2 - 0.963*x1, a2*(a2 + 2*x0 + x1), a1 + 2.25*a2]
# experiment 7 generation 3 best solution: [a1**2, a1 - 0.97*x1, a2]
# experiment 7 generation 4 best solution: [0.156*a1**3, -0.0167*a2 - 0.883*x1*(x0 + 1.29), -0.091*a1*a2 + a1 + a2]
# experiment 7 generation 5 best solution: [0.184*a1**2, -0.0167*a2 - 0.883*x1*(x0 + 1.29), a1 + 0.909*a2]
# experiment 7 generation 6 best solution: [0.184*a1**2, -0.0167*a2 - 0.883*x1*(x0 + 1.29), a1 + 0.909*a2]
# experiment 7 generation 7 best solution: [0.184*a1**2, -0.0167*a2 - 0.883*x1*(x0 + 1.29), a1 + 0.909*a2]
# experiment 7 generation 8 best solution: [0.184*a1**2, -0.0167*a2 - 0.883*x1*(x0 + 1.29), a1 + 0.909*a2]
# experiment 7 generation 9 best solution: [0.184*a1**2, -0.0167*a2 - 0.883*x1*(x0 + 1.29), a1 + 0.909*a2]
# experiment 7 generation 10 best solution: [a1*(-x0 - 0.318)*(x1 - 0.574), -0.0167*a2 - 0.883*x1*(x0 + 1.29), 2*a2**2*(a1 - a2) + a2]
# experiment 7 generation 11 best solution: [a1, -0.0167*a2 - 0.883*x1*(x0 + 1.29), 2*a2**2*(a1 - a2) + a2]
# experiment 7 generation 12 best solution: [a1, -0.0167*a2 - 0.883*x1*(x0 + 1.29), 2*a2**2*(a1 - a2) + a2]
# experiment 7 generation 13 best solution: [a1, -0.0167*a2 - 0.883*x1*(x0 + 1.29), 2*a2**2*(a1 - a2) + a2]
# experiment 7 generation 14 best solution: [a1, -0.0167*a2 - 0.883*x1*(x0 + 1.29), a2*(a1 - a2)*(a2 - 0.091) + a2]
# experiment 7 generation 15 best solution: [x0*(2*a1 + 0.591)*(-a1 - x0 + 0.156), a2**2*x0 - 0.883*x1*(x0 + 1.29), 0.481*a1*a2 + a2]
# experiment 7 generation 16 best solution: [0.484*x1**2 - 1.43, -0.0291*a2 + x1, -1.07*a2]
# experiment 7 generation 17 best solution: [0.484*x1**2 - 1.43, -0.0291*a2 + x1, -1.07*a2]
# experiment 7 generation 18 best solution: [x1, -0.0291*a2 + 0.0503*x0*x1 + x1, -1.07*a2]
# experiment 7 generation 19 best solution: [-0.482, -0.0291*a2 + 0.0503*x0*x1 + x1, -1.07*a2]
# experiment 7 generation 20 best solution: [-0.916, -0.0291*a2 + x1, -1.07*a2]
# experiment 7 generation 21 best solution: [1.78, -0.0984*a2 + x1, -1.21*a2]
# experiment 7 generation 22 best solution: [1.78, -0.0984*a2 + x1, -1.21*a2]
# experiment 7 generation 23 best solution: [1.78, -0.0984*a2 + x1, -1.21*a2]
# experiment 7 generation 24 best solution: [1.78, -0.0984*a2 + x1, -1.21*a2]
# experiment 7 generation 25 best solution: [1.78, -0.0984*a2 + x1, -1.21*a2]
# experiment 7 generation 26 best solution: [1.78, -0.0984*a2 + x1, -1.21*a2]
# experiment 7 generation 27 best solution: [1.78, -0.0984*a2 + x1, -1.21*a2]
# experiment 7 generation 28 best solution: [1.78, -0.0984*a2 + x1, -1.21*a2]
# experiment 7 generation 29 best solution: [1.78, -0.0984*a2 + x1, -1.21*a2]
# experiment 7 generation 30 best solution: [0.0972, -0.0984*a2 + x1, -1.21*a2]
# experiment 7 generation 31 best solution: [-0.768, -0.0984*a2 + x1, -1.21*a2]
# experiment 7 generation 32 best solution: [-1.98, -0.0984*a2 + x1, -1.21*a2]
# experiment 7 generation 33 best solution: [-1.98, -0.0984*a2 + x1, -1.21*a2]
# experiment 7 generation 34 best solution: [a2, -0.0984*a2 + x1, -1.27*a2]
# experiment 7 generation 35 best solution: [a2, -0.0984*a2 + x1, -1.27*a2]
# experiment 7 generation 36 best solution: [a2, -0.0984*a2 + x1, -1.27*a2]
# experiment 7 generation 37 best solution: [a1*x0, -0.114*a2 + 0.0503*x0 + x1, -1.07*a2]
# experiment 7 generation 38 best solution: [a1*x0, -0.114*a2 + 0.0503*x0 + x1, -1.07*a2]
# experiment 7 generation 39 best solution: [a1*x0, -0.114*a2 + 0.0503*x0 + x1, -1.07*a2]
# experiment 7 generation 40 best solution: [a1*x0, -0.114*a2 + 0.0503*x0 + x1, -1.07*a2]
# experiment 7 generation 41 best solution: [a1*x0, -0.114*a2 + 0.0503*x0 + x1, -1.07*a2]
# experiment 7 generation 42 best solution: [a1*x0, -0.114*a2 + 0.0503*x0 + x1, -1.07*a2]
# experiment 7 generation 43 best solution: [a1*x0, -0.114*a2 + 0.0503*x0 + x1, -1.07*a2]
# experiment 7 generation 44 best solution: [a1*x0, -0.114*a2 + 0.0503*x0 + x1, -1.07*a2]
# experiment 7 generation 45 best solution: [0.644, -0.114*a2 + 0.0503*x0 + x1, -1.07*a2]
# experiment 7 generation 46 best solution: [0.644, -0.114*a2 + 0.0503*x0 + x1, -1.07*a2]
# experiment 7 generation 47 best solution: [0.644, -0.114*a2 + 0.0503*x0 + x1, -1.07*a2]
# experiment 7 generation 48 best solution: [-1.98, -1.96*a2 + x0 + x1, -1.27*a2]
# experiment 7 generation 49 best solution: [-1.98, -1.96*a2 + x0 + x1, -1.27*a2]
# experiment 7 generation 50 best solution: [-1.98, -1.96*a2 + x0 + x1, -1.27*a2]
# experiment 7 final best solution: [-1.98, -1.96*a2 + x0 + x1, -1.27*a2]
# experiment 7 fitness: -15.064332962036133
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2'].
# experiment 8 generation 1 best solution: [a1*a2, -1.2*x1, a1**2 + a2]
# experiment 8 generation 2 best solution: [a1*a2, -1.2*x1, a1**2 + a2]
# experiment 8 generation 3 best solution: [a2*x0, -7.0*a2 - 3.5*x0 - 3.5*x1, 0.779*a2]
# experiment 8 generation 4 best solution: [a2, -7.0*a2 - 3.5*x0 - 3.5*x1, 0.779*a2]
# experiment 8 generation 5 best solution: [a2*x0, -7.0*a2 - 3.5*x0 - 3.5*x1, 0.869*a2]
# experiment 8 generation 6 best solution: [-0.83*x1, -10.5*a2 - 7.0*x0 - 7.0*x1, 0.779*a2]
# experiment 8 generation 7 best solution: [-1.02*x1, -3.5*a2 - 3.5*x0 - 7.0*x1, 0.779*a2]
# experiment 8 generation 8 best solution: [-0.83*a2*x0, -7.0*a2 - 7.0*x0 - 10.5*x1, 0.779*a2]
# experiment 8 generation 9 best solution: [a2*x0, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.68*a2]
# experiment 8 generation 10 best solution: [a2, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.68*a2]
# experiment 8 generation 11 best solution: [a2, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.52*a2]
# experiment 8 generation 12 best solution: [a2, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.52*a2]
# experiment 8 generation 13 best solution: [0.257, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.52*a2]
# experiment 8 generation 14 best solution: [-0.156, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.52*a2]
# experiment 8 generation 15 best solution: [a2, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.5*a2]
# experiment 8 generation 16 best solution: [a2, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.51*a2]
# experiment 8 generation 17 best solution: [a2, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.51*a2]
# experiment 8 generation 18 best solution: [0.786, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.51*a2]
# experiment 8 generation 19 best solution: [0.786, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.51*a2]
# experiment 8 generation 20 best solution: [-1.02, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.51*a2]
# experiment 8 generation 21 best solution: [-1.02, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.51*a2]
# experiment 8 generation 22 best solution: [-1.02, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.51*a2]
# experiment 8 generation 23 best solution: [-1.02, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.51*a2]
# experiment 8 generation 24 best solution: [-1.02, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.51*a2]
# experiment 8 generation 25 best solution: [-1.02, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.51*a2]
# experiment 8 generation 26 best solution: [a2, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.59*a2]
# experiment 8 generation 27 best solution: [a2, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.59*a2]
# experiment 8 generation 28 best solution: [a2, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.59*a2]
# experiment 8 generation 29 best solution: [a2, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.59*a2]
# experiment 8 generation 30 best solution: [-0.450, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.59*a2]
# experiment 8 generation 31 best solution: [-0.450, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.59*a2]
# experiment 8 generation 32 best solution: [-0.450, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.59*a2]
# experiment 8 generation 33 best solution: [-0.510, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.59*a2]
# experiment 8 generation 34 best solution: [-0.510, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.59*a2]
# experiment 8 generation 35 best solution: [-1.02, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.59*a2]
# experiment 8 generation 36 best solution: [-1.02, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.59*a2]
# experiment 8 generation 37 best solution: [-1.02, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.59*a2]
# experiment 8 generation 38 best solution: [-2.29, -10.5*a2 - 7.0*x0 - 7.0*x1, 1.59*a2]
# experiment 8 generation 39 best solution: [a2, -10.5*a2 - 3.5*x0 - 3.5*x1, 3*a2]
# experiment 8 generation 40 best solution: [a2, -10.5*a2 - 3.5*x0 - 3.5*x1, 3*a2]
# experiment 8 generation 41 best solution: [a2, -10.5*a2 - 3.5*x0 - 3.5*x1, 3*a2]
# experiment 8 generation 42 best solution: [a2, -10.5*a2 - 3.5*x0 - 3.5*x1, 3*a2]
# experiment 8 generation 43 best solution: [a2, -10.5*a2 - 3.5*x0 - 3.5*x1, 3*a2]
# experiment 8 generation 44 best solution: [a2, -10.5*a2 - 3.5*x0 - 3.5*x1, 3*a2]
# experiment 8 generation 45 best solution: [a2, -10.5*a2 - 3.5*x0 - 3.5*x1, 3*a2]
# experiment 8 generation 46 best solution: [a2, -10.5*a2 - 3.5*x0 - 3.5*x1, 3*a2]
# experiment 8 generation 47 best solution: [a2, -10.5*a2 - 3.5*x0 - 3.5*x1, 3*a2]
# experiment 8 generation 48 best solution: [a2, -10.5*a2 - 3.5*x0 - 3.5*x1, 3*a2]
# experiment 8 generation 49 best solution: [a2, -10.5*a2 - 3.5*x0 - 3.5*x1, 3*a2]
# experiment 8 generation 50 best solution: [a2, -10.5*a2 - 3.5*x0 - 3.5*x1, 3*a2]
# experiment 8 final best solution: [a2, -10.5*a2 - 3.5*x0 - 3.5*x1, 3*a2]
# experiment 8 fitness: -10.162786483764648
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2'].
# experiment 9 generation 1 best solution: [-0.447*x1, -0.945*x0, 2.22*a1]
# experiment 9 generation 2 best solution: [a1*(x1 + 0.0569), -0.879*x1, 1.4*a1 + 1.27*a2]
# experiment 9 generation 3 best solution: [a1*(x1 + 0.0569), -0.879*x1, 1.4*a1 + 1.27*a2]
# experiment 9 generation 4 best solution: [a1*(x1 + 0.0569), -0.879*x1, 1.4*a1 + 1.27*a2]
# experiment 9 generation 5 best solution: [-a1 + 0.104*x0 + x1, -0.945*x0, -2.62*a1]
# experiment 9 generation 6 best solution: [-a1 + 0.104*x0 + x1, -0.945*x0, -2.62*a1]
# experiment 9 generation 7 best solution: [-a1 + 0.104*x0 + x1, a1, -2.62*a1]
# experiment 9 generation 8 best solution: [-a1 + 0.104*x0 + x1, a1, -2.62*a1]
# experiment 9 generation 9 best solution: [-a1 + 0.104*x0 + x1, a1, -2.62*a1]
# experiment 9 generation 10 best solution: [-a1 + 0.208*x0 + x1, 2.89*a1 + x1, -2.62*a1]
# experiment 9 generation 11 best solution: [-2*a1 + a2 + 2*x1, x1, 1.08*a1**3 - 2.08*a1]
# experiment 9 generation 12 best solution: [-2*a1 + a2 + 2*x1, x1, 1.08*a1**3 - 2.08*a1]
# experiment 9 generation 13 best solution: [-2*a1 + a2 + 2*x1, x1, 1.08*a1**3 - 2.08*a1]
# experiment 9 generation 14 best solution: [-3*a1 + a2 + 0.104*x0 + 2*x1, x1, -2.83*a1**2 - 2.08*a1]
# experiment 9 generation 15 best solution: [-3*a1 + a2 + 2*x1, x1, 1.08*a1**3 - 2.08*a1]
# experiment 9 generation 16 best solution: [-3*a1 + a2 + 0.104*x0 + 2*x1, x1, -2.02*a1]
# experiment 9 generation 17 best solution: [-3*a1 + a2 + 0.104*x0 + 2*x1, x1, 0.859*a1**3 - 2.08*a1]
# experiment 9 generation 18 best solution: [-3*a1 + a2 + 0.104*x0 + 2*x1, x1, 0.859*a1**3 - 2.08*a1]
# experiment 9 generation 19 best solution: [-3*a1 + a2 + 0.104*x0 + 2*x1, x1, 0.859*a1**3 - 2.08*a1]
# experiment 9 generation 20 best solution: [-3*a1 + 1.1*x0 + 2*x1, -0.440, a1**2 - 2.08*a1]
# experiment 9 generation 21 best solution: [-3*a1 + 1.1*x0 + 2*x1, -0.440, a1**2 - 2.08*a1]
# experiment 9 generation 22 best solution: [-3*a1 + a2 + 0.104*x0 + 2*x1, x1, a1**2 - 2.08*a1]
# experiment 9 generation 23 best solution: [-3*a1 + 1.1*x0 + 2*x1, a2*x1, -2.08*a1]
# experiment 9 generation 24 best solution: [-3*a1 + a2 + 0.104*x0 + 2*x1, x1, -2.08*a1]
# experiment 9 generation 25 best solution: [-3*a1 + a2 + 0.104*x0 + 2*x1, x1, -2.08*a1]
# experiment 9 generation 26 best solution: [-3*a1 + a2 + 0.104*x0 + 2*x1, x1, -2.08*a1]
# experiment 9 generation 27 best solution: [-3*a1 + 1.1*x0 + 2*x1, x1, -2.08*a1]
# experiment 9 generation 28 best solution: [-3*a1 + 1.1*x0 + 2*x1, x1, -2.08*a1]
# experiment 9 generation 29 best solution: [-3*a1 + 1.1*x0 + 2*x1, x1, -2.08*a1]
# experiment 9 generation 30 best solution: [-3*a1 + 1.1*x0 + 2*x1, x1, -2.08*a1]
# experiment 9 generation 31 best solution: [-3*a1 + 1.1*x0 + 2*x1, x1, -2.08*a1]
# experiment 9 generation 32 best solution: [-4*a1 + x0 + 2*x1, a1, -2.62*a1]
# experiment 9 generation 33 best solution: [-5*a1 + x0 + 2*x1, x1, -3.08*a1]
# experiment 9 generation 34 best solution: [-4*a1 + x0 + 1.57*x1, a1 + x1, -3.08*a1]
# experiment 9 generation 35 best solution: [-4*a1 + x0 + 1.57*x1, -0.618, -3.08*a1]
# experiment 9 generation 36 best solution: [-4*a1 + x0 + 1.57*x1, -0.618, -3.08*a1]
# experiment 9 generation 37 best solution: [-4*a1 + x0 + 1.57*x1, -0.618, -3.08*a1]
# experiment 9 generation 38 best solution: [-4*a1 + x0 + 1.57*x1, -0.872, -3.08*a1]
# experiment 9 generation 39 best solution: [-4*a1 + x0 + 1.57*x1, -0.872, -3.08*a1]
# experiment 9 generation 40 best solution: [-4*a1 + x0 + 1.57*x1, -0.872, -3.08*a1]
# experiment 9 generation 41 best solution: [-5*a1 + x0 + 2*x1, 0.893, -3.62*a1]
# experiment 9 generation 42 best solution: [-5*a1 + x0 + 2*x1, 0.893, -3.62*a1]
# experiment 9 generation 43 best solution: [-5*a1 + x0 + 2*x1, 0.0881, -3.62*a1]
# experiment 9 generation 44 best solution: [-5*a1 + x0 + 2*x1, 0.0881, -3.62*a1]
# experiment 9 generation 45 best solution: [-5*a1 + x0 + 2*x1, -1.51, -3.62*a1]
# experiment 9 generation 46 best solution: [-5*a1 + x0 + 2*x1, -1.51, -3.62*a1]
# experiment 9 generation 47 best solution: [-5*a1 + x0 + 2*x1, -1.51, -3.62*a1]
# experiment 9 generation 48 best solution: [-5*a1 + x0 + 2*x1, -1.51, -3.62*a1]
# experiment 9 generation 49 best solution: [-5*a1 + x0 + 2*x1, -1.51, -3.62*a1]
# experiment 9 generation 50 best solution: [-5*a1 + x0 + 2*x1, -1.51, -3.62*a1]
# experiment 9 final best solution: [-5*a1 + x0 + 2*x1, -1.51, -3.62*a1]
# experiment 9 fitness: -10.7404203414917
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2'].
# experiment 10 generation 1 best solution: [x1*(a1 + x0)*(a1 + a2 - 0.297), 1.08*x1, 0.272*a1 - 0.584*a2]
# experiment 10 generation 2 best solution: [x0*x1, -1.23*a2 - 1.23*x0 - 1.63*x1, a1 + a2 + 0.0665]
# experiment 10 generation 3 best solution: [x0*x1, -1.23*a2 - 1.23*x0 - 1.63*x1, a1 + a2 + 0.0665]
# experiment 10 generation 4 best solution: [x1**3*(x0 - 0.0556), -1.23*a2 - 1.23*x0 - 1.63*x1, a2 - 0.0039]
# experiment 10 generation 5 best solution: [-1.93*a1, -1.23*a2 - 1.23*x0 - 1.63*x1, a2 - 0.0039]
# experiment 10 generation 6 best solution: [-1.93*a1*x1**2, -1.23*a2 - 0.942*x0 - 1.63*x1, a2 - 0.0039]
# experiment 10 generation 7 best solution: [-1.93*a1*x1*(x0 - 0.0556), -1.23*a2 - 0.942*x0 - 2.17*x1, a2 + 0.0176]
# experiment 10 generation 8 best solution: [-1.93*x1**3, -2.46*a2 - 1.23*x0 - 3.27*x1, a2 - 0.0039]
# experiment 10 generation 9 best solution: [x1**2, -2.46*a2 - 1.23*x0 - 3.27*x1, a2 - 0.0039]
# experiment 10 generation 10 best solution: [x1**4, -2.46*a2 - 1.23*x0 - 3.27*x1, a2]
# experiment 10 generation 11 best solution: [x0 - 0.0556, -3.69*a2 - 1.23*x0 - 2.17*x1, 2*a2 + 0.0133]
# experiment 10 generation 12 best solution: [-1.93*a1*x1**6, -4.92*a2 - 1.23*x0 - 1.63*x1, 3*a2 + 0.0133]
# experiment 10 generation 13 best solution: [-1.93*a1*x1**6, -4.92*a2 - 1.23*x0 - 1.63*x1, 3*a2 + 0.00664]
# experiment 10 generation 14 best solution: [-1.93*a1*x1**6, -4.92*a2 - 1.23*x0 - 1.63*x1, 3*a2]
# experiment 10 generation 15 best solution: [-1.93*a1**2*x1**5, -4.92*a2 - 1.23*x0 - 1.63*x1, 4*a2]
# experiment 10 generation 16 best solution: [-1.93*x1**4, -4.92*a2 - 1.23*x0 - 1.63*x1, 4*a2]
# experiment 10 generation 17 best solution: [-1.93*x1**4, -4.92*a2 - 1.23*x0 - 1.63*x1, 4*a2]
# experiment 10 generation 18 best solution: [-1.93*x1**4, -4.92*a2 - 1.23*x0 - 1.63*x1, 4*a2]
# experiment 10 generation 19 best solution: [-1.93*x1**4, -4.92*a2 - 1.23*x0 - 1.63*x1, 4*a2]
# experiment 10 generation 20 best solution: [-0.776*x0*x1, -4.92*a2 - 1.23*x0 - 1.63*x1, 4*a2]
# experiment 10 generation 21 best solution: [a1*x1**2, -4.92*a2 - 1.23*x0 - 1.63*x1, 4*a2]
# experiment 10 generation 22 best solution: [-1.93*a1*x1**3, -5.2*a2 - 1.3*x0 - 1.73*x1, 4*a2]
# experiment 10 generation 23 best solution: [-1.93*a1*x1**3, -5.2*a2 - 1.3*x0 - 1.73*x1, 4*a2]
# experiment 10 generation 24 best solution: [3.71*x1**3*(x0*x1 - 0.0556), -4.92*a2 - 1.23*x0 - 1.63*x1, 3.22*a2]
# experiment 10 generation 25 best solution: [3.71*x1**3*(x0*x1 - 0.0556), -4.92*a2 - 1.23*x0 - 1.63*x1, 3.22*a2]
# experiment 10 generation 26 best solution: [-7.16*x1**3, -4.92*a2 - 1.23*x0 - 1.63*x1, 3.22*a2]
# experiment 10 generation 27 best solution: [1.5*x1**2, -6.15*a2 - 1.23*x0 - 1.23*x1, 5*a2]
# experiment 10 generation 28 best solution: [-1.93*x1**2, -6.15*a2 - 1.23*x0 - 1.23*x1, 5*a2]
# experiment 10 generation 29 best solution: [0.936, -5.2*a2 - 1.3*x0 - 1.73*x1, 3.22*a2]
# experiment 10 generation 30 best solution: [0.936, -5.2*a2 - 1.3*x0 - 1.73*x1, 3.22*a2]
# experiment 10 generation 31 best solution: [0.936, -5.2*a2 - 1.3*x0 - 1.73*x1, 3.22*a2]
# experiment 10 generation 32 best solution: [0.936, -5.2*a2 - 1.3*x0 - 1.73*x1, 3.22*a2]
# experiment 10 generation 33 best solution: [0.936, -5.2*a2 - 1.3*x0 - 1.73*x1, 3.22*a2]
# experiment 10 generation 34 best solution: [-0.843, -11.1*a2 - 2.76*x0 - 3.67*x1, 3.39*a2]
# experiment 10 generation 35 best solution: [-0.843, -11.1*a2 - 2.76*x0 - 3.67*x1, 3.39*a2]
# experiment 10 generation 36 best solution: [-0.843, -11.1*a2 - 2.76*x0 - 3.67*x1, 3.39*a2]
# experiment 10 generation 37 best solution: [-0.843, -11.1*a2 - 2.76*x0 - 3.67*x1, 3.39*a2]
# experiment 10 generation 38 best solution: [-0.843, -11.1*a2 - 2.76*x0 - 3.67*x1, 3.39*a2]
# experiment 10 generation 39 best solution: [-0.843, -11.1*a2 - 2.76*x0 - 3.67*x1, 3.39*a2]
# experiment 10 generation 40 best solution: [-0.843, -11.1*a2 - 2.76*x0 - 3.67*x1, 3.39*a2]
# experiment 10 generation 41 best solution: [-0.843, -11.1*a2 - 2.76*x0 - 3.67*x1, 3.39*a2]
# experiment 10 generation 42 best solution: [-1.93, -11.1*a2 - 2.76*x0 - 3.67*x1, 3.39*a2]
# experiment 10 generation 43 best solution: [-1.93, -11.1*a2 - 2.76*x0 - 3.67*x1, 3.39*a2]
# experiment 10 generation 44 best solution: [-1.93, -11.1*a2 - 2.76*x0 - 3.67*x1, 3.39*a2]
# experiment 10 generation 45 best solution: [-1.93, -11.1*a2 - 2.76*x0 - 3.67*x1, 3.39*a2]
# experiment 10 generation 46 best solution: [-1.15, -13.8*a2 - 2.76*x0 - 2.76*x1, 5.39*a2]
# ...
# experiment 17 generation 39 best solution: [-15.2*a1 - 15.2*x0 - 17.2*x1, -0.873, a1]
# experiment 17 generation 40 best solution: [-15.2*a1 - 15.2*x0 - 17.2*x1, -0.873, a1]
# experiment 17 generation 41 best solution: [-15.2*a1 - 15.2*x0 - 17.2*x1, -0.873, a1]
# experiment 17 generation 42 best solution: [-15.2*a1 - 15.2*x0 - 17.2*x1, -0.873, a1]
# experiment 17 generation 43 best solution: [-15.2*a1 - 15.2*x0 - 17.2*x1, -0.873, a1]
# experiment 17 generation 44 best solution: [-15.2*a1 - 15.2*x0 - 17.2*x1, -0.873, a1]
# experiment 17 generation 45 best solution: [-15.2*a1 - 15.2*x0 - 17.2*x1, -0.873, a1]
# experiment 17 generation 46 best solution: [-15.2*a1 - 15.2*x0 - 17.2*x1, -0.873, a1]
# experiment 17 generation 47 best solution: [-15.2*a1 - 15.2*x0 - 17.2*x1, -0.873, a1]
# experiment 17 generation 48 best solution: [-15.2*a1 - 15.2*x0 - 17.2*x1, -0.873, a1]
# experiment 17 generation 49 best solution: [-15.2*a1 - 15.2*x0 - 17.2*x1, -0.873, a1]
# experiment 17 generation 50 best solution: [-15.2*a1 - 15.2*x0 - 17.2*x1, -0.873, a1]
# experiment 17 final best solution: [-15.2*a1 - 15.2*x0 - 17.2*x1, -0.873, a1]
# experiment 17 fitness: -9.954741477966309
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2'].
# experiment 18 generation 1 best solution: [1.18*a2*x1, x1*(0.206*a2*x0*(x0 + x1) + 0.691), a2*(a1 - 1.4)]
# experiment 18 generation 2 best solution: [-a2 - 0.924*x1, -0.563*a2*x0*x1**3, 1.16*a1 + a2]
# experiment 18 generation 3 best solution: [-a2 - 0.924*x1, -0.563*a2*x0*x1**3, 1.16*a1 + a2]
# experiment 18 generation 4 best solution: [-a2 - 0.924*x1, -0.563*a2, 1.16*a1]
# experiment 18 generation 5 best solution: [-a2 - 0.924*x1, -0.563*a2, 1.16*a1]
# experiment 18 generation 6 best solution: [1.63*a1*a2 + 1.84*x1, -0.0136*a1*x0, 0.0744*a1*a2 + a1*(a2 - 0.548)]
# experiment 18 generation 7 best solution: [1.63*a1*a2 + 1.84*x1, -0.0136*a1*x0, 0.0744*a1*a2 + a1*(a2 - 0.548)]
# experiment 18 generation 8 best solution: [-0.0967*a1 + 1.84*x1, -0.0181*x0*x1, a1*(a2 - 0.548) - 0.00598*a1]
# experiment 18 generation 9 best solution: [-1.34*a1 - 1.34*x1, (2*a2 - 0.353)*(a1*a2 + x1), 3*a1 + a2]
# experiment 18 generation 10 best solution: [-1.34*a1 - 1.34*x1, (2*a2 - 0.353)*(a1*a2 + x1), 3*a1 + a2]
# experiment 18 generation 11 best solution: [-1.34*a1 - 1.34*x1, (2*a2 - 0.353)*(a1*a2 + x1), 3*a1 + a2]
# experiment 18 generation 12 best solution: [-1.34*a1 - 1.34*x1, (2*a2 - 0.353)*(a1*a2 + x1), 3*a1 + a2]
# experiment 18 generation 13 best solution: [-1.34*a1 - 1.34*x1, (2*a2 - 0.353)*(a1*a2 + x1), 3*a1 + a2]
# experiment 18 generation 14 best solution: [-1.34*a1 - 1.34*x1, (2*a2 - 0.353)*(a1*a2 + x1), 3*a1 + a2]
# experiment 18 generation 15 best solution: [-1.34*a1 - 1.34*x1, (2*a2 - 0.353)*(a1*a2 + x1), 3*a1 + a2]
# experiment 18 generation 16 best solution: [-1.34*a1 - 1.34*x1, (2*a2 - 0.353)*(a1*a2 + x1), 3*a1 + a2]
# experiment 18 generation 17 best solution: [-1.34*a1 - 1.34*x1, (2*a2 - 0.353)*(a1*a2 + x1), 3*a1 + a2]
# experiment 18 generation 18 best solution: [-1.34*a1 - 1.34*x1, (2*a2 - 0.353)*(0.164*a1*a2 + x1), 2.0*a1 + a2]
# experiment 18 generation 19 best solution: [-1.34*a1 - 1.34*x1, (2*a2 - 0.353)*(0.164*a1*a2 + x1), 2.0*a1 + a2]
# experiment 18 generation 20 best solution: [-1.34*a1 - 1.34*x1, 0.00926*a2*x0 - 0.353*x1, 2*a1 + 2*a2]
# experiment 18 generation 21 best solution: [-1.34*a1 - 1.34*x1, (2*a2 - 0.353)*(a1*a2**2 + x1), a1 + 2*a2]
# experiment 18 generation 22 best solution: [-1.34*a1 - 1.34*x1, 0.00926*a2*x0 - 0.353*x1, a1 + 2*a2]
# experiment 18 generation 23 best solution: [-1.34*a1 - 1.34*x1, 0.00926*a2*x0 - 0.353*x1, a1 + 2*a2]
# experiment 18 generation 24 best solution: [-2.69*a1 - 1.34*x1, (2*a2 - 0.353)*(-0.164*a1*a2 + x1), 3*a1 + 2*a2]
# experiment 18 generation 25 best solution: [-2.69*a1 - 2.69*x1, 0.0204*a1*a2*x0 - 0.353*x1, a1 + 2*a2]
# experiment 18 generation 26 best solution: [-2.69*a1 - 2.69*x1, 0.0204*a1*a2*x0 - 0.353*x1, a1 + 2*a2]
# experiment 18 generation 27 best solution: [-2.69*a1 - 2.69*x1, 0.0204*a1*a2*x0 - 0.353*x1, a1 + 2*a2]
# experiment 18 generation 28 best solution: [-4.03*a1 - 1.34*x1, (0.0578*a1 + x1)*(2*a2 - 0.353), 4*a1 + 2*a2]
# experiment 18 generation 29 best solution: [-6.71*a1 - 2.69*x1, (0.0268*a1**2 + x1)*(a2 - 0.543), 2*a1 + 2*a2]
# experiment 18 generation 30 best solution: [-6.71*a1 - 2.69*x1, (-0.0889*a1**2 + x1)*(a2 - 0.543), 2*a1 + 2*a2]
# experiment 18 generation 31 best solution: [-5.37*a1 - 2.69*x1, 0.125*a2**2*x0*x1 - 0.353*x1, 2*a1 + 3*a2]
# experiment 18 generation 32 best solution: [-6.71*a1 - 2.69*x1, (2*a2 - 0.353)*(a1**2*a2**2 + x1), 3*a1 + 2*a2]
# experiment 18 generation 33 best solution: [-8.05*a1 - 1.34*x1, (a2 - 0.353)*(-0.164*a1*(a2 - 0.353) + x1), 5*a1 + 3*a2]
# experiment 18 generation 34 best solution: [-8.05*a1 - 1.34*x1, (a2 - 0.353)*(-0.164*a1*(a2 - 0.353) + x1), 6*a1 + 2*a2]
# experiment 18 generation 35 best solution: [-8.05*a1 - 1.34*x1, (a2 - 0.353)*(-0.164*a1*a2 + x1), 6*a1 + 2*a2]
# experiment 18 generation 36 best solution: [-8.05*a1 - 1.34*x1, (a2 - 0.353)*(0.353*a1*(a2 - 0.353) + x1), 6*a1 + 2*a2]
# experiment 18 generation 37 best solution: [-8.05*a1 - 1.34*x1, 0.0578*a1*a2 - 0.353*x1, 6*a1 + 2*a2]
# experiment 18 generation 38 best solution: [-8.05*a1 - 1.34*x1, (-0.164*a1 + x1)*(a2 - 0.353), 6*a1 + 2*a2]
# experiment 18 generation 39 best solution: [-8.05*a1 - 1.34*x1, (a2 - 0.353)*(-0.00947*a1*x1 + 1.06*x1), 6*a1 + 2*a2]
# experiment 18 generation 40 best solution: [-8.05*a1 - 1.34*x1, (2*a2 - 0.896)*(-0.353*a1*a2 + x1), 6*a1 + a2]
# experiment 18 generation 41 best solution: [-8.05*a1 - 1.34*x1, (2*a2 - 0.896)*(-0.353*a1*a2 + x1), 6*a1 + a2]
# experiment 18 generation 42 best solution: [-8.05*a1 - 1.34*x1, -0.125*a1*(a2 - 0.353) + 0.353*a1 - 0.353*x1, 6*a1 + 2*a2]
# experiment 18 generation 43 best solution: [-8.05*a1 - 1.34*x1, -0.125*a1*(a2 - 0.353) + 0.353*a1 - 0.353*x1, 6*a1 + 2*a2]
# experiment 18 generation 44 best solution: [-8.05*a1 - 1.34*x1, -0.125*a1*(a2 - 0.353) + 0.353*a1 - 0.353*x1, 6*a1 + 2*a2]
# experiment 18 generation 45 best solution: [-8.05*a1 - 1.34*x1, (0.125*a1 + x1)*(a2 + x0 - 0.896), 6*a1 + a2]
# experiment 18 generation 46 best solution: [-8.05*a1 - 1.34*x1, 0.353*a1 - 0.353*x1, 6*a1 + 2*a2]
# experiment 18 generation 47 best solution: [-8.05*a1 - 1.34*x1, 0.353*a1 - 0.353*x1, 6*a1 + 2*a2]
# experiment 18 generation 48 best solution: [-8.05*a1 - 1.34*x1, 0.353*a1 - 0.353*x1, 6*a1 + 2*a2]
# experiment 18 generation 49 best solution: [-8.05*a1 - 1.34*x1, 0.353*a1 - 0.353*x1, 6*a1 + 2*a2]
# experiment 18 generation 50 best solution: [-8.05*a1 - 1.34*x1, 0.353*a1 - 0.353*x1, 6*a1 + 2*a2]
# experiment 18 final best solution: [-8.05*a1 - 1.34*x1, 0.353*a1 - 0.353*x1, 6*a1 + 2*a2]
# experiment 18 fitness: -10.242036819458008
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2'].
# experiment 19 generation 1 best solution: [-0.443*a2*x0*x1, 0.74*x1, a1 - a2]
# experiment 19 generation 2 best solution: [2*a1*(x0 - 0.255) + a1, 1.96*a2*x1 - x1, -a1 + a2]
# experiment 19 generation 3 best solution: [2*a1*(x0 - 0.255) + a1, 1.96*a2*x1 - x1, a2]
# experiment 19 generation 4 best solution: [-0.336*a1 + x1, x0*x1**2, -2*a1 - 1.59*a2]
# experiment 19 generation 5 best solution: [-0.336*a1 + x1, x0*x1**2, -2*a1 - 1.59*a2]
# experiment 19 generation 6 best solution: [-0.336*a1 + x1, x0*x1**2, a1*a2 - 2*a1 - 1.36*a2]
# experiment 19 generation 7 best solution: [-0.336*a1 + x1, x0*x1**2, a1*a2 - 2*a1 - 1.36*a2]
# experiment 19 generation 8 best solution: [-0.336*a1 + x1, (x0 - 0.315)*(-0.981*x0*x1 + x1), -a1*a2 - a1 + a2]
# experiment 19 generation 9 best solution: [-0.336*a1 + x1, (x0 - 0.315)*(-0.981*x0*x1 + x1), -a1*a2 - a1 + a2]
# experiment 19 generation 10 best solution: [-a1 + x1, x0**2*x1 - x1, -a1 + a2]
# experiment 19 generation 11 best solution: [-a1 + x1, x0**2*x1 - x1, -a1 + a2]
# experiment 19 generation 12 best solution: [-a1 + x1, x0**2*x1 - x1, -a1 + a2]
# experiment 19 generation 13 best solution: [-a1 + x1, x0**2*x1 - x1, -a1 + a2]
# experiment 19 generation 14 best solution: [-1.27*a1 - x1, -1.98*a2*x1**2 - x1, 2*a1 + a2]
# experiment 19 generation 15 best solution: [-1.27*a1 - x1, -1.98*a2*x1**2 - x1, 2*a1 + a2]
# experiment 19 generation 16 best solution: [-2*a1 + x1, x0*x1 - x1, a1*a2**2 - a1 + a2]
# experiment 19 generation 17 best solution: [-2.87*a1 - 2*x1, (x0 - 0.315)*(-0.981*x0*x1 + x1), a1*a2 + 3*a1 + 2*a2]
# experiment 19 generation 18 best solution: [-2.87*a1 - 2*x1, (x0 - 0.315)*(-0.981*x0*x1 + x1), a1*a2 + 3*a1 + 2*a2]
# experiment 19 generation 19 best solution: [-2.27*a1 - x1, a2*x1*(-0.981*x0*x1 - x1) - x1, 3*a1 + a2]
# experiment 19 generation 20 best solution: [-3.21*a1 - x1, -x1, 2*a1 + a2]
# experiment 19 generation 21 best solution: [-4.81*a1 - 2*x1, (x0 - 0.315)*(-0.315*a2*x1 + x1), 2*a1 + 3*a2]
# experiment 19 generation 22 best solution: [-4.81*a1 - 2*x1, (x0 - 0.315)*(-0.315*a2*x1 + x1), 2*a1 + 3*a2]
# experiment 19 generation 23 best solution: [-4.81*a1 - 2*x1, (x0 - 0.315)*(-0.315*a2*x1 + x1), 2*a1 + 3*a2]
# experiment 19 generation 24 best solution: [-4.81*a1 - 2*x1, a2*x1*(0.138 - x1) - x1, 2*a1 + a2]
# experiment 19 generation 25 best solution: [-4.81*a1 - 2*x1, a2*x1*(0.138 - x1) - x1, 2*a1 + a2]
# experiment 19 generation 26 best solution: [-4.81*a1 - 2*x1, (x0 - 0.315)*(x0*x1 + x1), 3*a1 + 3*a2]
# experiment 19 generation 27 best solution: [-4.81*a1 - 2*x1, (x0 - 0.315)*(x0*x1 + x1), 3*a1 + 3*a2]
# experiment 19 generation 28 best solution: [-4.81*a1 - 2*x1, (x0 - 0.315)*(x0*x1 + x1), 3*a1 + 3*a2]
# experiment 19 generation 29 best solution: [-4.81*a1 - 2*x1, -0.862*x1, 2*a1 + a2]
# experiment 19 generation 30 best solution: [-4.81*a1 - 2*x1, -0.862*x1, 2*a1 + a2]
# experiment 19 generation 31 best solution: [-5*a1 + 0.12*a2 + x1, x0*(x0*x1*(x0*x1 - x1) - x1) - x1, -6*a1 + a2]
# experiment 19 generation 32 best solution: [-5*a1 + 0.12*a2 + x1, x1**2*(a2 - x1) - x1, -6*a1 + a2]
# experiment 19 generation 33 best solution: [-7*a1 + x1, x0*x1 - x1, -6*a1 + a2]
# experiment 19 generation 34 best solution: [-7*a1 + x1, x0*x1 - x1, -6*a1 + a2]
# experiment 19 generation 35 best solution: [-7*a1 + x1, x0*x1 - x1, -6*a1 + a2]
# experiment 19 generation 36 best solution: [-12.3*a1 + 6.29*x1, x1, -a1**2 + a1*a2 - 2*a1 - a2]
# experiment 19 generation 37 best solution: [-12.3*a1 + 6.29*x1, x1, -a1**2 + a1*a2 - 2*a1 - a2]
# experiment 19 generation 38 best solution: [-12.3*a1 + 6.29*x1, x1, -a1**2 + a1*a2 - 2*a1 - a2]
# experiment 19 generation 39 best solution: [-12.3*a1 + 6.29*x1, x0*x1**2 - x1, -2*a1 + a2]
# experiment 19 generation 40 best solution: [-12.3*a1 + 6.29*x1, x0*x1**2 - x1, -2*a1 + a2]
# experiment 19 generation 41 best solution: [-12.3*a1 + 6.29*x1, x0*x1**2 - x1, -2*a1 + a2]
# experiment 19 generation 42 best solution: [-12.3*a1 + 6.29*x1, x0*x1**2 - x1, -2*a1 + a2]
# experiment 19 generation 43 best solution: [-12.3*a1 + 6.29*x1, x0*x1**2 - x1, -2*a1 + a2]
# experiment 19 generation 44 best solution: [-12.3*a1 + 6.29*x1, x0*x1**2 - x1, -2*a1 + a2]
# experiment 19 generation 45 best solution: [-12.3*a1 + 6.29*x1, x0*x1**2 - x1, -2*a1 + a2]
# experiment 19 generation 46 best solution: [-12.3*a1 + 6.29*x1, x0*x1**2 - x1, -2*a1 + a2]
# experiment 19 generation 47 best solution: [-12.3*a1 + 6.29*x1, x0*x1**2 - x1, -2*a1 + a2]
# experiment 19 generation 48 best solution: [-12.3*a1 + 6.29*x1, x0*x1**2 - x1, -2*a1 + a2]
# experiment 19 generation 49 best solution: [-12.3*a1 + 6.29*x1, x0*x1**2 - x1, -2*a1 + a2]
# experiment 19 generation 50 best solution: [-12.3*a1 + 6.29*x1, x0*x1**2 - x1, -2*a1 + a2]
# experiment 19 final best solution: [-12.3*a1 + 6.29*x1, x0*x1**2 - x1, -2*a1 + a2]
# experiment 19 fitness: -10.01427173614502
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2'].
# experiment 20 generation 1 best solution: [x0 + x1 + 1.28, x1, -1.73*a2]
# experiment 20 generation 2 best solution: [x0*(x0 + (-a2 + x0)*(x1 - 0.616)) - 1.11, 2*x1, -0.419*a2]
# experiment 20 generation 3 best solution: [x0*(x0 + (-a2 + x0)*(x1 - 0.616)) - 1.11, 2*x1, -0.419*a2]
# experiment 20 generation 4 best solution: [0.816*x1, x0**2*x1, -1.28*a1]
# experiment 20 generation 5 best solution: [0.816*x1, x0**2*x1, -1.28*a1]
# experiment 20 generation 6 best solution: [0.71*x0 - 2*x1 - 0.365, -0.13*a2 + x1, -1.73*a2]
# experiment 20 generation 7 best solution: [(-0.05*a2 - 0.05*x0)*(0.71*x0 - 0.449), -0.13*a2 + x1, -1.73*a2]
# experiment 20 generation 8 best solution: [0.0399*a2 + 0.0399*x0, -0.13*a2 + x1, -1.73*a2]
# experiment 20 generation 9 best solution: [-0.0159, -0.13*a2 + x1, -1.73*a2]
# experiment 20 generation 10 best solution: [-0.0159, -0.13*a2 + x1, -1.73*a2]
# experiment 20 generation 11 best solution: [0.71*x0 - x1 - 2.37, -0.13*a2 + 0.87*x1, -1.73*a2]
# experiment 20 generation 12 best solution: [a2 - 0.612, -0.12*a2 + 2*x1, -0.674*a2]
# experiment 20 generation 13 best solution: [a2 - 0.612, -0.12*a2 + 2*x1, -0.674*a2]
# experiment 20 generation 14 best solution: [x1, -0.12*a2 + 2*x1, -0.674*a2]
# experiment 20 generation 15 best solution: [x1, -0.12*a2 + 2*x1, -0.674*a2]
# experiment 20 generation 16 best solution: [x1, -0.12*a2 + 2*x1, -0.674*a2]
# experiment 20 generation 17 best solution: [x1, -0.12*a2 + 2*x1, -0.674*a2]
# experiment 20 generation 18 best solution: [x1, -0.12*a2 + 2*x1, -0.674*a2]
# experiment 20 generation 19 best solution: [1.15*x0 + 1.15*x1, -1.36*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 20 best solution: [1.15*x0 + 1.15*x1, -1.36*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 21 best solution: [1.15*x0 + 1.15*x1, -1.36*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 22 best solution: [1.15*x0 + 1.15*x1, -1.36*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 23 best solution: [1.15*a2 - 0.702, -1.36*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 24 best solution: [1.15*x1 + 0.201, -1.36*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 25 best solution: [0, -1.48*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 26 best solution: [-0.508, -2.72*a2 + 2*x0 + 2*x1, -1.76*a2]
# experiment 20 generation 27 best solution: [-0.842, -2.72*a2 + 2*x0 + 2*x1, -1.63*a2]
# experiment 20 generation 28 best solution: [-0.842, -2.72*a2 + 2*x0 + 2*x1, -1.63*a2]
# experiment 20 generation 29 best solution: [-0.842, -2.72*a2 + 2*x0 + 2*x1, -1.63*a2]
# experiment 20 generation 30 best solution: [0, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 31 best solution: [-1.11, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 32 best solution: [-1.11, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 33 best solution: [-1.11, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 34 best solution: [-1.11, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 35 best solution: [-1.11, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 36 best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 37 best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 38 best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 39 best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 40 best solution: [-0.606, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 41 best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 42 best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 43 best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 44 best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -1.76*a2]
# experiment 20 generation 45 best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -2.08*a2]
# experiment 20 generation 46 best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -2.08*a2]
# experiment 20 generation 47 best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -2.08*a2]
# experiment 20 generation 48 best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -2.08*a2]
# experiment 20 generation 49 best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -2.08*a2]
# experiment 20 generation 50 best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -2.08*a2]
# experiment 20 final best solution: [-1.97, -2.72*a2 + x0 + 2*x1, -2.08*a2]
# experiment 20 fitness: -11.26388931274414

# %%
# stats for interquartile range; ignore nan values
fdata = jnp.array(FBEST)
q1_learning = jnp.nanpercentile(fdata, 25, axis=0)
q3_learning = jnp.nanpercentile(fdata, 75, axis=0)
median_learning = jnp.nanmedian(fdata, axis=0)

# %%
 # final best solution; store trajectory
final_fitness, final_solution = STRATS[5].get_statistics(num_generations)
xs, ys, us, activities, fitness = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(best_solution, *data, strategy.tree_evaluator)
print(f'experiment {idx+1} final best solution: {strategy.expression_to_string(final_solution)}')
print(f'experiment {idx+1} fitness: {-jnp.mean(fitness)}')
# Out:
# experiment 20 final best solution: [x0, -15.9*a2 - 3.17*x0 - 3.17*x1, 5*a2]
# experiment 20 fitness: -11.26388931274414

# %%
ts = jnp.arange(0, T, dt)

fig, ax = plt.subplots(1, 3, figsize=(12,3.35))

gens = jnp.arange(num_generations)+1
ax[0].fill_between(gens, q1_learning, q3_learning, alpha=0.35)
ax[0].plot(gens, median_learning, color=cmap(0), lw=0.5)
# for i in range(NUM_EXP):
#     ax[0].plot(gens, FBEST[i], color=cmap(0), lw=1)
ax[0].set_ylabel('fitness');
ax[0].set_xlabel('generation')
ax[0].text(0.0, 1.0, '(a)', transform=(
    ax[0].transAxes + ScaledTranslation(-52/72, +7/72, fig.dpi_scale_trans)),
    fontsize='large', va='bottom', fontfamily='serif')

ax[1].plot([0, T], [0.0, 0.0], 'k-', lw=0.5,label='_nolegend_')
ax[1].plot(ts, xs[0,:,0],label='final generation', lw=1)
ax[1].plot(ts, xs0[0,:,0],label='initial generation', lw=1)
ax[1].legend(loc='upper left')
ax[1].set_ylabel('particle position');
ax[1].set_xlabel('time (s)')
ax[1].text(0.0, 1.0, '(b)', transform=(
    ax[1].transAxes + ScaledTranslation(-52/72, +7/72, fig.dpi_scale_trans)),
    fontsize='large', va='bottom', fontfamily='serif')

ax[2].plot([0, T], [0.0, 0.0], 'k-', lw=0.5,label='_nolegend_')
ax[2].plot(ts, xs[0,:,1],label='final generation', lw=1)
ax[2].plot(ts, xs0[0,:,1],label='initial generation', lw=1)
ax[2].legend(loc='upper left')
ax[2].set_ylabel('particle velocity');
ax[2].set_xlabel('time (s)')
ax[2].text(0.0, 1.0, '(c)', transform=(
    ax[2].transAxes + ScaledTranslation(-52/72, +7/72, fig.dpi_scale_trans)),
    fontsize='large', va='bottom', fontfamily='serif')

# ax[0].text(0.0, -1.0, '(d)', transform=(
#     ax[0].transAxes + ScaledTranslation(-32/72, +7/72, fig.dpi_scale_trans)),
#     fontsize='large', va='bottom', fontfamily='serif')

for i in range(3):
    ax[i].margins(x=0)

plt.tight_layout()

plt.savefig('../figures/differential_genetic_programming.pdf', format='pdf')
# Out:
# python(62436) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(62437) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(62438) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(62445) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
# save workspace - strategy cannot be pickled...
import pickle
with open('differential_genetic_programming_repeated_workspace.pkl', 'wb') as f:
    pickle.dump({
        'XS0': XS0,
        'XS': XS,
        'FS': FS,
        'FBEST': FBEST,
        'xs' : xs,
        'ys' : ys,
        'us' : us,
        'activities' : activities,
        'mean_fitness' : -jnp.mean(fitness),
        'final_solution_str' : strategy.expression_to_string(final_solution),
    }, f)
