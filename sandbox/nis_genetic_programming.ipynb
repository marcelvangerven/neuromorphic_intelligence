# %% [markdown]
# # Stochastic double integrator example
#
# In this example, we show GP-based control of a stochatic double integrator.

# %%
# Specify the cores to use for XLA
import os
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=10'

import jax
import jax.numpy as jnp
import diffrax
import jax.random as jr
import matplotlib.pyplot as plt
from jax import Array
from typing import Tuple, Callable
import copy

from kozax.genetic_programming import GeneticProgramming
# from kozax.environments.control_environments.acrobot import Acrobot
# from kozax.environments.control_environments.harmonic_oscillator import HarmonicOscillator
from neuromorphic_intelligence.kozax_sdi import StochasticDoubleIntegrator
# Out:
# These device(s) are detected:  [CpuDevice(id=0), CpuDevice(id=1), CpuDevice(id=2), CpuDevice(id=3), CpuDevice(id=4), CpuDevice(id=5), CpuDevice(id=6), CpuDevice(id=7), CpuDevice(id=8), CpuDevice(id=9)]

# %% [markdown]
# Simulation used for the DGP example picture

# %%
from diffrax import diffeqsolve, ODETerm, Dopri5
import jax.numpy as jnp
import matplotlib.pyplot as plt
from diffrax import CubicInterpolation, backward_hermite_coefficients

def obs(t):
    k = jax.random.fold_in(jr.PRNGKey(0), jnp.int32(t * 1000.0))  # Unique key for each time step
    return 0.1 * jax.random.normal(k)

ts = jnp.linspace(0, 10, 200)
coeffs = backward_hermite_coefficients(ts, jax.vmap(obs)(ts))
fy = CubicInterpolation(ts, coeffs)

def f(t, x, args):
    return -1 * x + args.evaluate(t)

term = ODETerm(f)
solver = Dopri5()
x0 = jnp.array(0.0)
sol = diffeqsolve(term, solver, t0=0, t1=10, dt0=0.01, y0=x0, saveat=diffrax.SaveAt(ts=ts), args=fy)

plt.figure(figsize=(10, 5))
plt.plot(sol.ts, sol.ys, color='black', linewidth=2)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()

plt.savefig('../figures/timeseries.pdf', format='pdf')
plt.savefig('../figures/timeseries.png', format='png', dpi=300, transparent=True)

# %% [markdown]
# First we generate data, consisting of initial conditions, keys for noise, targets and parameters of the environment.

# %%
def get_data(key, env, batch_size, dt, T, param_setting):
    init_key, noise_key2, param_key = jr.split(key, 3)
    x0, targets = env.sample_init_states(batch_size, init_key)
    obs_noise_keys = jr.split(noise_key2, batch_size)
    ts = jnp.arange(0, T, dt)

    params = env.sample_params(batch_size, param_setting, ts, param_key)
    return x0, ts, targets, obs_noise_keys, params

key = jr.PRNGKey(0)
gp_key, data_key = jr.split(key)
batch_size = 8
T = 30
dt = 0.05 # NOTE: using the same parameters as in the Neuromorphic paper
param_setting = "Constant"

env = StochasticDoubleIntegrator()

data = get_data(data_key, env, batch_size, dt, T, param_setting)

# %% [markdown]
# The evaluator class parallelizes the simulation of the control loop over the batched data. In each trajectory, a coupled dynamical system is simulated using diffrax, integrating both the dynamic memory and the dynamic environment. At every time step, the state of the environment is mapped to an observations and the latent memory is mapped to a control signal. Afterwards, the state equation of the memory and environment state is computed. When the simulation is done, the fitness is computed given the control and environment state.

# %%
class Evaluator:
    def __init__(self, env, state_size: int, dt0: float, solver=diffrax.Euler(), max_steps: int = 16**4, stepsize_controller: diffrax.AbstractStepSizeController = diffrax.ConstantStepSize()) -> None:
        """Evaluates dynamic symbolic policies in control tasks.

        Args:
            env: Environment on which the candidate is evaluated.
            state_size: Dimensionality of the hidden state.
            dt0: Initial step size for integration.
            solver: Solver used for integration (default: diffrax.Euler()).
            max_steps: The maximum number of steps that can be used in integration (default: 16**4).
            stepsize_controller: Controller for the stepsize during integration (default: diffrax.ConstantStepSize()).

        Attributes:
            env: Environment on which the candidate is evaluated.
            max_fitness: Max fitness which is assigned when a trajectory returns an invalid value.
            state_size: Dimensionality of the hidden state.
            obs_size: Dimensionality of the observations.
            control_size: Dimensionality of the control.
            latent_size: Dimensionality of the state of the environment.
            dt0: Initial step size for integration.
            solver: Solver used for integration.
            max_steps: The maximum number of steps that can be used in integration.
            stepsize_controller: Controller for the stepsize during integration.
        """
        self.env = env
        self.max_fitness = 1e4
        self.state_size = state_size
        self.obs_size = env.n_obs
        self.control_size = env.n_control_inputs
        self.latent_size = env.n_var*env.n_dim
        self.dt0 = dt0
        self.solver = solver
        self.max_steps = max_steps
        self.stepsize_controller = stepsize_controller

    def __call__(self, candidate: Array, data: Tuple, tree_evaluator: Callable) -> float:
        """Evaluates the candidate on a task.

        Args:
            candidate: The coefficients of the candidate.
            data: The data required to evaluate the candidate.
            tree_evaluator: Function for evaluating trees.

        Returns:
            Fitness of the candidate.
        """
        _, _, _, _, fitness = jax.vmap(self.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(candidate, *data, tree_evaluator)

        fitness = jnp.mean(fitness)
        return fitness
      
    def evaluate_trajectory(self, candidate: Array, x0: Array, ts: Array, target: float, obs_noise_key: jr.PRNGKey, params: Tuple, tree_evaluator: Callable) -> Tuple[Array, Array, Array, Array, float]:
        """Solves the coupled differential equation of the system and controller. 
        The differential equation of the system is defined in the environment and the differential equation 
        of the control is defined by the set of trees.

        Args:
            candidate: Candidate with trees for the hidden state and readout.
            x0: Initial state of the system.
            ts: Time points on which the controller is evaluated.
            target: Target position that the system should reach.
            obs_noise_key: Key to generate noisy observations.
            params: Parameters that define the environment.
            tree_evaluator: Function for evaluating trees.

        Returns:
            States, observations, control, activities of the hidden state of the candidate and the fitness of the candidate.
        """
        env = copy.copy(self.env)
        env.initialize_parameters(params, ts)

        state_equation = candidate[:self.state_size]
        readout = candidate[self.state_size:]
        
        solver = self.solver
        dt0 = self.dt0
        saveat = diffrax.SaveAt(ts=ts)

        # Concatenate the initial state of the system with the initial state of the latent memory
        _x0 = jnp.concatenate([jnp.atleast_1d(x0), jnp.atleast_1d(jnp.zeros(self.state_size))])

        system = diffrax.ODETerm(self._drift)
        
        # Solve the coupled system of the environment and the controller
        sol = diffrax.diffeqsolve(
            system, solver, ts[0], ts[-1], dt0, _x0, saveat=saveat, adjoint=diffrax.DirectAdjoint(), max_steps=self.max_steps, event=diffrax.Event(self.env.cond_fn_nan), 
            args=(env, state_equation, readout, obs_noise_key, target, tree_evaluator), stepsize_controller=self.stepsize_controller, throw=False
        )

        xs = sol.ys[:,:self.latent_size]
        # Get observations of the state at every time step
        _, ys = jax.lax.scan(env.f_obs, obs_noise_key, (ts, xs))

        activities = sol.ys[:,self.latent_size:]
        # Get control actions at every time step
        us = jax.vmap(lambda y, a, tar: tree_evaluator(readout, jnp.concatenate([y, a, jnp.zeros(self.control_size), target])), in_axes=[0,0,None])(ys, activities, target)

        # Compute the fitness of the candidate in this trajectory
        fitness = env.fitness_function(xs, us[:,None], target, ts)

        return xs, ys, us, activities, fitness
    
    def _drift(self, t, x_a, args):
        env, state_equation, readout, obs_noise_key, target, tree_evaluator = args
        x = x_a[:self.latent_size]
        a = x_a[self.latent_size:]

        _, y = env.f_obs(obs_noise_key, (t, x)) #Get observations from system
        u = tree_evaluator(readout, jnp.concatenate([jnp.zeros(self.obs_size), a, jnp.zeros(self.control_size), target])) #Compute control action from latent memory

        u = jnp.atleast_1d(u)

        dx = env.drift(t, x, u) #Apply control to system and get system change
        da = tree_evaluator(state_equation, jnp.concatenate([y, a, u, target])) #Compute change in latent memory

        return jnp.concatenate([jnp.atleast_1d(dx), jnp.atleast_1d(da)])

# %% [markdown]
# Here we define the hyperparameters, operators, variables and initialize the strategy. The control policy will consist of two latent variables and a readout layer. `layer_sizes` allows us to define different types of tree, where `variable_list` contains different sets of input variables for each type of tree. The readout layer will only receive the latent states, while the inputs to the state equations consists of the observations, control signal and latent states.

# %%
#Define hyperparameters
population_size = 100
num_populations = 10
num_generations = 50
state_size = 1

#Define expressions NOTE: Logical basis? Also see Boolean networks, Scheffer stroke, etc.; also look into circuit design etc
operator_list = [("+", lambda x, y: x + y, 2, 0.5),
                ("-", lambda x, y: x - y, 2, 0.1),
                ("*", lambda x, y: x * y, 2, 0.5),
                ("sigma", lambda x: jax.nn.sigmoid(x), 1, 0.1)]

variable_list = [["x" + str(i) for i in range(env.n_obs)] + ["a1", "a2", "u"], ["a1", "a2"]]

layer_sizes = jnp.array([state_size, env.n_control_inputs])

#Define evaluator
fitness_function = Evaluator(env, state_size, dt, solver=diffrax.Dopri5(), stepsize_controller=diffrax.PIDController(atol=1e-4, rtol=1e-4, dtmin=0.001), max_steps=1000)

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, layer_sizes, num_populations = num_populations, size_parsimony=0.003)

res = strategy.fit(gp_key, data, verbose=True)
# Out:
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2', 'u'].
# In generation 1, best fitness = 1470.4169, best solution = [sigma(u*x1) - 1.84, 0.00121]
# In generation 2, best fitness = 1470.4078, best solution = [-0.0858*x1, 0.00121]
# In generation 3, best fitness = 1470.4019, best solution = [0.0749, 0.00121]
# In generation 4, best fitness = 1470.4019, best solution = [-2.59, 0.00121]
# In generation 5, best fitness = 1467.9685, best solution = [2*sigma(x1) - 1.49, 0.00517*a2 + 0.00517*sigma(a1*(a2 + sigma(a1*a2)))]
# In generation 6, best fitness = 1111.2788, best solution = [u, 0.00517*a2 + 0.00517*sigma(a1*(a2 + sigma(a1*a2)))]
# In generation 7, best fitness = 1087.8528, best solution = [u, 0.00517*sigma(a1 + a2) + 2.67e-5]
# In generation 8, best fitness = 1072.1272, best solution = [u + sigma(x1) - 1.49, 0.00517*a2 + 0.00517*sigma(a1*(a2 + sigma(a1*a2)))]
# In generation 9, best fitness = 1070.6853, best solution = [u - 1.49, 0.00517*a2 + 0.00517*sigma(a1*a2 + a1 + sigma(a1*a2))]
# In generation 10, best fitness = 1035.9739, best solution = [a1 + 2*u - 1.49, 0.00517*a2 + 0.00517*sigma(a1*(2*a2 + 0.567))]
# In generation 11, best fitness = 1007.6164, best solution = [u + sigma(u*x1) + 0.492, a1*(a2 + 0.000279) + a2 + 0.000228]
# In generation 12, best fitness = 1007.6164, best solution = [u + sigma(u*x1) + 0.492, a1*(a2 + 0.000279) + a2 + 0.000228]
# In generation 13, best fitness = 1007.6164, best solution = [u + sigma(u*x1) + 0.492, a1*(a2 + 0.000279) + a2 + 0.000228]
# In generation 14, best fitness = 1007.6164, best solution = [u + sigma(u*x1) + 0.492, a1*(a2 + 0.000279) + a2 + 0.000228]
# In generation 15, best fitness = 1007.6164, best solution = [u + sigma(u*x1) + 0.492, a1*(a2 + 0.000279) + a2 + 0.000228]
# In generation 16, best fitness = 925.5047, best solution = [u + sigma(x1) + sigma(u*x1) - 0.492, a1*(a2 + 0.000279) + a2 + 0.000228]
# In generation 17, best fitness = 925.5047, best solution = [u + sigma(x1) + sigma(u*x1) - 0.492, a1*(a2 + 0.000279) + a2 + 0.000228]
# In generation 18, best fitness = 912.2836, best solution = [a2 + u + x0, a1*(2*a2 + 0.000279) + a2 + 0.00121]
# In generation 19, best fitness = 895.2005, best solution = [u + sigma(x1) + sigma(u + x1) - 0.492, a1*(a2 + 0.000279) + a2 + 0.000228]
# In generation 20, best fitness = 895.2005, best solution = [u + sigma(x1) + sigma(u + x1) - 0.492, a1*(a2 + 0.000279) + a2 + 0.000228]
# In generation 21, best fitness = 867.8317, best solution = [u + sigma(u) + sigma(x1) - 0.994, a1*(a2 + 0.000279) + a2]
# In generation 22, best fitness = 864.9966, best solution = [u + sigma(u) - 0.492, a1*(a2 + 0.000279) + 2*a2 + 0.000228]
# In generation 23, best fitness = 864.9966, best solution = [u + sigma(u) - 0.492, a1*(a2 + 0.000279) + 2*a2 + 0.000228]
# In generation 24, best fitness = 853.9409, best solution = [1.49*u, a1*(a2 + 0.000279) + a2 + 0.000228]
# In generation 25, best fitness = 853.9409, best solution = [1.49*u, a1*(a2 + 0.000279) + a2 + 0.000228]
# In generation 26, best fitness = 853.9409, best solution = [1.49*u, a1*(a2 + 0.000279) + a2 + 0.000228]
# In generation 27, best fitness = 850.2272, best solution = [1.73*u - 0.232, a1*(3*a2 + 0.000228) - a2 + 0.000228]
# In generation 28, best fitness = 850.2272, best solution = [1.73*u - 0.232, a1*(3*a2 + 0.000228) - a2 + 0.000228]
# In generation 29, best fitness = 850.2272, best solution = [1.73*u - 0.232, a1*(3*a2 + 0.000228) - a2 + 0.000228]
# In generation 30, best fitness = 850.2272, best solution = [1.73*u - 0.232, a1*(3*a2 + 0.000228) - a2 + 0.000228]
# In generation 31, best fitness = 850.2272, best solution = [1.73*u - 0.232, a1*(3*a2 + 0.000228) - a2 + 0.000228]
# In generation 32, best fitness = 850.2272, best solution = [1.73*u - 0.232, a1*(3*a2 + 0.000228) - a2 + 0.000228]
# In generation 33, best fitness = 849.6658, best solution = [1.62*u - 0.472, a1*(0.000228 - a2) + 0.000684]
# In generation 34, best fitness = 847.4353, best solution = [1.73*u - 0.232, a1*(a2 + 0.000228) + 2*a2 + 0.000684]
# In generation 35, best fitness = 847.4353, best solution = [1.73*u - 0.232, a1*(a2 + 0.000228) + 2*a2 + 0.000684]
# In generation 36, best fitness = 847.4353, best solution = [1.73*u - 0.232, a1*(a2 + 0.000228) + 2*a2 + 0.000684]
# In generation 37, best fitness = 847.4353, best solution = [1.73*u - 0.232, a1*(a2 + 0.000228) + 2*a2 + 0.000684]
# In generation 38, best fitness = 847.4353, best solution = [1.73*u - 0.232, a1*(a2 + 0.000228) + 2*a2 + 0.000684]
# In generation 39, best fitness = 847.1532, best solution = [1.73*u - 0.247, a1*(a2 + 0.000228) + 2*a2 + 0.000684]
# In generation 40, best fitness = 847.1532, best solution = [1.73*u - 0.247, a1*(a2 + 0.000228) + 2*a2 + 0.000684]
# In generation 41, best fitness = 847.1532, best solution = [1.73*u - 0.247, a1*(a2 + 0.000228) + 2*a2 + 0.000684]
# In generation 42, best fitness = 847.1412, best solution = [1.73*u - 0.247, a1*(3*a2 + 0.000228) + 0.000684]
# In generation 43, best fitness = 845.4095, best solution = [u + sigma(u - 1.37) + sigma(u - 0.932) - 0.985, a1*(2*a2 + 0.000279) + 0.00121]
# In generation 44, best fitness = 843.1419, best solution = [u + sigma(u) + sigma(u + x1) - 1.48, a1*(2*a2 + 0.000279) + a2 + 0.00144]
# In generation 45, best fitness = 843.1419, best solution = [u + sigma(u) + sigma(u + x1) - 1.48, a1*(2*a2 + 0.000279) + a2 + 0.00144]
# In generation 46, best fitness = 841.8529, best solution = [u + sigma(u) + sigma(u + x1 - 0.932) - 1.42, a1*(2*a2 + 0.000279) + 2*a2 + 0.00149]
# In generation 47, best fitness = 841.8529, best solution = [u + sigma(u) + sigma(u + x1 - 0.932) - 1.42, a1*(2*a2 + 0.000279) + 2*a2 + 0.00149]
# In generation 48, best fitness = 840.5562, best solution = [u + sigma(u) + sigma(u - 0.932) - 1.48, a1*(2*a2 + 0.000279) + a2 + 0.00171]
# In generation 49, best fitness = 840.5562, best solution = [u + sigma(u) + sigma(u - 0.932) - 1.48, a1*(2*a2 + 0.000279) + a2 + 0.00171]
# In generation 50, best fitness = 840.5562, best solution = [u + sigma(u) + sigma(u - 0.932) - 1.48, a1*(2*a2 + 0.000279) + a2 + 0.00171]
# Complexity: 2, fitness: 1470.098388671875, equations: [-1.65, 0.00152]
# Complexity: 6, fitness: 869.70361328125, equations: [2*u, 0.000228*a1]
# Complexity: 8, fitness: 853.6906127929688, equations: [1.49*u, 0.000279*a1]
# Complexity: 12, fitness: 852.3220825195312, equations: [1.49*u - 0.492*x1, a1*(a2 + 0.000279)]
# Complexity: 16, fitness: 846.12158203125, equations: [1.49*u - 0.492*x0, a1*(a2 + 0.000279) + a2 + 0.000228]
# Complexity: 18, fitness: 844.7380981445312, equations: [1.49*u - 0.492*x0 - 0.0807, a1*(a2 + 0.000279) + a2 + 0.000228]
# Complexity: 24, fitness: 841.2377319335938, equations: [u + sigma(u) + sigma(u - 0.932) - 1.42, a1*(2*a2 + 0.000279) + a2 + 0.00171]
# Complexity: 26, fitness: 840.972412109375, equations: [u + 2*sigma(u - 0.932) - 1.42, a1*(2*a2 + 0.000279) + a2 + 0.00171]

# %% [markdown]
# ## Plot convergence

# %%
plt.plot(strategy.best_fitnesses)

# %% [markdown]
# ## Visualize best solution

# %%
#Generate test_data
data = get_data(jr.PRNGKey(10), env, 1, 0.01, 300, param_setting) # Note: we test on a longer trajectory
x0s, ts, _, _, params = data

best_candidate = strategy.pareto_front[1][21]

xs, ys, us, activities, fitness = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(best_candidate, *data, strategy.tree_evaluator)

# %%
plt.figure()
plt.plot(ts, xs[0,:,:])
plt.figure()
plt.plot(ts, ys[0,:,:])
plt.figure()
plt.plot(ts, us[0,:])

# %% [markdown]
# To do:
# - analytical solution bound?
# - evol strat? or just mention?
# - kozax; optimize fitness function (rl); learning to learn
# - automate solution visualisation?
# - automate latex generation?
# - use minus(x,y) etc instead of x minus y (tree representation)
