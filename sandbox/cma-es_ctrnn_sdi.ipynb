# %% [markdown]
# CMA-ES on CTRNN_SDI

# %%
import jax
import jax.numpy as jnp
import jax.random as jr
import diffrax as dfx
import equinox as eqx
from oua.oua import OUAModel
from neuromorphic_intelligence.models import StochasticDoubleIntegrator, CTRNN, CoupledSystem
import matplotlib.pyplot as plt
from matplotlib.transforms import ScaledTranslation
from evosax.problems.problem import Problem, State
from functools import partial
from evosax.types import Fitness, Metrics, Population, Solution

# %%
class CTRNNSDIProblem(Problem):

    @partial(jax.jit, static_argnames=("self",))
    def init(self, key: jax.Array) -> State:
        """Initialize state."""
        return State(counter=0)

    @partial(jax.jit, static_argnames=("self",))
    def eval(
        self,
        key: jax.Array,
        solutions: Population,
        state: State,
    ) -> tuple[Fitness, State, Metrics]:
        """Evaluate a batch of solutions."""

        param_rate, noise_rate, mean_rate, reward_rate = solutions

        agent = CTRNN(num_inputs=2, num_neurons=2, num_outputs=1, noise_scale=0.0)
        env = StochasticDoubleIntegrator(mass=1.0, damping_factor=0.5, noise_scale=0.1)
        coupled_system = CoupledSystem(agent=agent, env=env)
        system = OUAModel(model=coupled_system, param_rate=param_rate, noise_rate=noise_rate, mean_rate=mean_rate, reward_rate=reward_rate)

        def reward(t, x, args):
            (agent_state, env_state), agent_params, agent_means, avg_reward = x
            position, velocity = env_state
            tau, A, bias, B, C = agent_params
            u = jax.nn.tanh(jnp.squeeze(C @ agent_state))
            return -0.9 * jnp.linalg.norm(position)**2 - 0.1 * jnp.linalg.norm(u)**2

        def custom_output(t, x, args):
            return x, args['reward'](t, x, args)

        args = {'reward': reward}

        system = OUAModel(model=coupled_system, param_rate=param_rate, noise_rate=0.0, mean_rate=mean_rate, reward_rate=reward_rate)

        key, = jr.split(key, 1)
        sol = dfx.diffeqsolve(system.terms(key), dfx.EulerHeun(), args=args, t0=0, t1=300, dt0=0.01, y0=system.initial, saveat=dfx.SaveAt(steps=True, fn=custom_output), adjoint=dfx.DirectAdjoint(), max_steps=int(1e6))

        x, reward2 = sol.ys

        return jnp.cumsum(reward2, axis=0)[-1], state, {}

    @partial(jax.jit, static_argnames=("self",))
    def sample(self, key: jax.Array) -> Solution:
        """Sample a solution in the search space.
            Hyperparameters are (lambda, sigma, eta, rho). We keep k, z0, phi0 fixed with k nr of neurons, z0 = neuron state and phi0 = theta0, mu0, nu0 where theta0 are all CTRNN parameters
        """

        # Sample hyperparameters
        key, subkey = jr.split(key)
        lambda_ = jr.uniform(subkey, shape=(1,), minval=0.0, maxval=5.0)
        key, subkey = jr.split(key)
        sigma = jr.uniform(subkey, shape=(1,), minval=0.01, maxval=1.0)
        key, subkey = jr.split(key)
        eta = jr.uniform(subkey, shape=(1,), minval=0.0, maxval=100.0)
        key, subkey = jr.split(key)
        rho = jr.uniform(subkey, shape=(1,), minval=0.0, maxval=5.0)

        return (lambda_, sigma, eta, rho)

# %%
from evosax.algorithms import CMA_ES as ES

key = jax.random.PRNGKey(0)

num_generations = 64
population_size = 16

problem = CTRNNSDIProblem()

key, subkey = jax.random.split(key)
problem_state = problem.init(subkey)

# Instantiate evolution strategy
# solution is a PyTree
# hyperparameters are (z0, phi0, lambda, sigma, eta, rho) with z0 = neuron state and phi0 = theta0, mu0, nu0 where theta0 are all CTRNN parameters
key, subkey = jax.random.split(key)
solution = problem.sample(subkey)

es = ES(
    population_size=population_size,
    solution=solution,  # requires a dummy solution
)

# Use default parameters
params = es.default_params

# Initialize evolution strategy
key, subkey = jax.random.split(key)
state = es.init(subkey, solution, params)

# %%
key, subkey = jax.random.split(key)
key_ask, key_eval, key_tell = jax.random.split(subkey, 3)

# Generate a set of candidate solutions to evaluate
population, state = es.ask(key_ask, state, params)

# Evaluate the fitness of the population
fitness, problem_state, info = problem.eval(key_eval, population, problem_state)

# Update the evolution strategy
state, metrics = es.tell(key_tell, population, fitness, state, params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/diffrax/_integrate.py:168, in _assert_term_compatible.<locals>._check(term_cls, term, term_contr_kwargs, yi)
#     167 try:
# --> 168     vf_type = eqx.filter_eval_shape(term.vf, 0.0, yi, args)
#     169 except Exception as e:
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/equinox/_eval_shape.py:38, in filter_eval_shape(fun, *args, **kwargs)
#      37 dynamic, static = partition((fun, args, kwargs), _filter)
# ---> 38 dynamic_out, static_out = jax.eval_shape(ft.partial(_fn, static), dynamic)
#      39 return combine(dynamic_out, static_out.value)
#
#     [... skipping hidden 1 frame]
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/api.py:2840, in eval_shape(fun, *args, **kwargs)
#    2839 except TypeError: fun = partial(fun)
# -> 2840 return jit(fun).eval_shape(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:401, in jit_eval_shape(jit_func, *args, **kwargs)
#     399 @api_boundary
#     400 def jit_eval_shape(jit_func, *args, **kwargs):
# --> 401   p, _ = _infer_params(jit_func._fun, jit_func._jit_info, args, kwargs)
#     402   out_s = [None if isinstance(s, UnspecifiedValue) else s for s in p.params['out_shardings']]
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:716, in _infer_params(fun, ji, args, kwargs)
#     715     return _infer_params_internal(fun, ji, args, kwargs)
# --> 716 return _infer_params_internal(fun, ji, args, kwargs)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:739, in _infer_params_internal(fun, ji, args, kwargs)
#     738 if entry.pjit_params is None:
# --> 739   p, args_flat = _infer_params_impl(
#     740       fun, ji, ctx_mesh, dbg, args, kwargs, in_avals=avals)
#     741   if p.attrs_tracked:  # if attrs, don't populate the cache
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:636, in _infer_params_impl(***failed resolving arguments***)
#     634 attr_token = _attr_cache_index(flat_fun, in_type)
# --> 636 jaxpr, consts, out_avals, attrs_tracked = _create_pjit_jaxpr(
#     637     flat_fun, in_type, attr_token, IgnoreKey(ji.inline))
#     639 if config.mutable_array_checks.value:
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:477, in cache.<locals>.memoized_fun(fun, *args)
#     476   start = time.time()
# --> 477 ans = call(fun, *args)
#     478 if do_explain:
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:1441, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1440 else:
# -> 1441   jaxpr, global_out_avals, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#    1442       fun, in_type)
#    1443   # assert attr_data is sentinel or attr_data matches attrs_tracked
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 with TraceAnnotation(name, **decorator_kwargs):
# --> 334   return func(*args, **kwargs)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:2223, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs)
#    2222 with core.set_current_trace(trace):
# -> 2223   ans = fun.call_wrapped(*in_tracers)
#    2225 out_tracers = map(trace.to_jaxpr_tracer, ans)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 """Calls the transformed function"""
# --> 211 return self.f_transformed(*args, **kwargs)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      72 py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73 ans = f(*py_args, **py_kwargs)
#      74 ans, out_tree = tree_flatten(ans)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:402, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     400 @transformation_with_aux2
#     401 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 402   ans = _fun(*args, **kwargs)
#     403   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/equinox/_eval_shape.py:33, in filter_eval_shape.<locals>._fn(_static, _dynamic)
#      32 _fun, _args, _kwargs = combine(_static, _dynamic)
# ---> 33 _out = _fun(*_args, **_kwargs)
#      34 _dynamic_out, _static_out = partition(_out, _filter)
#
#     [... skipping hidden 1 frame]
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/diffrax/_term.py:194, in ODETerm.vf(self, t, y, args)
#     193 def vf(self, t: RealScalarLike, y: Y, args: Args) -> _VF:
# --> 194     out = self.vector_field(t, y, args)
#     195     if jtu.tree_structure(out) != jtu.tree_structure(y):
#
#     [... skipping hidden 1 frame]
#
# File ~/Coding/projects/oua/src/oua/oua.py:80, in OUAModel.drift(self, t, x, args)
#      79 state_drift = self.model.drift(t, (state, parameters), args)
# ---> 80 param_drift = jax.tree.map(lambda _theta, _mu: self.param_rate * (_mu - _theta), parameters, means)
#      81 mean_drift = jax.tree.map(lambda _mu, _theta: self.mean_rate * RPE * (_theta - _mu), means, parameters)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/tree.py:155, in map(f, tree, is_leaf, *rest)
#     119 """Maps a multi-input function over pytree args to produce a new pytree.
#     120
#     121 Args:
#    (...)    153   - :func:`jax.tree.reduce`
#     154 """
# --> 155 return tree_util.tree_map(f, tree, *rest, is_leaf=is_leaf)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/tree_util.py:358, in tree_map(f, tree, is_leaf, *rest)
#     357 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 358 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/tree_util.py:358, in <genexpr>(.0)
#     357 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 358 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# File ~/Coding/projects/oua/src/oua/oua.py:80, in OUAModel.drift.<locals>.<lambda>(_theta, _mu)
#      79 state_drift = self.model.drift(t, (state, parameters), args)
# ---> 80 param_drift = jax.tree.map(lambda _theta, _mu: self.param_rate * (_mu - _theta), parameters, means)
#      81 mean_drift = jax.tree.map(lambda _mu, _theta: self.mean_rate * RPE * (_theta - _mu), means, parameters)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:1060, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1059 def op(self, *args):
# -> 1060   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:579, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     578 if isinstance(other, _accepted_binop_types):
# --> 579   return binary_op(*args)
#     580 # Note: don't use isinstance here, because we don't want to raise for
#     581 # subclasses, e.g. NamedTuple objects that may override operators.
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/numpy/ufunc_api.py:180, in ufunc.__call__(self, out, where, *args)
#     179 call = self.__static_props['call'] or self._call_vectorized
# --> 180 return call(*args)
#
#     [... skipping hidden 1 frame]
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:340, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     336   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     337                      "`jit`, but 'no_tracing' is set")
#     339 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, executable,
# --> 340  pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     342 maybe_fastpath_data = _get_fastpath_data(
#     343     executable, out_tree, args_flat, out_flat, attrs_tracked, jaxpr.effects,
#     344     jaxpr.consts, jit_info.abstracted_axes,
#     345     pgle_profiler)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:178, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     177 def _python_pjit_helper(fun: Callable, jit_info: PjitInfo, *args, **kwargs):
# --> 178   p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     180   for arg in args_flat:
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:716, in _infer_params(fun, ji, args, kwargs)
#     715     return _infer_params_internal(fun, ji, args, kwargs)
# --> 716 return _infer_params_internal(fun, ji, args, kwargs)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:739, in _infer_params_internal(fun, ji, args, kwargs)
#     738 if entry.pjit_params is None:
# --> 739   p, args_flat = _infer_params_impl(
#     740       fun, ji, ctx_mesh, dbg, args, kwargs, in_avals=avals)
#     741   if p.attrs_tracked:  # if attrs, don't populate the cache
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:636, in _infer_params_impl(***failed resolving arguments***)
#     634 attr_token = _attr_cache_index(flat_fun, in_type)
# --> 636 jaxpr, consts, out_avals, attrs_tracked = _create_pjit_jaxpr(
#     637     flat_fun, in_type, attr_token, IgnoreKey(ji.inline))
#     639 if config.mutable_array_checks.value:
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:477, in cache.<locals>.memoized_fun(fun, *args)
#     476   start = time.time()
# --> 477 ans = call(fun, *args)
#     478 if do_explain:
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:1441, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1440 else:
# -> 1441   jaxpr, global_out_avals, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#    1442       fun, in_type)
#    1443   # assert attr_data is sentinel or attr_data matches attrs_tracked
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 with TraceAnnotation(name, **decorator_kwargs):
# --> 334   return func(*args, **kwargs)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:2223, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs)
#    2222 with core.set_current_trace(trace):
# -> 2223   ans = fun.call_wrapped(*in_tracers)
#    2225 out_tracers = map(trace.to_jaxpr_tracer, ans)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 """Calls the transformed function"""
# --> 211 return self.f_transformed(*args, **kwargs)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      72 py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73 ans = f(*py_args, **py_kwargs)
#      74 ans, out_tree = tree_flatten(ans)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:402, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     400 @transformation_with_aux2
#     401 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 402   ans = _fun(*args, **kwargs)
#     403   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/numpy/ufuncs.py:1280, in multiply(x, y)
#    1279 x, y = promote_args("multiply", x, y)
# -> 1280 return lax.mul(x, y) if x.dtype != bool else lax.bitwise_and(x, y)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/lax/lax.py:1243, in mul(x, y)
#    1242 x, y = core.standard_insert_pvary(x, y)
# -> 1243 return mul_p.bind(x, y)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:496, in Primitive.bind(self, *args, **params)
#     495 args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 496 return self._true_bind(*args, **params)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:512, in Primitive._true_bind(self, *args, **params)
#     511 try:
# --> 512   return self.bind_with_trace(prev_trace, args, params)
#     513 finally:
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:517, in Primitive.bind_with_trace(self, trace, args, params)
#     516 def bind_with_trace(self, trace, args, params):
# --> 517   return trace.process_primitive(self, args, params)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:1972, in DynamicJaxprTrace.process_primitive(self, primitive, tracers, params)
#    1971   return custom_staging_rules[primitive](self, *jaxpr_tracers, **params)
# -> 1972 return self.default_process_primitive(primitive, jaxpr_tracers, params)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:1976, in DynamicJaxprTrace.default_process_primitive(self, primitive, tracers, params)
#    1975 avals = [t.aval for t in tracers]
# -> 1976 out_avals, effects = primitive.abstract_eval(*avals, **params)
#    1977 if isinstance(out_avals, (tuple, list)) != primitive.multiple_results:
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/core.py:549, in _effect_free_abstract_eval.<locals>.abstract_eval_(*args, **kwargs)
#     548 def abstract_eval_(*args, **kwargs):
# --> 549   return abstract_eval(*args, **kwargs), no_effects
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/lax/utils.py:112, in standard_abstract_eval(prim, shape_rule, dtype_rule, weak_type_rule, sharding_rule, vma_rule, *avals, **kwargs)
#     111 core.check_avals_context_mesh(avals, prim.name)
# --> 112 out_shape, out_dtype, out_sharding = call_shape_dtype_sharding_rule(
#     113     prim, shape_rule, dtype_rule, sharding_rule, False,
#     114     *avals, **kwargs)
#     115 out_vma = vma_rule(*avals, **kwargs)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/lax/utils.py:86, in call_shape_dtype_sharding_rule(prim, shape_rule, dtype_rule, sharding_rule, multi_out, *avals, **kwargs)
#      84 def call_shape_dtype_sharding_rule(prim, shape_rule, dtype_rule, sharding_rule,
#      85                                    multi_out, *avals, **kwargs):
# ---> 86   out_shapes = shape_rule(*avals, **kwargs)
#      87   out_dtypes = dtype_rule(*avals, **kwargs)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/lax/lax.py:3933, in broadcasting_shape_rule(name, *avals)
#    3932   return ()
# -> 3933 return _try_broadcast_shapes(*shapes, name=name)
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/lax/lax.py:135, in _try_broadcast_shapes(name, *shapes)
#     134     else:
# --> 135       raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#     136                       f'{", ".join(map(str, map(tuple, shapes)))}.')
#     137 return tuple(result_shape)
#
# TypeError: mul got incompatible shapes for broadcasting: (16, 1), (2, 2).
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/diffrax/_integrate.py:194, in _assert_term_compatible(y, args, terms, term_structure, contr_kwargs)
#     193     with jax.numpy_dtype_promotion("standard"):
# --> 194         jtu.tree_map(_check, term_structure, terms, contr_kwargs, y)
#     195 except Exception as e:
#     196     # ValueError may also arise from mismatched tree structures
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/tree_util.py:358, in tree_map(f, tree, is_leaf, *rest)
#     357 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 358 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/tree_util.py:358, in <genexpr>(.0)
#     357 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 358 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/diffrax/_integrate.py:170, in _assert_term_compatible.<locals>._check(term_cls, term, term_contr_kwargs, yi)
#     169 except Exception as e:
# --> 170     raise ValueError(f"Error while tracing {term}.vf: " + str(e))
#     171 vf_type_compatible = eqx.filter_eval_shape(
#     172     better_isinstance, vf_type, vf_type_expected
#     173 )
#
# ValueError: Error while tracing ODETerm(
#   vector_field=BoundMethod(
#     __func__=<function OUAModel.drift>,
#     __self__=OUAModel(
#       model=CoupledSystem(
#         agent=CTRNN(
#           num_inputs=2,
#           num_neurons=2,
#           num_outputs=1,
#           tau=f32[2],
#           A=f32[2,2],
#           bias=f32[2],
#           B=f32[2,2],
#           C=f32[1,2],
#           noise_scale=0.0
#         ),
#         env=StochasticDoubleIntegrator(
#           mass=1.0, damping_factor=0.5, noise_scale=0.1
#         )
#       ),
#       param_rate=f32[16,1],
#       noise_rate=0.0,
#       mean_rate=f32[16,1],
#       reward_rate=f32[16,1]
#     )
#   )
# ).vf: mul got incompatible shapes for broadcasting: (16, 1), (2, 2).
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/diffrax/_integrate.py:194, in _assert_term_compatible(y, args, terms, term_structure, contr_kwargs)
#     193     with jax.numpy_dtype_promotion("standard"):
# --> 194         jtu.tree_map(_check, term_structure, terms, contr_kwargs, y)
#     195 except Exception as e:
#     196     # ValueError may also arise from mismatched tree structures
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/tree_util.py:358, in tree_map(f, tree, is_leaf, *rest)
#     357 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 358 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/jax/_src/tree_util.py:358, in <genexpr>(.0)
#     357 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 358 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/diffrax/_integrate.py:140, in _assert_term_compatible.<locals>._check(term_cls, term, term_contr_kwargs, yi)
#     137     for term, arg, term_contr_kwarg in zip(
#     138         term.terms, get_args(_tmp), term_contr_kwargs
#     139     ):
# --> 140         _assert_term_compatible(yi, args, term, arg, term_contr_kwarg)
#     141 else:
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/diffrax/_integrate.py:197, in _assert_term_compatible(y, args, terms, term_structure, contr_kwargs)
#     195 except Exception as e:
#     196     # ValueError may also arise from mismatched tree structures
# --> 197     raise ValueError("Terms are not compatible with solver!") from e
#
# ValueError: Terms are not compatible with solver!
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 8
#       5 population, state = es.ask(key_ask, state, params)
#       7 # Evaluate the fitness of the population
# ----> 8 fitness, problem_state, info = problem.eval(key_eval, population, problem_state)
#      10 # Update the evolution strategy
#      11 state, metrics = es.tell(key_tell, population, fitness, state, params)
#
#     [... skipping hidden 16 frame]
#
# Cell In[18], line 39, in CTRNNSDIProblem.eval(self, key, solutions, state)
#      36 system = OUAModel(model=coupled_system, param_rate=param_rate, noise_rate=0.0, mean_rate=mean_rate, reward_rate=reward_rate)
#      38 key, = jr.split(key, 1)
# ---> 39 sol = dfx.diffeqsolve(system.terms(key), dfx.EulerHeun(), args=args, t0=0, t1=300, dt0=0.01, y0=system.initial, saveat=dfx.SaveAt(steps=True, fn=custom_output), adjoint=dfx.DirectAdjoint(), max_steps=int(1e6))
#      41 x, reward2 = sol.ys
#      43 return jnp.cumsum(reward2, axis=0)[-1], state, {}
#
#     [... skipping hidden 19 frame]
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/diffrax/_integrate.py:1089, in diffeqsolve(terms, solver, t0, t1, dt0, y0, args, saveat, stepsize_controller, adjoint, event, max_steps, throw, progress_meter, solver_state, controller_state, made_jump, discrete_terminating_event)
#    1086         terms = MultiTerm(*terms)
#    1088 # Error checking for term compatibility
# -> 1089 _assert_term_compatible(
#    1090     y0,
#    1091     args,
#    1092     terms,
#    1093     solver.term_structure,
#    1094     solver.term_compatible_contr_kwargs,
#    1095 )
#    1097 if is_sde(terms):
#    1098     if not isinstance(solver, (AbstractItoSolver, AbstractStratonovichSolver)):
#
# File ~/Coding/projects/neuromorphic_intelligence/.venv/lib/python3.13/site-packages/diffrax/_integrate.py:197, in _assert_term_compatible(y, args, terms, term_structure, contr_kwargs)
#     194         jtu.tree_map(_check, term_structure, terms, contr_kwargs, y)
#     195 except Exception as e:
#     196     # ValueError may also arise from mismatched tree structures
# --> 197     raise ValueError("Terms are not compatible with solver!") from e
#
# ValueError: Terms are not compatible with solver!

# %%
key, subkey = jax.random.split(key)
state = es.init(subkey, solution, params)

metrics_log = []
for i in range(num_generations):
    key, subkey = jax.random.split(key)
    key_ask, key_eval, key_tell = jax.random.split(subkey, 3)

    population, state = es.ask(key_ask, state, params)

    fitness, problem_state, info = problem.eval(key_eval, population, problem_state)

    state, metrics = es.tell(key_tell, population, fitness, state, params)

    # Log metrics
    metrics_log.append(metrics)

# %%
# Extract the best fitness values across generations
generations = [metrics["generation_counter"] for metrics in metrics_log]
best_fitness = [metrics["best_fitness"] for metrics in metrics_log]

plt.figure(figsize=(10, 5))
plt.plot(generations, best_fitness, label="Best Fitness", marker="o", markersize=3)

plt.title("Best fitness over generations")
plt.xlabel("Generation")
plt.ylabel("Fitness")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
