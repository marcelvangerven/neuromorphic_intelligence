# %% [markdown]
# # Memory-based control policy optimization
#
# In this more advanced example, we will optimize a symbolic control policy that is extended with a dynamic latent memory (check out this paper for more details: https://arxiv.org/abs/2406.02765). The memory is defined by a set of differential equations, consisting of a tree for each latent unit. The memory updates every time step, and the control policy maps the memory to a control signal via an additional readout tree. This setup is applied to the partially observable acrobot swingup task, in which the angular velocity is hidden.

# %%
# Specify the cores to use for XLA
import os
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=10'

import jax
import jax.numpy as jnp
import diffrax
import jax.random as jr
import matplotlib.pyplot as plt
from jax import Array
from typing import Tuple, Callable
import copy

from kozax.genetic_programming import GeneticProgramming
from kozax.environments.control_environments.acrobot import Acrobot
from kozax.environments.control_environments.harmonic_oscillator import HarmonicOscillator
# Out:
# These device(s) are detected:  [CpuDevice(id=0), CpuDevice(id=1), CpuDevice(id=2), CpuDevice(id=3), CpuDevice(id=4), CpuDevice(id=5), CpuDevice(id=6), CpuDevice(id=7), CpuDevice(id=8), CpuDevice(id=9)]

# %% [markdown]
# First we generate data, consisting of initial conditions, keys for noise, targets and parameters of the environment.

# %%
def get_data(key, env, batch_size, dt, T, param_setting):
    init_key, noise_key2, param_key = jr.split(key, 3)
    x0, targets = env.sample_init_states(batch_size, init_key)
    obs_noise_keys = jr.split(noise_key2, batch_size)
    ts = jnp.arange(0, T, dt)

    params = env.sample_params(batch_size, param_setting, ts, param_key)
    return x0, ts, targets, obs_noise_keys, params

key = jr.PRNGKey(0)
gp_key, data_key = jr.split(key)
batch_size = 8
T = 40
dt = 0.2
param_setting = "Constant"

env = Acrobot(n_obs = 2) # Partial observably Acrobot

data = get_data(data_key, env, batch_size, dt, T, param_setting)

# %% [markdown]
# The evaluator class parallelizes the simulation of the control loop over the batched data. In each trajectory, a coupled dynamical system is simulated using diffrax, integrating both the dynamic memory and the dynamic environment. At every time step, the state of the environment is mapped to an observations and the latent memory is mapped to a control signal. Afterwards, the state equation of the memory and environment state is computed. When the simulation is done, the fitness is computed given the control and environment state.

# %%
class Evaluator:
    def __init__(self, env, state_size: int, dt0: float, solver=diffrax.Euler(), max_steps: int = 16**4, stepsize_controller: diffrax.AbstractStepSizeController = diffrax.ConstantStepSize()) -> None:
        """Evaluates dynamic symbolic policies in control tasks.

        Args:
            env: Environment on which the candidate is evaluated.
            state_size: Dimensionality of the hidden state.
            dt0: Initial step size for integration.
            solver: Solver used for integration (default: diffrax.Euler()).
            max_steps: The maximum number of steps that can be used in integration (default: 16**4).
            stepsize_controller: Controller for the stepsize during integration (default: diffrax.ConstantStepSize()).

        Attributes:
            env: Environment on which the candidate is evaluated.
            max_fitness: Max fitness which is assigned when a trajectory returns an invalid value.
            state_size: Dimensionality of the hidden state.
            obs_size: Dimensionality of the observations.
            control_size: Dimensionality of the control.
            latent_size: Dimensionality of the state of the environment.
            dt0: Initial step size for integration.
            solver: Solver used for integration.
            max_steps: The maximum number of steps that can be used in integration.
            stepsize_controller: Controller for the stepsize during integration.
        """
        self.env = env
        self.max_fitness = 1e4
        self.state_size = state_size
        self.obs_size = env.n_obs
        self.control_size = env.n_control_inputs
        self.latent_size = env.n_var*env.n_dim
        self.dt0 = dt0
        self.solver = solver
        self.max_steps = max_steps
        self.stepsize_controller = stepsize_controller

    def __call__(self, candidate: Array, data: Tuple, tree_evaluator: Callable) -> float:
        """Evaluates the candidate on a task.

        Args:
            candidate: The coefficients of the candidate.
            data: The data required to evaluate the candidate.
            tree_evaluator: Function for evaluating trees.

        Returns:
            Fitness of the candidate.
        """
        _, _, _, _, fitness = jax.vmap(self.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(candidate, *data, tree_evaluator)

        fitness = jnp.mean(fitness)
        return fitness
      
    def evaluate_trajectory(self, candidate: Array, x0: Array, ts: Array, target: float, obs_noise_key: jr.PRNGKey, params: Tuple, tree_evaluator: Callable) -> Tuple[Array, Array, Array, Array, float]:
        """Solves the coupled differential equation of the system and controller. 
        The differential equation of the system is defined in the environment and the differential equation 
        of the control is defined by the set of trees.

        Args:
            candidate: Candidate with trees for the hidden state and readout.
            x0: Initial state of the system.
            ts: Time points on which the controller is evaluated.
            target: Target position that the system should reach.
            obs_noise_key: Key to generate noisy observations.
            params: Parameters that define the environment.
            tree_evaluator: Function for evaluating trees.

        Returns:
            States, observations, control, activities of the hidden state of the candidate and the fitness of the candidate.
        """
        env = copy.copy(self.env)
        env.initialize_parameters(params, ts)

        state_equation = candidate[:self.state_size]
        readout = candidate[self.state_size:]
        
        solver = self.solver
        dt0 = self.dt0
        saveat = diffrax.SaveAt(ts=ts)

        # Concatenate the initial state of the system with the initial state of the latent memory
        _x0 = jnp.concatenate([x0, jnp.zeros(self.state_size)])

        system = diffrax.ODETerm(self._drift)
        
        # Solve the coupled system of the environment and the controller
        sol = diffrax.diffeqsolve(
            system, solver, ts[0], ts[-1], dt0, _x0, saveat=saveat, adjoint=diffrax.DirectAdjoint(), max_steps=self.max_steps, event=diffrax.Event(self.env.cond_fn_nan), 
            args=(env, state_equation, readout, obs_noise_key, target, tree_evaluator), stepsize_controller=self.stepsize_controller, throw=False
        )

        xs = sol.ys[:,:self.latent_size]
        # Get observations of the state at every time step
        _, ys = jax.lax.scan(env.f_obs, obs_noise_key, (ts, xs))

        activities = sol.ys[:,self.latent_size:]
        # Get control actions at every time step
        us = jax.vmap(lambda y, a, tar: tree_evaluator(readout, jnp.concatenate([y, a, jnp.zeros(self.control_size), target])), in_axes=[0,0,None])(ys, activities, target)

        # Compute the fitness of the candidate in this trajectory
        fitness = env.fitness_function(xs, us[:,None], target, ts)

        return xs, ys, us, activities, fitness
    
    def _drift(self, t, x_a, args):
        env, state_equation, readout, obs_noise_key, target, tree_evaluator = args
        x = x_a[:self.latent_size]
        a = x_a[self.latent_size:]

        _, y = env.f_obs(obs_noise_key, (t, x)) #Get observations from system
        u = tree_evaluator(readout, jnp.concatenate([jnp.zeros(self.obs_size), a, jnp.zeros(self.control_size), target])) #Compute control action from latent memory

        u = jnp.atleast_1d(u)

        dx = env.drift(t, x, u) #Apply control to system and get system change
        da = tree_evaluator(state_equation, jnp.concatenate([y, a, u, target])) #Compute change in latent memory

        return jnp.concatenate([dx, da])

# %% [markdown]
# Here we define the hyperparameters, operators, variables and initialize the strategy. The control policy will consist of two latent variables and a readout layer. `layer_sizes` allows us to define different types of tree, where `variable_list` contains different sets of input variables for each type of tree. The readout layer will only receive the latent states, while the inputs to the state equations consists of the observations, control signal and latent states.

# %%
#Define hyperparameters
population_size = 100
num_populations = 10
num_generations = 50
state_size = 2

#Define expressions
operator_list = [("+", lambda x, y: x + y, 2, 0.5), 
                ("-", lambda x, y: x - y, 2, 0.1),
                ("*", lambda x, y: x * y, 2, 0.5),
                ("sin", lambda x: jnp.sin(x), 1, 0.1),
                ("cos", lambda x: jnp.cos(x), 1, 0.1)]

variable_list = [["x" + str(i) for i in range(env.n_obs)] + ["a1", "a2", "u"], ["a1", "a2"]]

layer_sizes = jnp.array([state_size, env.n_control_inputs])

#Define evaluator
fitness_function = Evaluator(env, state_size, 0.05, solver=diffrax.Dopri5(), stepsize_controller=diffrax.PIDController(atol=1e-4, rtol=1e-4, dtmin=0.001), max_steps=1000)

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, layer_sizes, num_populations = num_populations, size_parsimony=0.003)

strategy.fit(gp_key, data, verbose=True)
# Out:
# Input data should be formatted as: ['x0', 'x1', 'a1', 'a2', 'u'].
# In generation 1, best fitness = 152.5511, best solution = [a2**2*x0, 0.987, a1 - cos(a1**2)]
# In generation 2, best fitness = 152.5511, best solution = [a2**2*x0, 0.987, a1 - cos(a1**2)]
# In generation 3, best fitness = 152.5511, best solution = [a2**2*x0, 0.987, a1 - cos(a1**2)]
# In generation 4, best fitness = 141.0616, best solution = [a2 + x1 + 4.04, sin(x0), a2*(2*a1 - 0.628)]
# In generation 5, best fitness = 141.0616, best solution = [a2 + x1 + 4.04, sin(x0), a2*(2*a1 - 0.628)]
# In generation 6, best fitness = 141.0616, best solution = [a2 + x1 + 4.04, sin(x0), a2*(2*a1 - 0.628)]
# In generation 7, best fitness = 141.0616, best solution = [a2 + x1 + 4.04, sin(x0), a2*(2*a1 - 0.628)]
# In generation 8, best fitness = 141.0616, best solution = [a2 + x1 + 4.04, sin(x0), a2*(2*a1 - 0.628)]
# In generation 9, best fitness = 141.0616, best solution = [a2 + x1 + 4.04, sin(x0), a2*(2*a1 - 0.628)]
# In generation 10, best fitness = 137.8828, best solution = [1.29*a2 + 1.29*x1 + 5.4, sin(x0), a2*(a1 + 1.23) + a2 - 0.606]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 24
#      21 #Initialize strategy
#      22 strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, layer_sizes, num_populations = num_populations, size_parsimony=0.003)
# ---> 24 strategy.fit(gp_key, data, verbose=True)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/kozax/genetic_programming.py:479, in GeneticProgramming.fit(self, key, data, verbose, save_pareto_front, save_path)
#     477 for g in range(self.num_generations):
#     478     key, eval_key, sample_key = jr.split(key, 3)
# --> 479     fitness, population = self.evaluate_population(population, data, eval_key)
#     481     if verbose:
#     482         best_fitness, best_solution = self.get_statistics(g)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/kozax/genetic_programming.py:771, in GeneticProgramming.evaluate_population(self, populations, data, key)
#     768     flat_populations = flat_populations.at[best_candidates_idx].set(optimized_population)
#     769     fitness = fitness.at[best_candidates_idx].set(optimized_fitness)
# --> 771 self.update_pareto_front(fitness, flat_populations)
#     773 # Increase fitness based on the size of the candidate
#     774 fitness = fitness + jax.vmap(lambda array: self.size_parsimony * jnp.sum(array[:, :, 0] != 0))(flat_populations)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/kozax/genetic_programming.py:962, in GeneticProgramming.update_pareto_front(self, current_fitness, current_population)
#     951 """
#     952 Updates the Pareto front with the current population.
#     953
#    (...)    959     Current population.
#     960 """
#     961 # Compute complexity of the current population
# --> 962 current_population_complexity = jax.vmap(lambda array: jnp.sum(array[:, :, 0] != 0))(current_population)
#     963 pareto_fitness, pareto_solutions = self.pareto_front
#     965 # Replace the best solutions in the Pareto front with the best solutions at each complexity level
#
#     [... skipping hidden 1 frame]
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/api.py:1015, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1012 try:
#    1013   axis_data = batching.AxisData(axis_name, axis_size_, spmd_axis_name,
#    1014                                 explicit_mesh_axis)
# -> 1015   out_flat = batching.batch(
#    1016       flat_fun, axis_data, in_axes_flat,
#    1017       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes)
#    1018   ).call_wrapped(*args_flat)
#    1019 except batching.SpecMatchError as e:
#    1020   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:210, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     208 def call_wrapped(self, *args, **kwargs):
#     209   """Calls the transformed function"""
# --> 210   return self.f_transformed(*args, **kwargs)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:604, in _batch_outer(f, axis_data, in_dims, *in_vals)
#     602 tag = TraceTag()
#     603 with source_info_util.transform_name_stack('vmap'):
# --> 604   outs, trace = f(tag, in_dims, *in_vals)
#     605 with core.ensure_no_leaks(trace): del trace
#     606 return outs
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:619, in _batch_inner(f, axis_data, out_dim_dests, tag, in_dims, *in_vals)
#     615   in_tracers = map(partial(to_elt, trace, idx), in_vals, in_dims)
#     616   with (core.set_current_trace(trace),
#     617         core.extend_axis_env_nd([(axis_data.name, axis_data.size)]),
#     618         core.add_spmd_axis_names(axis_data.spmd_name)):
# --> 619     outs = f(*in_tracers)
#     621 out_dim_dests = out_dim_dests() if callable(out_dim_dests) else out_dim_dests
#     622 out_vals = map(partial(from_elt, trace, axis_data.size,
#     623                        axis_data.explicit_mesh_axis),
#     624                range(len(outs)), outs, out_dim_dests)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:339, in flatten_fun_for_vmap(f, store, in_tree, *args_flat)
#     335 @lu.transformation_with_aux2
#     336 def flatten_fun_for_vmap(f: Callable,
#     337                          store: lu.Store, in_tree: PyTreeDef, *args_flat):
#     338   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# --> 339   ans = f(*py_args, **py_kwargs)
#     340   ans, out_tree = tree_flatten(ans, is_leaf=is_vmappable)
#     341   store.store(out_tree)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:370, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     368 @transformation_with_aux2
#     369 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 370   ans = _fun(*args, **kwargs)
#     371   result_paths = [_clean_keystr_arg_names(path) for path, _ in generate_key_paths(ans)]
#     372   if _store:
#     373     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     374     # the bwd function in a custom_vjp
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/kozax/genetic_programming.py:962, in GeneticProgramming.update_pareto_front.<locals>.<lambda>(array)
#     951 """
#     952 Updates the Pareto front with the current population.
#     953
#    (...)    959     Current population.
#     960 """
#     961 # Compute complexity of the current population
# --> 962 current_population_complexity = jax.vmap(lambda array: jnp.sum(array[:, :, 0] != 0))(current_population)
#     963 pareto_fitness, pareto_solutions = self.pareto_front
#     965 # Replace the best solutions in the Pareto front with the best solutions at each complexity level
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:1060, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1059 def op(self, *args):
# -> 1060   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:652, in _getitem(self, item)
#     651 def _getitem(self, item):
# --> 652   return indexing.rewriting_take(self, item)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/numpy/indexing.py:613, in rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value, out_sharding)
#     604 def rewriting_take(arr, idx, indices_are_sorted=False, unique_indices=False,
#     605                    mode=None, fill_value=None, out_sharding=None):
#     606   # Computes arr[idx].
#    (...)    610   # For simplicity of generated primitives, we call lax.dynamic_slice in the
#     611   # simplest cases: i.e. non-dynamic arrays indexed with integers and slices.
# --> 613   if (result := _attempt_rewriting_take_via_slice(arr, idx, mode)) is not None:
#     614     return result
#     616   # TODO(mattjj,dougalm): expand dynamic shape indexing support
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/numpy/indexing.py:590, in _attempt_rewriting_take_via_slice(arr, idx, mode)
#     588   int_start_indices = [int(i) for i in start_indices]  # type: ignore
#     589   int_limit_indices = [i + s for i, s in zip(int_start_indices, slice_sizes)]
# --> 590   arr = lax.slice(
#     591       arr, start_indices=int_start_indices, limit_indices=int_limit_indices)
#     592 else:
#     593   # We must be careful with dtypes because dynamic_slice requires all
#     594   # start indices to have matching types.
#     595   if len(start_indices) > 1:
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/lax/slicing.py:108, in slice(operand, start_indices, limit_indices, strides)
#      57 def slice(operand: ArrayLike, start_indices: Sequence[int],
#      58           limit_indices: Sequence[int],
#      59           strides: Sequence[int] | None = None) -> Array:
#      60   """Wraps XLA's `Slice
#      61   <https://www.tensorflow.org/xla/operation_semantics#slice>`_
#      62   operator.
#    (...)    106     - :func:`jax.lax.dynamic_slice`
#     107   """
# --> 108   return slice_p.bind(operand, start_indices=tuple(start_indices),
#     109                       limit_indices=tuple(limit_indices),
#     110                       strides=None if strides is None else tuple(strides))
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/core.py:502, in Primitive.bind(self, *args, **params)
#     500 def bind(self, *args, **params):
#     501   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 502   return self._true_bind(*args, **params)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/core.py:520, in Primitive._true_bind(self, *args, **params)
#     518 trace_ctx.set_trace(eval_trace)
#     519 try:
# --> 520   return self.bind_with_trace(prev_trace, args, params)
#     521 finally:
#     522   trace_ctx.set_trace(prev_trace)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/core.py:525, in Primitive.bind_with_trace(self, trace, args, params)
#     524 def bind_with_trace(self, trace, args, params):
# --> 525   return trace.process_primitive(self, args, params)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:495, in BatchTrace.process_primitive(self, p, tracers, params)
#     493 elif p in primitive_batchers:
#     494   with core.set_current_trace(self.parent_trace):
# --> 495     val_out, dim_out = primitive_batchers[p](vals_in, dims_in, **params)
#     496 else:
#     497   raise NotImplementedError("Batching rule for '{}' not implemented".format(p))
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/lax/slicing.py:1342, in _slice_batching_rule(batched_args, batch_dims, start_indices, limit_indices, strides)
#    1339   new_strides = list(strides)
#    1340   new_strides.insert(bdim, 1)
# -> 1342 out = slice(operand, new_start_indices, new_limit_indices, new_strides)
#    1343 return out, bdim
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/lax/slicing.py:108, in slice(operand, start_indices, limit_indices, strides)
#      57 def slice(operand: ArrayLike, start_indices: Sequence[int],
#      58           limit_indices: Sequence[int],
#      59           strides: Sequence[int] | None = None) -> Array:
#      60   """Wraps XLA's `Slice
#      61   <https://www.tensorflow.org/xla/operation_semantics#slice>`_
#      62   operator.
#    (...)    106     - :func:`jax.lax.dynamic_slice`
#     107   """
# --> 108   return slice_p.bind(operand, start_indices=tuple(start_indices),
#     109                       limit_indices=tuple(limit_indices),
#     110                       strides=None if strides is None else tuple(strides))
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/core.py:502, in Primitive.bind(self, *args, **params)
#     500 def bind(self, *args, **params):
#     501   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 502   return self._true_bind(*args, **params)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/core.py:520, in Primitive._true_bind(self, *args, **params)
#     518 trace_ctx.set_trace(eval_trace)
#     519 try:
# --> 520   return self.bind_with_trace(prev_trace, args, params)
#     521 finally:
#     522   trace_ctx.set_trace(prev_trace)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/core.py:525, in Primitive.bind_with_trace(self, trace, args, params)
#     524 def bind_with_trace(self, trace, args, params):
# --> 525   return trace.process_primitive(self, args, params)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/core.py:1024, in EvalTrace.process_primitive(self, primitive, args, params)
#    1022       return primitive.bind_with_trace(arg._trace, args, params)
#    1023 check_eval_args(args)
# -> 1024 return primitive.impl(*args, **params)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/lax/slicing.py:1364, in _slice_impl(x, start_indices, limit_indices, strides)
#    1360   return dispatch.apply_primitive(
#    1361     slice_p, x, start_indices=start_indices,
#    1362     limit_indices=limit_indices, strides=strides)
#    1363 slice_sizes = tuple(np.array(limit_indices) - np.array(start_indices))
# -> 1364 return dispatch.apply_primitive(dynamic_slice_p, x, *start_indices,
#    1365                                 slice_sizes=slice_sizes)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/dispatch.py:90, in apply_primitive(prim, *args, **params)
#      88 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      89 try:
# ---> 90   outs = fun(*args)
#      91 finally:
#      92   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 1 frame]
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:341, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     336 if config.no_tracing.value:
#     337   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     338                      "`jit`, but 'no_tracing' is set")
#     340 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, executable,
# --> 341  pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     343 maybe_fastpath_data = _get_fastpath_data(
#     344     executable, out_tree, args_flat, out_flat, attrs_tracked, jaxpr.effects,
#     345     jaxpr.consts, jit_info.abstracted_axes,
#     346     pgle_profiler)
#     348 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:197, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     195   out_flat, compiled, profiler = _pjit_call_impl_python(*args_flat, **p.params)
#     196 else:
# --> 197   out_flat = pjit_p.bind(*args_flat, **p.params)
#     198   compiled = None
#     199   profiler = None
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/core.py:502, in Primitive.bind(self, *args, **params)
#     500 def bind(self, *args, **params):
#     501   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 502   return self._true_bind(*args, **params)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/core.py:520, in Primitive._true_bind(self, *args, **params)
#     518 trace_ctx.set_trace(eval_trace)
#     519 try:
# --> 520   return self.bind_with_trace(prev_trace, args, params)
#     521 finally:
#     522   trace_ctx.set_trace(prev_trace)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/core.py:525, in Primitive.bind_with_trace(self, trace, args, params)
#     524 def bind_with_trace(self, trace, args, params):
# --> 525   return trace.process_primitive(self, args, params)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/core.py:1024, in EvalTrace.process_primitive(self, primitive, args, params)
#    1022       return primitive.bind_with_trace(arg._trace, args, params)
#    1023 check_eval_args(args)
# -> 1024 return primitive.impl(*args, **params)
#
# File ~/Research/projects/oua/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:1724, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, compiler_options_kvs, *args)
#    1715 donated_argnums = tuple(i for i, d in enumerate(donated_invars) if d)
#    1716 cache_key = pxla.JitGlobalCppCacheKeys(
#    1717     donate_argnums=donated_argnums, donate_argnames=None,
#    1718     device=None, backend=None,
#    (...)   1722     out_layouts_treedef=None, out_layouts_leaves=out_layouts,
#    1723     use_resource_env=resource_env is not None)
# -> 1724 return xc._xla.pjit(
#    1725     name, f, call_impl_cache_miss, [], [], cache_key,
#    1726     tree_util.dispatch_registry, pxla.cc_shard_arg,
#    1727     _get_cpp_global_cache(cache_key.contains_explicit_attributes))(*args)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualize best solution

# %%
#Generate test_data
data = get_data(jr.PRNGKey(10), env, 1, 0.01, T, param_setting)
x0s, ts, _, _, params = data

best_candidate = strategy.pareto_front[1][21]

xs, ys, us, activities, fitness = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(best_candidate, *data, strategy.tree_evaluator)

plt.plot(ts, -jnp.cos(xs[0,:,0]), color = f"C{0}", label="first link")
plt.plot(ts, -jnp.cos(xs[0,:,0]) - jnp.cos(xs[0,:,0] + xs[0,:,1]), color = f"C{1}", label="second link")
plt.hlines(1.5, ts[0], ts[-1], linestyles='dashed', color = "black")

plt.legend(loc="best")
plt.show()

# %% [markdown]
# The acrobot and other environments provided by Kozax also include features such as process noise, observations noise and varying environment settings, in which the memory-based control policy outperforms memory-less policies.
